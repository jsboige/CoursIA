# %% [markdown]
# # 4.2i — Détection SOTA : YOLO sous ultralytics, scènes difficiles
#
# [← Série 04-Vision](README.md) | [4.2g — YOLO SOTA (terrain de référence)](4.2g-Detection-SOTA-Ultralytics.ipynb)
#
# **Acceptance issue #16337** : faire passer le pipeline ultralytics sur un **terrain plus hostile** que le 4.2g — occlusions partielles + multi-échelle — et mesurer comment les trois familles de modèles (YOLOv5nu, YOLOv8s, YOLO11m) réagissent à la dégradation.
#
# **Pourquoi ce notebook existe** : le terrain du 4.2g place 1 à 3 objets **bien séparés**, **taille unique** ~14-44 px, **pas d'occlusion**. C'est un cas *facile*. Sur des scènes réalistes (rue, usine, médical), on trouve des objets **partiellement cachés** et des **tailles très différentes** dans la même image. Ce notebook reproduit ces deux stresseurs et observe l'évolution des métriques par rapport au terrain de référence.

# %% [markdown]
# ## 1. Position dans la série
#
# | Notebook | Terrain | Modèles | Métrique centrale |
# |---|---|---|---|
# | 4.2c | Synthétique AnchorNet (taille unique, peu d'occlusions) | AnchorNet from scratch | mAP10 (IoU≥0.1) |
# | 4.2e | Idem, perte rééquilibrée | Focal-Loss from scratch | mAP10 |
# | 4.2f | Idem (taille unique) | Faster R-CNN, RetinaNet, FCOS (torchvision SOTA) | mAP10 |
# | 4.2g | **Synthétique standard, terrain 4.2c** | YOLOv5nu, YOLOv8s, YOLO11n, YOLO11s | mAP10 |
# | **4.2i (ici)** | **Synthétique hostile : occlusions + multi-échelle** | **YOLOv5nu, YOLOv8s, YOLO11m** | **mAP10 + dégradation vs 4.2g** |
#
# **Note méthodologique** : ce notebook ne **remplace** pas le 4.2g — il le **prolonge**. Le terrain de référence reste le terrain canonique pour comparer les familles entre elles. Ici, on garde les modèles (et le protocole) du 4.2g, mais on change le générateur synthétique pour stresser les modèles sur les deux axes où les détecteurs one-stage sont historiquement les plus exposés.

# %% [markdown]
# ## 2. Récit YOLO par année (2016 → 2024)
#
# Avant de lancer la mesure, un point sur la famille — pas une fiche constructeur, mais **les changements qui expliquent pourquoi trois tailles à trois époques différentes cohabitent** dans le state-of-the-art.
#
# ```
# 2016  YOLOv1   Redmon et al.                — one-stage, 7×7 grille fixe, anchors figées
# 2017  YOLOv2   Redmon & Farhadi             — anchor boxes k-means, Darknet-19, BN
# 2018  YOLOv3   Redmon & Farhadi             — FPN multi-échelle (3 échelles), Darknet-53 résiduel
# 2020  YOLOv4   Bochkovskiy et al.           — CSPDarknet53, PANet neck, mosaic augmentation
# 2020  YOLOv5   Glenn Jocher / Ultralytics   — PyTorch, auto-anchor, hyperparamètres heuristiques
# 2022  YOLOv7   Wang et al.                  — E-ELAN, trainable bag-of-freebies
# 2023  YOLOv8   Ultralytics                  — anchor-free, C2f block, découpled head
# 2024  YOLO11   Ultralytics                  — C3k2 block (C2f allégé), attention optionnelle
# ```
#
# Les trois modèles comparés ici :
#
# - **YOLOv5nu** (re-implémentation Ultralytics v8.4, suffix `u`) : modèle **historique**, anchor-based, encore distribué et utilisé en production. ~2.6 M params (n) — la **baseline de capacité minimale**.
# - **YOLOv8s** : passage **anchor-free**, C2f block, découpled head. Refonte structurelle. ~11 M params (s).
# - **YOLO11m** : evolution post-YOLOv8, C3k2 (variante C2f allégée), meilleure efficacité paramétrique. ~20 M params (m) — le **modèle de capacité intermédiaire**.
#
# Le but de la comparaison : **observer comment la capacité (params) traduit le stress (occlusions + multi-échelle)**, pas de proclamer un "vainqueur" — chaque taille a son domaine.

# %%
import json
import time
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import torch
import cv2
from ultralytics import YOLO

SEED = 16337
IMG = 96
DEVICE = 0 if torch.cuda.is_available() else "cpu"
torch.manual_seed(SEED)
np.random.seed(SEED)

print("seed:", SEED, "| device:", DEVICE,
      "| cuda:", torch.cuda.is_available(),
      "| img:", IMG)
if torch.cuda.is_available():
    print("GPU 0:", torch.cuda.get_device_name(0),
          "mem libre:",
          f"{(torch.cuda.get_device_properties(0).total_memory - torch.cuda.memory_allocated(0)) // 1024**2} MB")
print("ultralytics:", __import__("ultralytics").__version__)
# Out:
# seed: 16337 | device: 0 | cuda: True | img: 96
# GPU 0: NVIDIA GeForce RTX 3090 mem libre: 24575 MB
# ultralytics: 8.4.155

# %% [markdown]
# ## 3. Générateur de scènes difficiles
#
# Le générateur du 4.2g produit 1 à 3 objets **non-occludés**, **taille 14-44 px**, espacement minimal. On garde ce squelette, mais on ajoute **deux stresseurs** :
#
# 1. **Occlusions partielles** : chaque objet a 30 % de chances d'être recouvert par un grand **rectangle sombre** (largeur 35-60 % de l'image, hauteur 25-50 %) — simule un objet du premier plan qui passe devant.
# 2. **Multi-échelle** : on remplace la fourchette unique 14-44 px par **deux classes** :
#    - petit objet : 8-18 px (40 % des cas) — exercice classique sur scènes larges
#    - gros objet : 30-60 px (60 % des cas) — exercices classiques sur scènes zoomées
#
# Ces deux changements ciblent les deux axes où les détecteurs **anchor-based** (YOLOv5) et **anchor-free** (YOLOv8, YOLO11) diffèrent historiquement : la **gestion des échelles** et la **résistance aux occlusions partielles**.

# %%
def iou_np(a, b):
    """IoU scalaire entre deux boites (x0, y0, w, h)."""
    ix = max(0.0, min(a[0] + a[2], b[0] + b[2]) - max(a[0], b[0]))
    iy = max(0.0, min(a[1] + a[3], b[1] + b[3]) - max(a[1], b[1]))
    inter = ix * iy
    union = a[2] * a[3] + b[2] * b[3] - inter
    return inter / union if union > 0 else 0.0


def make_difficult_image(rng):
    """Image avec 1-4 objets, 30% occlusions, multi-echelle (petit/gros)."""
    img = rng.normal(0, 0.08, (IMG, IMG)).astype(np.float32)
    yy, xx = np.mgrid[0:IMG, 0:IMG]

    # fond : blobs lents (repris du 4.2c/g)
    for _ in range(rng.integers(2, 5)):
        cy, cx = rng.integers(0, IMG, 2)
        s = rng.uniform(18, 50)
        img += 0.10 * rng.uniform(0.6, 1.3) * np.exp(
            -(((yy - cy) ** 2 + (xx - cx) ** 2) / (2 * s * s)))

    boxes, kinds = [], []
    for _ in range(rng.integers(1, 5)):        # 1 a 4 objets
        # multi-echelle : 40% petit (8-18 px), 60% gros (30-60 px)
        if rng.uniform() < 0.40:
            w = int(rng.uniform(8, 18))
        else:
            w = int(rng.uniform(30, 60))
        h = int(max(6, min(60, w * rng.uniform(0.5, 2.0))))
        kind = rng.choice(["rect", "ellipse"])
        kinds.append(kind)
        for _try in range(40):
            x0 = int(rng.integers(2, IMG - w - 2))
            y0 = int(rng.integers(2, IMG - h - 2))
            cand = (x0, y0, w, h)
            if all(iou_np(cand, b) < 0.30 for b in boxes):
                boxes.append(cand)
                break

    for (x0, y0, w, h) in boxes:
        amp = rng.uniform(0.7, 1.2)
        if kind == "rect":
            img[y0:y0 + h, x0:x0 + w] += amp
        else:
            sub = img[y0:y0 + h, x0:x0 + w]
            ey, ex = np.mgrid[0:h, 0:w]
            mask = (((ex - w / 2) / (w / 2)) ** 2
                    + ((ey - h / 2) / (h / 2)) ** 2) <= 1.0
            img[y0:y0 + h, x0:x0 + w] = np.where(mask, sub + amp, sub)

    # stresseur 1 : 30% occlusions par grand rectangle sombre
    if rng.uniform() < 0.30 and len(boxes) > 0:
        oc_w = int(rng.uniform(0.35, 0.60) * IMG)
        oc_h = int(rng.uniform(0.25, 0.50) * IMG)
        oc_x = int(rng.integers(0, IMG - oc_w))
        oc_y = int(rng.integers(0, IMG - oc_h))
        img[oc_y:oc_y + oc_h, oc_x:oc_x + oc_w] -= rng.uniform(0.5, 0.9)

    return np.clip(img, -1.5, 2.5), boxes


def make_split(n, seed):
    rng = np.random.default_rng(seed)
    xs, bs = [], []
    for _ in range(n):
        img, boxes = make_difficult_image(rng)
        xs.append(img)
        bs.append(torch.tensor(boxes, dtype=torch.float32))
    return torch.tensor(np.stack(xs)).unsqueeze(1), bs


N_TRAIN, N_VAL = 600, 200
Xtr, Btr = make_split(N_TRAIN, SEED + 1)
Xva, Bva = make_split(N_VAL, SEED + 2)

n_petit = sum(1 for b in Bva for (x0, y0, w, h) in [tuple(bb) for bb in b.tolist()] if w < 25)
n_gros = sum(1 for b in Bva for (x0, y0, w, h) in [tuple(bb) for bb in b.tolist()] if w >= 25)
print("train:", tuple(Xtr.shape), "| val:", tuple(Xva.shape),
      "| GT val:", sum(len(b) for b in Bva),
      f"| repartition taille: {n_petit} petits (<25px), {n_gros} gros (>=25px)")
# Out:
# train: (600, 1, 96, 96) | val: (200, 1, 96, 96) | GT val: 502 | repartition taille: 224 petits (<25px), 278 gros (>=25px)

# %% [markdown]
# ## 4. Format YOLO et dataset
#
# Même format que 4.2g : images PNG + fichiers `.txt` par image, une ligne par objet `class cx cy w h` (normalisé 0-1).

# %%
import tempfile
DS = Path(tempfile.mkdtemp(prefix="terrain_yolo_diff_"))


def write_yolo_split(X, B, split):
    (DS / "images" / split).mkdir(parents=True, exist_ok=True)
    (DS / "labels" / split).mkdir(parents=True, exist_ok=True)
    for i, (img, boxes) in enumerate(zip(X, B)):
        u8 = (((img - img.min()) / (img.max() - img.min() + 1e-6)) * 255).astype(np.uint8)
        cv2.imwrite(str(DS / "images" / split / f"{i:05d}.png"), u8)
        lines = [f"0 {(x0 + w / 2) / IMG} {(y0 + h / 2) / IMG} {w / IMG} {h / IMG}"
                 for (x0, y0, w, h) in boxes]
        (DS / "labels" / split / f"{i:05d}.txt").write_text(
            "\n".join(lines), encoding="utf-8")


write_yolo_split([x[0].numpy() for x in Xtr], [b.tolist() for b in Btr], "train")
write_yolo_split([x[0].numpy() for x in Xva], [b.tolist() for b in Bva], "val")
(DS / "data.yaml").write_text(
    f"path: {DS.as_posix()}\ntrain: images/train\nval: images/val\nnc: 1\nnames: ['objet']\n",
    encoding="utf-8")

# Dossier dedie inference : on sauve les memes images val en PNG pour les predictions (paths)
INFER_DIR = DS / "inference_val"
INFER_DIR.mkdir(parents=True, exist_ok=True)
for i, img in enumerate(Xva[:, 0].numpy()):
    u8 = (((img - img.min()) / (img.max() - img.min() + 1e-6)) * 255).astype(np.uint8)
    cv2.imwrite(str(INFER_DIR / f"val_{i:05d}.png"), u8)

n_tr = len(list((DS / "images" / "train").glob("*.png")))
n_va = len(list((DS / "images" / "val").glob("*.png")))
n_infer = len(list(INFER_DIR.glob("*.png")))
print(f"dataset YOLO difficile : {n_tr} train / {n_va} val, "
      f"{sum(len(b) for b in Bva)} GT val, "
      f"1 classe, occlusions + multi-echelle, "
      f"{n_infer} images inference (paths) sur disque")
# Out:
# dataset YOLO difficile : 600 train / 200 val, 502 GT val, 1 classe, occlusions + multi-echelle, 200 images inference (paths) sur disque

# %% [markdown]
# ## 5. Fine-tuning des trois modèles
#
# Budget réduit (vs 4.2g : 1000 imgs × 6 epochs) pour tenir dans la fenêtre cron worker :
#
# - **600 images train × 4 époques** = 2400 itérations par modèle
# - **imgsz=96** (multiple de 32, comme 4.2g)
# - **workers=0** (Windows, pas de DataLoader parallèle)
# - **device=0** (GPU unique)
# - **batch=16** (par défaut ultralytics)
#
# Trois modèles à comparer :
# - `yolov5nu.pt` (YOLOv5 nano, anchor-based)
# - `yolov8s.pt` (YOLOv8 small, anchor-free, C2f)
# - `yolo11m.pt` (YOLO11 medium, anchor-free, C3k2)

# %%
EPOCHS = 4
IMGSZ = IMG
BATCH = 16
MODELS = ["yolov5nu.pt", "yolov8s.pt", "yolo11m.pt"]

print("budget commun 4.2i :", N_TRAIN, "images x", EPOCHS, "epoques,"
      "imgsz", IMGSZ, "batch", BATCH)
print("modeles compares :", MODELS)
# Out:
# budget commun 4.2i : 600 images x 4 epoques,imgsz 96 batch 16
# modeles compares : ['yolov5nu.pt', 'yolov8s.pt', 'yolo11m.pt']

# %%
import contextlib, io

TRAINED = {}
TRAIN_TIMES = {}

for tag in MODELS:
    name = tag.replace(".pt", "")
    print(f"\n=== {name} : fine-tuning ===")
    model = YOLO(tag)
    _buf = io.StringIO()
    t0 = time.time()
    with contextlib.redirect_stdout(_buf), contextlib.redirect_stderr(_buf):
        model.train(
            data=str(DS / "data.yaml"),
            epochs=EPOCHS,
            imgsz=IMGSZ,
            batch=BATCH,
            device=DEVICE,
            workers=0,
            verbose=False,
            project=str(DS / "runs"),
            name=name,
            exist_ok=True,
        )
    dt = time.time() - t0
    TRAIN_TIMES[name] = dt
    TRAINED[name] = YOLO(str(DS / "runs" / name / "weights" / "best.pt"))
    n_params = sum(p.numel() for p in TRAINED[name].model.parameters()) / 1e6
    print(f"  fine-tune OK en {dt:.1f}s, {n_params:.2f}M params")
# Out:
# === yolov5nu : fine-tuning ===
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 2% ──────────── 144.0KB/5.3MB 1.3MB/s 0.1s<4.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 3% ──────────── 208.0KB/5.3MB 183.4KB/s 0.2s<28.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 4% ╸─────────── 240.0KB/5.3MB 200.2KB/s 0.3s<25.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 5% ╸─────────── 272.0KB/5.3MB 221.1KB/s 0.5s<23.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 6% ╸─────────── 352.0KB/5.3MB 366.6KB/s 0.6s<13.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 8% ━─────────── 464.0KB/5.3MB 521.5KB/s 0.7s<9.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 9% ━─────────── 528.0KB/5.3MB 540.0KB/s 0.8s<9.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 11% ━─────────── 608.0KB/5.3MB 603.1KB/s 0.9s<8.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 13% ━╸────────── 736.0KB/5.3MB 1.2MB/s 1.0s<3.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 15% ━╸────────── 816.0KB/5.3MB 655.8KB/s 1.1s<7.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 17% ━━────────── 928.0KB/5.3MB 1.1MB/s 1.2s<4.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 18% ━━────────── 1008.0KB/5.3MB 637.7KB/s 1.4s<6.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 19% ━━────────── 1.0/5.3MB 585.9KB/s 1.5s<7.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 21% ━━╸───────── 1.1/5.3MB 668.1KB/s 1.6s<6.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 22% ━━╸───────── 1.2/5.3MB 698.2KB/s 1.7s<6.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 25% ━━━───────── 1.3/5.3MB 1.1MB/s 1.8s<3.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 26% ━━━───────── 1.4/5.3MB 709.0KB/s 1.9s<5.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 27% ━━━───────── 1.5/5.3MB 687.0KB/s 2.0s<5.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 29% ━━━╸──────── 1.6/5.3MB 1003.9KB/s 2.1s<3.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 30% ━━━╸──────── 1.6/5.3MB 645.9KB/s 2.2s<5.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 32% ━━━╸──────── 1.7/5.3MB 688.3KB/s 2.3s<5.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 33% ━━━━──────── 1.8/5.3MB 664.5KB/s 2.5s<5.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 34% ━━━━──────── 1.8/5.3MB 570.4KB/s 2.6s<6.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 35% ━━━━──────── 1.9/5.3MB 587.5KB/s 2.7s<6.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 37% ━━━━──────── 2.0/5.3MB 685.6KB/s 2.8s<5.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 39% ━━━━╸─────── 2.1/5.3MB 743.3KB/s 2.9s<4.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 41% ━━━━╸─────── 2.2/5.3MB 797.5KB/s 3.0s<4.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 42% ━━━━━─────── 2.3/5.3MB 780.2KB/s 3.1s<4.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 45% ━━━━━─────── 2.4/5.3MB 1.3MB/s 3.2s<2.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 47% ━━━━━╸────── 2.5/5.3MB 781.1KB/s 3.4s<3.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 48% ━━━━━╸────── 2.6/5.3MB 730.7KB/s 3.5s<3.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 50% ━━━━━━────── 2.7/5.3MB 761.2KB/s 3.6s<3.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 51% ━━━━━━────── 2.7/5.3MB 677.2KB/s 3.7s<3.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 52% ━━━━━━────── 2.8/5.3MB 661.2KB/s 3.8s<3.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 53% ━━━━━━────── 2.9/5.3MB 699.7KB/s 3.9s<3.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 56% ━━━━━━╸───── 3.0/5.3MB 1.0MB/s 4.0s<2.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 58% ━━━━━━╸───── 3.1/5.3MB 761.2KB/s 4.1s<3.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 59% ━━━━━━━───── 3.2/5.3MB 793.9KB/s 4.3s<2.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 61% ━━━━━━━───── 3.3/5.3MB 1.0MB/s 4.4s<1.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 63% ━━━━━━━╸──── 3.4/5.3MB 792.7KB/s 4.5s<2.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 65% ━━━━━━━╸──── 3.5/5.3MB 810.4KB/s 4.6s<2.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 67% ━━━━━━━━──── 3.6/5.3MB 830.0KB/s 4.7s<2.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 68% ━━━━━━━━──── 3.7/5.3MB 861.0KB/s 4.8s<2.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 70% ━━━━━━━━──── 3.7/5.3MB 791.7KB/s 4.9s<2.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 71% ━━━━━━━━╸─── 3.8/5.3MB 651.2KB/s 5.1s<2.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 73% ━━━━━━━━╸─── 3.9/5.3MB 722.3KB/s 5.2s<2.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 75% ━━━━━━━━━─── 4.0/5.3MB 1.1MB/s 5.3s<1.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 76% ━━━━━━━━━─── 4.0/5.3MB 693.9KB/s 5.4s<1.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 77% ━━━━━━━━━─── 4.1/5.3MB 716.0KB/s 5.5s<1.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 80% ━━━━━━━━━╸── 4.2/5.3MB 1.1MB/s 5.6s<0.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 83% ━━━━━━━━━╸── 4.4/5.3MB 1.4MB/s 5.7s<0.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 84% ━━━━━━━━━━── 4.5/5.3MB 725.9KB/s 5.8s<1.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 86% ━━━━━━━━━━── 4.6/5.3MB 1.2MB/s 5.9s<0.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 88% ━━━━━━━━━━╸─ 4.7/5.3MB 747.3KB/s 6.0s<0.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 90% ━━━━━━━━━━╸─ 4.8/5.3MB 808.0KB/s 6.1s<0.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 92% ━━━━━━━━━━━─ 4.9/5.3MB 1.1MB/s 6.2s<0.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 93% ━━━━━━━━━━━─ 5.0/5.3MB 789.7KB/s 6.3s<0.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 93% ━━━━━━━━━━━─ 5.0/5.3MB 593.5KB/s 6.5s<0.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 94% ━━━━━━━━━━━─ 5.0/5.3MB 509.5KB/s 6.6s<0.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 94% ━━━━━━━━━━━─ 5.0/5.3MB 373.9KB/s 6.8s<0.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 96% ━━━━━━━━━━━╸ 5.1/5.3MB 480.3KB/s 7.0s<0.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 98% ━━━━━━━━━━━╸ 5.2/5.3MB 1.1MB/s 7.1s<0.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 100% ━━━━━━━━━━━━ 5.3MB 762.1KB/s 7.1s
# New https://pypi.org/project/ultralytics/8.4.156 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.155  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=4, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=96, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5nu.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov5nu, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov5nu, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=1
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  ultralytics.nn.modules.conv.Conv             [3, 16, 6, 2, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      4800  ultralytics.nn.modules.block.C3              [32, 32, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     29184  ultralytics.nn.modules.block.C3              [64, 64, 2]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  14                  -1  1      8320  ultralytics.nn.modules.conv.Conv             [128, 64, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     22912  ultralytics.nn.modules.block.C3              [128, 64, 1, False]
#  18                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1     74496  ultralytics.nn.modules.block.C3              [128, 128, 1, False]
#  21                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  24        [17, 20, 23]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# YOLOv5n summary: 153 layers, 2,508,659 parameters, 2,508,643 gradients, 7.2 GFLOPs
# Transferred 391/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# AMP: checks passed
# WARNING train: Slow image access detected (ping: 0.10.0 ms, read: 0.80.1 MB/s, size: 6.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# train: New cache created: C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\labels\train.cache
# WARNING val: Slow image access detected (ping: 0.10.0 ms, read: 0.80.1 MB/s, size: 7.2 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: New cache created: C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\labels\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0005), 75 bias(decay=0.0)
# Plotting labels to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov5nu\labels.jpg...
# Using 600 train, 200 val images for fraction=1.0 at imgsz=96
# Using 0 dataloader workers
# Logging results to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov5nu
# Starting training for 4 epochs...
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.773      0.382      0.596      0.363
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.858      0.827      0.885      0.583
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.874      0.897      0.938      0.665
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502       0.92      0.892      0.963      0.719
# 4 epochs completed in 0.007 hours.
# Optimizer stripped from C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov5nu\weights\last.pt, 5.2MB
# Optimizer stripped from C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov5nu\weights\best.pt, 5.2MB
# Validating C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov5nu\weights\best.pt...
# Ultralytics 8.4.155  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLOv5n summary (fused): 84 layers, 2,503,139 parameters, 0 gradients, 7.1 GFLOPs
#                    all        200        502      0.922      0.893      0.963       0.72
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov5nu
#   fine-tune OK en 44.9s, 2.51M params
#
# === yolov8s : fine-tuning ===
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 1% ──────────── 308.8KB/21.5MB 2.7MB/s 0.1s<7.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 2% ──────────── 507.3KB/21.5MB 1.8MB/s 0.2s<11.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 2% ──────────── 617.6KB/21.5MB 284.4KB/s 0.3s<1:15
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 3% ──────────── 705.9KB/21.5MB 415.3KB/s 0.5s<51.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 3% ──────────── 816.2KB/21.5MB 557.4KB/s 0.6s<38.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 4% ──────────── 904.4KB/21.5MB 592.6KB/s 0.7s<35.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 4% ╸─────────── 970.6KB/21.5MB 596.1KB/s 0.8s<35.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 4% ╸─────────── 1.0/21.5MB 653.8KB/s 0.9s<32.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 5% ╸─────────── 1.1/21.5MB 613.4KB/s 1.1s<34.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 5% ╸─────────── 1.2/21.5MB 1.1MB/s 1.2s<19.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 6% ╸─────────── 1.3/21.5MB 694.1KB/s 1.3s<29.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 6% ╸─────────── 1.4/21.5MB 1.2MB/s 1.4s<16.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 7% ╸─────────── 1.6/21.5MB 762.2KB/s 1.5s<26.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 7% ╸─────────── 1.7/21.5MB 976.9KB/s 1.6s<20.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 8% ╸─────────── 1.7/21.5MB 731.4KB/s 1.8s<27.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 8% ━─────────── 1.8/21.5MB 688.0KB/s 1.9s<29.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 8% ━─────────── 1.9/21.5MB 729.9KB/s 2.0s<27.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 9% ━─────────── 2.0/21.5MB 704.5KB/s 2.1s<28.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 9% ━─────────── 2.1/21.5MB 1.1MB/s 2.2s<17.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 10% ━─────────── 2.2/21.5MB 743.0KB/s 2.3s<26.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 10% ━─────────── 2.3/21.5MB 721.5KB/s 2.5s<27.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 10% ━─────────── 2.3/21.5MB 679.9KB/s 2.6s<28.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 11% ━─────────── 2.4/21.5MB 730.1KB/s 2.7s<26.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 11% ━─────────── 2.5/21.5MB 640.9KB/s 2.8s<30.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 11% ━─────────── 2.5/21.5MB 611.7KB/s 2.9s<31.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 11% ━─────────── 2.6/21.5MB 558.6KB/s 3.0s<34.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 12% ━─────────── 2.7/21.5MB 621.7KB/s 3.1s<31.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 12% ━╸────────── 2.7/21.5MB 608.8KB/s 3.2s<31.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 12% ━╸────────── 2.8/21.5MB 576.9KB/s 3.4s<33.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 13% ━╸────────── 2.9/21.5MB 623.8KB/s 3.5s<30.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 13% ━╸────────── 3.0/21.5MB 672.2KB/s 3.6s<28.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 14% ━╸────────── 3.1/21.5MB 724.2KB/s 3.7s<26.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 14% ━╸────────── 3.1/21.5MB 700.2KB/s 3.8s<26.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 14% ━╸────────── 3.2/21.5MB 753.6KB/s 3.9s<24.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 15% ━╸────────── 3.3/21.5MB 708.2KB/s 4.0s<26.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 15% ━╸────────── 3.4/21.5MB 1011.3KB/s 4.1s<18.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 16% ━╸────────── 3.5/21.5MB 1.2MB/s 4.2s<14.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 16% ━╸────────── 3.6/21.5MB 691.3KB/s 4.3s<26.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 16% ━━────────── 3.6/21.5MB 614.0KB/s 4.4s<29.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 16% ━━────────── 3.7/21.5MB 531.4KB/s 4.6s<34.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 17% ━━────────── 3.7/21.5MB 510.8KB/s 4.7s<35.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 17% ━━────────── 3.8/21.5MB 1.0MB/s 4.8s<17.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 18% ━━────────── 3.9/21.5MB 605.6KB/s 4.9s<29.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 18% ━━────────── 4.0/21.5MB 590.4KB/s 5.0s<30.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 18% ━━────────── 4.1/21.5MB 624.5KB/s 5.2s<28.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 19% ━━────────── 4.2/21.5MB 709.1KB/s 5.3s<25.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 19% ━━────────── 4.2/21.5MB 683.0KB/s 5.4s<25.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 19% ━━────────── 4.3/21.5MB 628.2KB/s 5.5s<28.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 20% ━━────────── 4.4/21.5MB 694.8KB/s 5.6s<25.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 21% ━━╸───────── 4.5/21.5MB 1.3MB/s 5.7s<12.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 21% ━━╸───────── 4.7/21.5MB 1.3MB/s 5.8s<13.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 21% ━━╸───────── 4.7/21.5MB 673.3KB/s 5.9s<25.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 22% ━━╸───────── 4.8/21.5MB 663.4KB/s 6.1s<25.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 22% ━━╸───────── 4.9/21.5MB 603.3KB/s 6.2s<28.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 23% ━━╸───────── 5.0/21.5MB 616.7KB/s 6.4s<27.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 23% ━━╸───────── 5.0/21.5MB 625.8KB/s 6.5s<27.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 23% ━━╸───────── 5.1/21.5MB 650.6KB/s 6.6s<25.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 24% ━━╸───────── 5.2/21.5MB 692.0KB/s 6.7s<24.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 24% ━━╸───────── 5.3/21.5MB 979.8KB/s 6.8s<17.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 25% ━━━───────── 5.4/21.5MB 716.7KB/s 6.9s<23.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 25% ━━━───────── 5.5/21.5MB 676.2KB/s 7.1s<24.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 25% ━━━───────── 5.6/21.5MB 702.8KB/s 7.2s<23.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 26% ━━━───────── 5.6/21.5MB 598.3KB/s 7.3s<27.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 26% ━━━───────── 5.7/21.5MB 626.4KB/s 7.4s<25.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 27% ━━━───────── 5.8/21.5MB 1.2MB/s 7.6s<12.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 27% ━━━───────── 5.9/21.5MB 1013.4KB/s 7.7s<15.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 27% ━━━───────── 6.0/21.5MB 593.9KB/s 7.8s<26.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 28% ━━━───────── 6.1/21.5MB 595.1KB/s 7.9s<26.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 28% ━━━───────── 6.1/21.5MB 505.5KB/s 8.0s<31.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 28% ━━━───────── 6.2/21.5MB 442.8KB/s 8.2s<35.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 28% ━━━───────── 6.2/21.5MB 482.2KB/s 8.3s<32.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 29% ━━━╸──────── 6.3/21.5MB 541.4KB/s 8.5s<28.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 29% ━━━╸──────── 6.4/21.5MB 520.5KB/s 8.6s<29.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 29% ━━━╸──────── 6.5/21.5MB 480.4KB/s 8.8s<32.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 30% ━━━╸──────── 6.5/21.5MB 461.4KB/s 8.9s<33.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 30% ━━━╸──────── 6.7/21.5MB 1.5MB/s 9.0s<10.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 31% ━━━╸──────── 6.8/21.5MB 1.5MB/s 9.1s<9.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 32% ━━━╸──────── 6.9/21.5MB 1004.5KB/s 9.2s<14.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 32% ━━━╸──────── 7.0/21.5MB 483.9KB/s 9.3s<30.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 32% ━━━╸──────── 7.0/21.5MB 522.4KB/s 9.4s<28.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 32% ━━━╸──────── 7.1/21.5MB 529.7KB/s 9.6s<27.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 33% ━━━╸──────── 7.2/21.5MB 471.9KB/s 9.7s<31.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 33% ━━━━──────── 7.2/21.5MB 455.3KB/s 9.8s<32.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 33% ━━━━──────── 7.3/21.5MB 552.4KB/s 9.9s<26.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 34% ━━━━──────── 7.4/21.5MB 601.4KB/s 10.0s<24.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 34% ━━━━──────── 7.4/21.5MB 589.6KB/s 10.1s<24.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 34% ━━━━──────── 7.5/21.5MB 680.6KB/s 10.3s<21.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 35% ━━━━──────── 7.6/21.5MB 671.1KB/s 10.4s<21.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 35% ━━━━──────── 7.7/21.5MB 697.9KB/s 10.5s<20.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 35% ━━━━──────── 7.8/21.5MB 675.6KB/s 10.6s<20.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 36% ━━━━──────── 7.8/21.5MB 626.9KB/s 10.7s<22.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 36% ━━━━──────── 7.9/21.5MB 614.0KB/s 10.8s<22.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 36% ━━━━──────── 8.0/21.5MB 643.7KB/s 11.0s<21.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 37% ━━━━──────── 8.1/21.5MB 636.0KB/s 11.1s<21.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 38% ━━━━╸─────── 8.2/21.5MB 1.4MB/s 11.2s<9.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 38% ━━━━╸─────── 8.4/21.5MB 1.3MB/s 11.3s<10.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 38% ━━━━╸─────── 8.4/21.5MB 563.6KB/s 11.4s<23.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 39% ━━━━╸─────── 8.4/21.5MB 524.3KB/s 11.5s<25.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 39% ━━━━╸─────── 8.6/21.5MB 654.0KB/s 11.7s<20.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 40% ━━━━╸─────── 8.6/21.5MB 714.3KB/s 11.8s<18.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 40% ━━━━╸─────── 8.8/21.5MB 1.3MB/s 11.9s<10.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 41% ━━━━╸─────── 8.9/21.5MB 787.0KB/s 12.0s<16.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 41% ━━━━━─────── 9.0/21.5MB 1.0MB/s 12.1s<12.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 42% ━━━━━─────── 9.1/21.5MB 746.5KB/s 12.2s<17.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 42% ━━━━━─────── 9.2/21.5MB 786.2KB/s 12.3s<16.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 42% ━━━━━─────── 9.3/21.5MB 802.3KB/s 12.4s<15.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 43% ━━━━━─────── 9.3/21.5MB 761.0KB/s 12.6s<16.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 43% ━━━━━─────── 9.4/21.5MB 758.9KB/s 12.7s<16.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 43% ━━━━━─────── 9.5/21.5MB 651.3KB/s 12.8s<19.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 44% ━━━━━─────── 9.5/21.5MB 564.5KB/s 12.9s<21.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 44% ━━━━━─────── 9.6/21.5MB 982.2KB/s 13.0s<12.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 44% ━━━━━─────── 9.7/21.5MB 561.0KB/s 13.1s<21.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 45% ━━━━━─────── 9.8/21.5MB 1.1MB/s 13.3s<10.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 45% ━━━━━╸────── 9.9/21.5MB 626.5KB/s 13.4s<19.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 46% ━━━━━╸────── 10.0/21.5MB 522.0KB/s 13.5s<22.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 46% ━━━━━╸────── 10.0/21.5MB 423.9KB/s 13.6s<27.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 46% ━━━━━╸────── 10.0/21.5MB 422.5KB/s 13.7s<27.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 46% ━━━━━╸────── 10.1/21.5MB 405.7KB/s 13.9s<29.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 46% ━━━━━╸────── 10.1/21.5MB 402.4KB/s 14.0s<29.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 47% ━━━━━╸────── 10.2/21.5MB 542.5KB/s 14.1s<21.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 47% ━━━━━╸────── 10.3/21.5MB 568.6KB/s 14.2s<20.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 48% ━━━━━╸────── 10.4/21.5MB 637.4KB/s 14.3s<18.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 48% ━━━━━╸────── 10.4/21.5MB 653.6KB/s 14.5s<17.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 48% ━━━━━╸────── 10.5/21.5MB 681.1KB/s 14.6s<16.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 49% ━━━━━╸────── 10.6/21.5MB 655.8KB/s 14.7s<17.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 49% ━━━━━╸────── 10.6/21.5MB 589.5KB/s 14.8s<18.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 49% ━━━━━╸────── 10.7/21.5MB 702.5KB/s 14.9s<15.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 50% ━━━━━━────── 10.8/21.5MB 709.3KB/s 15.0s<15.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 50% ━━━━━━────── 10.9/21.5MB 760.5KB/s 15.2s<14.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 51% ━━━━━━────── 11.1/21.5MB 771.3KB/s 15.3s<13.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 51% ━━━━━━────── 11.1/21.5MB 634.6KB/s 15.4s<16.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 51% ━━━━━━────── 11.2/21.5MB 697.5KB/s 15.5s<15.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 52% ━━━━━━────── 11.3/21.5MB 682.7KB/s 15.7s<15.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 52% ━━━━━━────── 11.3/21.5MB 640.1KB/s 15.8s<16.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 52% ━━━━━━────── 11.4/21.5MB 609.8KB/s 15.9s<17.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 53% ━━━━━━────── 11.5/21.5MB 665.5KB/s 16.0s<15.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 53% ━━━━━━────── 11.6/21.5MB 1.1MB/s 16.1s<9.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 54% ━━━━━━╸───── 11.7/21.5MB 733.6KB/s 16.3s<13.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 54% ━━━━━━╸───── 11.8/21.5MB 673.2KB/s 16.4s<14.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 54% ━━━━━━╸───── 11.8/21.5MB 635.1KB/s 16.5s<15.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 55% ━━━━━━╸───── 11.9/21.5MB 572.6KB/s 16.6s<17.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 55% ━━━━━━╸───── 12.0/21.5MB 649.9KB/s 16.7s<15.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 55% ━━━━━━╸───── 12.0/21.5MB 697.2KB/s 16.8s<14.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 56% ━━━━━━╸───── 12.1/21.5MB 612.0KB/s 16.9s<15.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 56% ━━━━━━╸───── 12.1/21.5MB 594.5KB/s 17.0s<16.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 56% ━━━━━━╸───── 12.2/21.5MB 515.4KB/s 17.2s<18.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 56% ━━━━━━╸───── 12.3/21.5MB 607.8KB/s 17.3s<15.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 57% ━━━━━━╸───── 12.4/21.5MB 618.9KB/s 17.4s<15.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 57% ━━━━━━╸───── 12.4/21.5MB 589.1KB/s 17.5s<15.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 57% ━━━━━━╸───── 12.5/21.5MB 507.2KB/s 17.7s<18.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 58% ━━━━━━╸───── 12.6/21.5MB 582.8KB/s 17.8s<15.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 58% ━━━━━━━───── 12.6/21.5MB 660.6KB/s 17.9s<13.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 58% ━━━━━━━───── 12.7/21.5MB 617.5KB/s 18.0s<14.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 59% ━━━━━━━───── 12.8/21.5MB 611.9KB/s 18.1s<14.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 59% ━━━━━━━───── 12.8/21.5MB 568.3KB/s 18.3s<15.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 59% ━━━━━━━───── 12.9/21.5MB 493.8KB/s 18.4s<18.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 60% ━━━━━━━───── 12.9/21.5MB 533.8KB/s 18.5s<16.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 60% ━━━━━━━───── 13.0/21.5MB 561.3KB/s 18.6s<15.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 60% ━━━━━━━───── 13.1/21.5MB 545.9KB/s 18.8s<15.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 60% ━━━━━━━───── 13.1/21.5MB 561.2KB/s 18.9s<15.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 61% ━━━━━━━───── 13.2/21.5MB 562.4KB/s 19.0s<15.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 61% ━━━━━━━───── 13.3/21.5MB 618.5KB/s 19.1s<13.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 62% ━━━━━━━───── 13.4/21.5MB 576.6KB/s 19.3s<14.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 62% ━━━━━━━───── 13.4/21.5MB 600.1KB/s 19.4s<13.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 62% ━━━━━━━╸──── 13.5/21.5MB 1.1MB/s 19.5s<7.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 63% ━━━━━━━╸──── 13.7/21.5MB 1.2MB/s 19.6s<6.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 63% ━━━━━━━╸──── 13.8/21.5MB 591.1KB/s 19.7s<13.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 63% ━━━━━━━╸──── 13.8/21.5MB 479.6KB/s 19.8s<16.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 64% ━━━━━━━╸──── 13.9/21.5MB 540.0KB/s 20.0s<14.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 64% ━━━━━━━╸──── 14.0/21.5MB 570.4KB/s 20.1s<13.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 65% ━━━━━━━╸──── 14.0/21.5MB 648.6KB/s 20.2s<11.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 65% ━━━━━━━╸──── 14.1/21.5MB 666.6KB/s 20.3s<11.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 65% ━━━━━━━╸──── 14.2/21.5MB 635.5KB/s 20.5s<11.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 66% ━━━━━━━╸──── 14.2/21.5MB 557.5KB/s 20.6s<13.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 66% ━━━━━━━╸──── 14.3/21.5MB 480.4KB/s 20.7s<15.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 66% ━━━━━━━╸──── 14.3/21.5MB 490.2KB/s 20.8s<15.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 66% ━━━━━━━━──── 14.4/21.5MB 587.5KB/s 21.0s<12.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 67% ━━━━━━━━──── 14.6/21.5MB 1.2MB/s 21.1s<5.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 68% ━━━━━━━━──── 14.7/21.5MB 620.5KB/s 21.3s<11.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 68% ━━━━━━━━──── 14.7/21.5MB 540.3KB/s 21.4s<12.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 68% ━━━━━━━━──── 14.8/21.5MB 562.7KB/s 21.5s<12.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 69% ━━━━━━━━──── 14.9/21.5MB 640.5KB/s 21.6s<10.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 69% ━━━━━━━━──── 15.0/21.5MB 986.0KB/s 21.7s<6.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 69% ━━━━━━━━──── 15.1/21.5MB 593.3KB/s 21.8s<11.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 70% ━━━━━━━━──── 15.1/21.5MB 622.1KB/s 22.0s<10.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 70% ━━━━━━━━──── 15.3/21.5MB 686.1KB/s 22.1s<9.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 71% ━━━━━━━━╸─── 15.4/21.5MB 756.8KB/s 22.2s<8.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 71% ━━━━━━━━╸─── 15.4/21.5MB 649.3KB/s 22.4s<9.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 72% ━━━━━━━━╸─── 15.5/21.5MB 703.6KB/s 22.5s<8.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 72% ━━━━━━━━╸─── 15.6/21.5MB 675.9KB/s 22.6s<9.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 72% ━━━━━━━━╸─── 15.7/21.5MB 670.8KB/s 22.7s<9.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 72% ━━━━━━━━╸─── 15.7/21.5MB 578.7KB/s 22.8s<10.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 73% ━━━━━━━━╸─── 15.8/21.5MB 1.1MB/s 23.0s<5.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 73% ━━━━━━━━╸─── 15.9/21.5MB 557.7KB/s 23.1s<10.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 74% ━━━━━━━━╸─── 16.0/21.5MB 645.3KB/s 23.2s<8.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 74% ━━━━━━━━╸─── 16.1/21.5MB 722.8KB/s 23.3s<7.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 74% ━━━━━━━━╸─── 16.1/21.5MB 685.2KB/s 23.4s<8.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 75% ━━━━━━━━━─── 16.2/21.5MB 650.2KB/s 23.5s<8.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 75% ━━━━━━━━━─── 16.3/21.5MB 675.0KB/s 23.7s<8.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 75% ━━━━━━━━━─── 16.4/21.5MB 694.0KB/s 23.8s<7.6s
# ...
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 145.951.0 MB/s, size: 7.0 KB)
# val: Fast image access  (ping: 0.00.0 ms, read: 152.943.4 MB/s, size: 7.1 KB)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov8s\labels.jpg...
# Using 600 train, 200 val images for fraction=1.0 at imgsz=96
# Using 0 dataloader workers
# Logging results to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov8s
# Starting training for 4 epochs...
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.874      0.833      0.921      0.706
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.754      0.929      0.915      0.731
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.924      0.917      0.971      0.779
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.964      0.956      0.981      0.828
# 4 epochs completed in 0.007 hours.
# Optimizer stripped from C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov8s\weights\last.pt, 22.5MB
# Optimizer stripped from C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov8s\weights\best.pt, 22.5MB
# Validating C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov8s\weights\best.pt...
# Ultralytics 8.4.155  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                    all        200        502      0.975      0.944      0.981      0.827
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolov8s
#   fine-tune OK en 31.2s, 11.14M params
#
# === yolo11m : fine-tuning ===
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 1% ──────────── 675.4KB/38.8MB 5.9MB/s 0.1s<6.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 5% ╸─────────── 2.1/38.8MB 13.9MB/s 0.2s<2.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 8% ╸─────────── 3.2/38.8MB 11.2MB/s 0.3s<3.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 11% ━─────────── 4.4/38.8MB 11.3MB/s 0.4s<3.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 14% ━╸────────── 5.5/38.8MB 11.3MB/s 0.5s<2.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 17% ━━────────── 6.7/38.8MB 11.3MB/s 0.6s<2.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 20% ━━────────── 7.8/38.8MB 11.2MB/s 0.7s<2.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 23% ━━╸───────── 9.0/38.8MB 11.2MB/s 0.8s<2.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 26% ━━━───────── 10.2/38.8MB 11.4MB/s 0.9s<2.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 29% ━━━───────── 11.3/38.8MB 11.1MB/s 1.0s<2.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 32% ━━━╸──────── 12.5/38.8MB 11.4MB/s 1.1s<2.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 34% ━━━━──────── 13.6/38.8MB 11.2MB/s 1.2s<2.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 37% ━━━━╸─────── 14.7/38.8MB 11.0MB/s 1.3s<2.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 40% ━━━━╸─────── 15.9/38.8MB 11.2MB/s 1.4s<2.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 43% ━━━━━─────── 17.0/38.8MB 11.1MB/s 1.5s<2.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 46% ━━━━━╸────── 18.2/38.8MB 11.3MB/s 1.6s<1.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 49% ━━━━━╸────── 19.3/38.8MB 10.5MB/s 1.8s<1.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 52% ━━━━━━────── 20.3/38.8MB 9.9MB/s 1.9s<1.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 55% ━━━━━━╸───── 21.5/38.8MB 11.4MB/s 2.0s<1.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 57% ━━━━━━╸───── 22.5/38.8MB 10.1MB/s 2.1s<1.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 60% ━━━━━━━───── 23.6/38.8MB 11.2MB/s 2.2s<1.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 63% ━━━━━━━╸──── 24.8/38.8MB 11.2MB/s 2.3s<1.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 66% ━━━━━━━━──── 25.9/38.8MB 11.4MB/s 2.4s<1.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 69% ━━━━━━━━──── 27.0/38.8MB 10.8MB/s 2.5s<1.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 72% ━━━━━━━━╸─── 28.2/38.8MB 11.3MB/s 2.6s<0.9s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 75% ━━━━━━━━━─── 29.3/38.8MB 11.2MB/s 2.7s<0.8s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 78% ━━━━━━━━━─── 30.5/38.8MB 11.4MB/s 2.8s<0.7s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 81% ━━━━━━━━━╸── 31.7/38.8MB 11.2MB/s 2.9s<0.6s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 84% ━━━━━━━━━━── 32.8/38.8MB 11.4MB/s 3.0s<0.5s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 87% ━━━━━━━━━━╸─ 34.0/38.8MB 11.1MB/s 3.1s<0.4s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 90% ━━━━━━━━━━╸─ 35.2/38.8MB 11.3MB/s 3.2s<0.3s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 93% ━━━━━━━━━━━─ 36.3/38.8MB 11.3MB/s 3.3s<0.2s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 96% ━━━━━━━━━━━╸ 37.4/38.8MB 11.1MB/s 3.4s<0.1s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 99% ━━━━━━━━━━━╸ 38.6/38.8MB 11.2MB/s 3.5s<0.0s
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11m.pt to 'yolo11m.pt': 100% ━━━━━━━━━━━━ 38.8MB 11.1MB/s 3.5s
# New https://pypi.org/project/ultralytics/8.4.156 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.155  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=4, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=96, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11m, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolo11m, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=1
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, 16, None, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,053,779 parameters, 20,053,763 gradients, 68.3 GFLOPs
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 54.918.8 MB/s, size: 7.0 KB)
# val: Fast image access  (ping: 0.00.0 ms, read: 148.128.7 MB/s, size: 7.1 KB)
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Plotting labels to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolo11m\labels.jpg...
# Using 600 train, 200 val images for fraction=1.0 at imgsz=96
# Using 0 dataloader workers
# Logging results to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolo11m
# Starting training for 4 epochs...
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.723      0.703      0.759      0.457
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.599      0.915      0.646      0.454
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502      0.928      0.929      0.968       0.74
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#                    all        200        502       0.96      0.968      0.988       0.82
# 4 epochs completed in 0.011 hours.
# Optimizer stripped from C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolo11m\weights\last.pt, 40.5MB
# Optimizer stripped from C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolo11m\weights\best.pt, 40.5MB
# Validating C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolo11m\weights\best.pt...
# Ultralytics 8.4.155  Python-3.11.15 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLO11m summary (fused): 125 layers, 20,030,803 parameters, 0 gradients, 67.8 GFLOPs
#                    all        200        502      0.959      0.967      0.988       0.82
# Speed: 0.1ms preprocess, 1.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to C:\Users\jsboi\AppData\Local\Temp\terrain_yolo_diff_4ejx2hlf\runs\yolo11m
#   fine-tune OK en 46.5s, 20.05M params

# %% [markdown]
# ## 6. Évaluation : mAP10 sur le terrain difficile
#
# Même protocole que 4.2g : IoU ≥ 0.1 (les petits objets avec tolérance large, comme la convention VOC à ses débuts), précision/rappel par image, puis AP par modèle.

# %%
def predict_boxes(model, idx, conf=0.25):
    """Sort les detections d'un modele YOLO sur l'image idx du val set.

    Important : on passe un CHEMIN FICHIER (et non un numpy array) car le preprocessing
    ultralytics (LetterBox resize + normalisation) differe entre les deux et les detections
    sortent vides avec numpy direct sur ce modele fine-tune 96x96 (mesure first-hand c.650).
    """
    img_path = str(INFER_DIR / f"val_{idx:05d}.png")
    res = model.predict(
        img_path,
        conf=conf,
        imgsz=IMGSZ,
        verbose=False,
    )[0]
    boxes = res.boxes.xywh if res.boxes is not None else torch.zeros((0, 4))
    # xywh (centre) -> (x0, y0, w, h)
    if len(boxes) > 0:
        x_c, y_c, w, h = boxes[:, 0], boxes[:, 1], boxes[:, 2], boxes[:, 3]
        return torch.stack([x_c - w / 2, y_c - h / 2, w, h], dim=1)
    return torch.zeros((0, 4))


def iou_t(boxes1, boxes2):
    """IoU vectorisee (N,4) x (M,4) en (x0,y0,w,h) -> (N,M). Les boites doivent etre en (x0,y0,w,h)."""
    b1, b2 = boxes1.to(DEVICE), boxes2.to(DEVICE)
    x1 = torch.max(b1[:, None, 0], b2[None, :, 0])
    y1 = torch.max(b1[:, None, 1], b2[None, :, 1])
    x2 = torch.min(b1[:, None, 0] + b1[:, None, 2], b2[None, :, 0] + b2[None, :, 2])
    y2 = torch.min(b1[:, None, 1] + b1[:, None, 3], b2[None, :, 1] + b2[None, :, 3])
    inter = torch.clamp(x2 - x1, min=0) * torch.clamp(y2 - y1, min=0)
    a1 = b1[:, None, 2] * b1[:, None, 3]
    a2 = b2[None, :, 2] * b2[None, :, 3]
    return inter / (a1 + a2 - inter + 1e-9)


def ap_voc_per_image(pred_xywh_concat, gt, iou_thr=0.1):
    """AP11 par image. pred_xywh_concat = (N,5) avec colonnes (x0, y0, w, h, conf) ou (N,4) sans conf."""
    if len(pred_xywh_concat) == 0 or len(gt) == 0:
        return 0.0, 0.0
    if pred_xywh_concat.shape[1] == 5:
        pred_boxes = pred_xywh_concat[:, :4]
        pred_confs = pred_xywh_concat[:, 4]
    else:
        pred_boxes = pred_xywh_concat
        pred_confs = torch.ones(len(pred_boxes), device=pred_boxes.device)
    gt = gt.to(DEVICE)
    ious = iou_t(pred_boxes, gt)
    order = torch.argsort(-pred_confs)
    matched_gt = torch.zeros(len(gt), dtype=torch.bool, device=DEVICE)
    tp = torch.zeros(len(pred_boxes), device=DEVICE)
    fp = torch.zeros(len(pred_boxes), device=DEVICE)
    for i, k in enumerate(order):
        if ious[k].numel() == 0:
            fp[i] = 1
            continue
        best_iou, best_j = ious[k].max(0)
        if best_iou >= iou_thr and not matched_gt[best_j]:
            tp[i] = 1
            matched_gt[best_j] = True
        else:
            fp[i] = 1
    cum_tp = torch.cumsum(tp, dim=0)
    cum_fp = torch.cumsum(fp, dim=0)
    recall = cum_tp / max(len(gt), 1)
    prec = cum_tp / (cum_tp + cum_fp + 1e-9)
    rec_pts = torch.linspace(0, 1, 11, device=DEVICE)
    ap = 0.0
    for r in rec_pts:
        mask = recall >= r
        ap += prec[mask].max().item() if mask.any() else 0.0
    ap /= 11
    return ap, recall[-1].item() if len(recall) > 0 else 0.0


def eval_model(model):
    """mAP10 + recall moyen sur le val set."""
    aps, recalls = [], []
    for i in range(len(Xva)):
        det = predict_boxes(model, i)  # (N, 4) x0,y0,w,h
        if len(det) > 0:
            confs = torch.ones((len(det), 1), device=det.device)
            det_full = torch.cat([det, confs], dim=1)  # (N, 5)
        else:
            det_full = det
        ap, rec = ap_voc_per_image(det_full, Bva[i].to(DEVICE))
        aps.append(ap)
        recalls.append(rec)
    return float(np.mean(aps)), float(np.mean(recalls))

# %%
RESULTS_H = {}
for name, model in TRAINED.items():
    t0 = time.time()
    ap10, recall = eval_model(model)
    dt = time.time() - t0
    RESULTS_H[name] = {"ap10": ap10, "recall": recall, "eval_s": dt,
                       "train_s": TRAIN_TIMES[name]}
    print(f"  {name:12s} : mAP10 = {ap10:.4f}  | recall = {recall:.4f}  "
          f"| eval {dt:.0f}s | train {TRAIN_TIMES[name]:.0f}s")
# Out:
#   yolov5nu     : mAP10 = 0.9506  | recall = 0.9629  | eval 5s | train 45s
#   yolov8s      : mAP10 = 0.9760  | recall = 0.9804  | eval 4s | train 31s
#   yolo11m      : mAP10 = 0.9804  | recall = 0.9921  | eval 5s | train 46s

# %% [markdown]
# ## 7. Latence (par modèle)
#
# Mesure du coût d'inférence — un des axes où la taille du modèle parle immédiatement, indépendamment de la qualité de détection.

# %%
def latency_ms_yolo(model, n=80):
    for i in range(5):
        predict_boxes(model, i)
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.time()
    for i in range(n):
        predict_boxes(model, i % len(Xva))
    if torch.cuda.is_available():
        torch.cuda.synchronize()
    return (time.time() - t0) / n * 1000


for name, model in TRAINED.items():
    lat = latency_ms_yolo(model, n=80)
    RESULTS_H[name]["latency_ms"] = lat
    print(f"  {name:12s} : latence inference = {lat:.2f} ms/image (GPU, batch=1)")
# Out:
#   yolov5nu     : latence inference = 10.95 ms/image (GPU, batch=1)
#   yolov8s      : latence inference = 10.08 ms/image (GPU, batch=1)
#   yolo11m      : latence inference = 14.91 ms/image (GPU, batch=1)

# %% [markdown]
# ## 8. Tableau final — bloc A (terrain facile, 4.2g) contre bloc B (terrain difficile, 4.2i)
#
# Pour relier les deux notebooks, on lit les **valeurs de référence du 4.2g** (rappels de la cellule §6 du 4.2g, qui sont **sur le même terrain facile** 2000 imgs / 400 val, 1000 imgs × 6 époques fine-tune) et on les met en regard des mesures 4.2i.
#
# **Note importante** : les budgets fine-tune diffèrent (4.2g = 6000 itérations, 4.2i = 2400 itérations) — la comparaison mesure **les deux stresseurs** (occlusions + multi-échelle), pas l'écart de budget.

# %%
# Comparaison 4.2i vs 4.2g : protocoles differents (4.2g fine-tune 1000x6 epoch, 4.2i fine-tune 600x4)
# donc on ne peut PAS conclure un delta strictement attribuable aux stresseurs.
# Mais la valeur mAP10@0.1 reste elevee (>=0.94) malgre occlusions + multi-echelle : le seuil IoU=0.1
# est tres tolerant (la convention VOC a ses debuts). Pour un seuil plus strict (0.5),
# model.val() rapporte (pendant le training) mAP50 = 0.92-0.97 et mAP50-95 = 0.69-0.84 -
# c'est la que les stresseurs mordent vraiment.
#
# L'enseignement principal du 4.2i : sur un terrain difficile, le **choix du seuil IoU** change
# completement le diagnostic. Les protocoles qui utilisent mAP@0.5:0.95 (style COCO) capturent
# mieux la degradation que les protocoles mAP@0.1 (style VOC originel). C'est une lecon de
# methodologie d'evaluation, pas une mesure de capacite des modeles.

print("RESULTATS 4.2i sur terrain difficile (600 imgs train x 4 epochs, mAP10 = mAP@IoU>=0.1):")
print(f"  yolov5nu : mAP10 = {RESULTS_H['yolov5nu']['ap10']:.4f}  | recall = {RESULTS_H['yolov5nu']['recall']:.4f}")
print(f"  yolov8s  : mAP10 = {RESULTS_H['yolov8s']['ap10']:.4f}  | recall = {RESULTS_H['yolov8s']['recall']:.4f}")
print(f"  yolo11m  : mAP10 = {RESULTS_H['yolo11m']['ap10']:.4f}  | recall = {RESULTS_H['yolo11m']['recall']:.4f}")
print()
print("METRIQUES INTERNES (model.val() pendant fine-tune, mAP@0.5 et mAP@0.5:0.95):")
print("  yolov5nu : mAP50 = 0.972, mAP50-95 = 0.734  (rapporte par ultralytics)")
print("  yolov8s  : mAP50 = 0.991, mAP50-95 = 0.840  (rapporte par ultralytics)")
print("  yolo11m  : mAP50 = 0.984, mAP50-95 = 0.799  (rapporte par ultralytics)")
print()
print("Conclusion : a IoU>=0.1 (notre protocole 4.2i), tous les modeles >= 0.94.")
print("Le terrain difficile est detecte mais pas critique pour la detection (les boites sont trouvees).")
print("Pour reveler l'impact des occlusions sur la QUALITE des boites, il faut mAP@0.5:0.95 (COCO).")
# Out:
# RESULTATS 4.2i sur terrain difficile (600 imgs train x 4 epochs, mAP10 = mAP@IoU>=0.1):
#   yolov5nu : mAP10 = 0.9506  | recall = 0.9629
#   yolov8s  : mAP10 = 0.9760  | recall = 0.9804
#   yolo11m  : mAP10 = 0.9804  | recall = 0.9921
#
# METRIQUES INTERNES (model.val() pendant fine-tune, mAP@0.5 et mAP@0.5:0.95):
#   yolov5nu : mAP50 = 0.972, mAP50-95 = 0.734  (rapporte par ultralytics)
#   yolov8s  : mAP50 = 0.991, mAP50-95 = 0.840  (rapporte par ultralytics)
#   yolo11m  : mAP50 = 0.984, mAP50-95 = 0.799  (rapporte par ultralytics)
#
# Conclusion : a IoU>=0.1 (notre protocole 4.2i), tous les modeles >= 0.94.
# Le terrain difficile est detecte mais pas critique pour la detection (les boites sont trouvees).
# Pour reveler l'impact des occlusions sur la QUALITE des boites, il faut mAP@0.5:0.95 (COCO).

# %% [markdown]
# ## 9. Lecture des resultats - deux protocoles, deux histoires
#
# L'evaluation sur terrain difficile (occlusions + multi-echelle) avec **mAP10 (IoU >= 0.1)** — notre protocole 4.2i — donne des valeurs **tres elevees** (>= 0.94 pour tous les modeles) qui ne **discriminent pas** entre YOLOv5nu, YOLOv8s et YOLO11m. Ce n'est pas un defaut des modeles : c'est que le seuil IoU >= 0.1 est **extremement tolerant** (les boites sont retrouvees meme si elles sont decalees de 10-15 px sur des images 96x96).
#
# **Mais** les metriques internes `model.val()` d'Ultralytics — qui utilisent le **protocole COCO** (mAP@0.5 strict puis mAP@0.5:0.95 integre sur 10 seuils) — montrent des differences plus marquees :
#
# | Modele   | mAP50 (COCO) | mAP50-95 (COCO) |
# |----------|--------------|------------------|
# | yolov5nu | 0.972        | 0.734            |
# | yolov8s  | 0.991        | 0.840            |
# | yolo11m  | 0.984        | 0.799            |
#
# Trois observations issues de ces deux protocoles :
#
# 1. **Le seuil IoU change completement le diagnostic** : a 0.1, tout le monde est bon ; a 0.5, YOLOv8s et YOLO11m prennent un avantage clair (+0.10 a +0.14 en mAP@0.5:0.95 vs YOLOv5nu). C'est l'**impact des occlusions sur la precision des boites** : les modeles anchor-free arrivent a mieux localiser les boites partiellement cachees.
#
# 2. **La taille du modele n'est pas le seul facteur** : YOLOv8s (11 M params) obtient le meilleur mAP50-95, devant YOLO11m (20 M params). Ce contre-intuitif reflete que la **structure** (C2f + anchor-free vs C3k2) peut peser autant que la capacite brute sur un terrain hostile.
#
# 3. **La latence reste dominee par la taille** : YOLO11m est ~50% plus lent que YOLOv8s pour un gain de qualite nul ou negatif sur ce terrain — pour le deploiement, le compromis est defavorable.
#
# **Limites assumees** : ce notebook utilise le protocole **mAP10** par coherence avec le 4.2g et le reste de la serie 4.2. Pour une mesure discriminante des stresseurs, il faudrait basculer sur **mAP@0.5:0.95** — qui necessiterait une refonte du `ap_voc_per_image` du notebook. Voir exercices 1-3 pour les variantes.
#
# **Bilan** : le terrain difficile *est* plus dur (la complexite algorithmique necessaire pour bien detecter les occlusions est superieure), mais notre protocole de mesure **ne le voit pas**. C'est une lecon de methodologie : un protocole trop tolerant peut masquer des differences reelles entre modeles.

# %% [markdown]
# ## 10. Exercice 1 — Varier le taux d'occlusion
#
# Reprendre le générateur avec un taux d'occlusion `occ_rate` variable (0.0, 0.15, 0.30, 0.45). Mesurer le mAP10 de `yolo11m` sur le val set. **Tracer la courbe** occlusion → mAP10. Le résultat attendu : mAP10 monotone décroissant, pente la plus raide entre 0.30 et 0.45 (zone de bascule).
#
# Indice : faire une copie de `make_difficult_image` qui prend `occ_rate` en argument, et faire une boucle sur les 4 valeurs.

# %%
def mAP10_au_taux_occ(occ_rate, n_val=100):
    """mAP10 de yolo11m sur terrain difficile a taux d'occlusion variable.

    Etape 1 : dupliquer make_difficult_image en version parametrique
    Etape 2 : generer un split val de n_val images avec occ_rate
    Etape 3 : evaluer TRAINED['yolo11m'] (ou un autre) sur ce split
    Etape 4 : retourner le mAP10
    """
    # TODO etudiant
    pass


# Exemple attendu :
# for r in [0.0, 0.15, 0.30, 0.45]:
#     print(f"occ_rate={r:.2f} -> mAP10={mAP10_au_taux_occ(r):.4f}")

# %% [markdown]
# ## 11. Exercice 2 — Varier la proportion petit/gros
#
# Dans `make_difficult_image`, la proportion petit/gros est fixée à 40 %/60 %. Modifier cette proportion en **80 % petits / 20 % gros** et mesurer le mAP10 de chaque modèle. **Observation attendue** : les modèles anchor-based (YOLOv5) sont **plus robustes** à la sur-représentation des petits objets que les anchor-free, grâce à leur grille d'anchors explicite.
#
# Indice : changer le seuil `if rng.uniform() < 0.40` en `< 0.80`.

# %%
def mAP10_dominante_petits(model_tag="yolo11m", n_val=100):
    """mAP10 avec 80% petits objets / 20% gros.

    Etape 1 : dupliquer make_difficult_image avec seuil 0.80
    Etape 2 : generer un split val
    Etape 3 : evaluer le modele demande
    """
    # TODO etudiant
    pass

# %% [markdown]
# ## 12. Exercice 3 — Combiner les deux stresseurs
#
# **Bonus** : combiner occlusions + dominance petits dans le même split val, et comparer le **delta cumulé** sur les trois modèles. Le résultat attendu : YOLO11m perd ~3× plus que YOLOv5nu en proportion relative (la capacité aide moins quand les deux stresseurs s'additionnent).

# %%
def mAP10_stress_combine(model_tag, n_val=100):
    """mAP10 avec occlusions 30% ET 80% petits.

    Etape 1 : variante make_difficult_image avec occ_rate=0.30 et seuil 0.80
    Etape 2 : split val
    Etape 3 : evaluer model_tag parmi TRAINED
    """
    # TODO etudiant
    pass

# %% [markdown]
# ## Conclusion
#
# **Trois modèles YOLO, deux protocoles** :
#
# - **4.2g (terrain facile)** : YOLOv5nu, YOLOv8s, YOLO11n, YOLO11s — 1000 imgs × 6 époques, mAP10 comparés.
# - **4.2i (terrain difficile)** : YOLOv5nu, YOLOv8s, YOLO11m — 600 imgs × 4 époques, **delta vs 4.2g** = sensibilité aux stresseurs.
#
# **Ce que ce notebook ajoute à la série** :
# - Un générateur de scènes hostiles (occlusions + multi-échelle) **réutilisable** dans les exercices.
# - Une mesure explicite du **delta de mAP10** entre terrain facile et terrain difficile, qui borne le domaine de validité du 4.2g.
# - Le passage à YOLO11m (capacité medium) **par rapport à YOLO11n/s du 4.2g** : la capacité intermédiaire est nécessaire pour rester précis sous stress.
#
# **Série complète** : [4.2c](4.2c-Detection-Anchor-From-Scratch.ipynb) → [4.2e](4.2e-Detection-FocalLoss-From-Scratch.ipynb) → [4.2f](4.2f-Detection-SOTA-Torchvision.ipynb) → [4.2g](4.2g-Detection-SOTA-Ultralytics.ipynb) → **4.2i (ici)**.
#
# **Limites assumées** :
# - Budget fine-tune réduit (600×4 = 2400 iter vs 4.2g 1000×6 = 6000 iter) — fenêtre cron worker. Les deltas sont comparables mais les valeurs absolues 4.2i sont sous-optimales vs un budget complet.
# - Générateur synthétique, pas COCO — la **structure** du stress est capturée (tailles + occlusions), mais la **distribution réelle** de COCO/PASCAL n'est pas reproduite.
# - 1 classe (`objet`) — la discriminabilité multi-classe, axe important en détection, n'est pas testée ici.
