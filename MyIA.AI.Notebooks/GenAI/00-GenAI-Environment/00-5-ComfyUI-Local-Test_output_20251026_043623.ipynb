# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [4]</a>'.</span>

# %% [markdown]
# # 00-5: ComfyUI Local - Test Rapide
#
# **Objectif**: Valider connexion et génération basique ComfyUI local
#
# **Prérequis**:
# - ComfyUI démarré sur port 8188
# - Modèle Qwen-Image-Edit-2509-FP8 chargé
# - Custom nodes Qwen installés
#
# **Durée**: ~2-3 minutes

# %% [markdown]
# ## Cell 1: Import et Configuration

# %%
# Imports
import sys
import os

# Ajouter shared helpers au path
# Note: Papermill exécute depuis le répertoire du notebook, pas depuis la racine
# On utilise donc un chemin absolu pour garantir la compatibilité
shared_path = r'd:\Dev\CoursIA\MyIA.AI.Notebooks\GenAI\shared'
if shared_path not in sys.path:
    sys.path.insert(0, shared_path)

from helpers.comfyui_client import create_client

print("✅ Imports réussis")
# Out:
# ✅ Imports réussis

# %% [markdown]
# ## Cell 2: Test Connexion ComfyUI

# %%
# Test connexion rapide via create_client()
print("🔍 Test connexion ComfyUI...")

try:
    test_client = create_client()
    
    # Test basique avec /system_stats
    stats = test_client.get_system_stats()
    
    print("\n✅ ComfyUI accessible!")
    
    if stats:
        system = stats.get('system', {})
        print(f"\n📊 Statistiques Système:")
        print(f"   - PyTorch: {system.get('pytorch_version', 'N/A')}")
        print(f"   - CUDA: {system.get('cuda', 'N/A')}")
        print(f"   - ComfyUI: {system.get('comfyui_version', 'N/A')}")
        print(f"   - Python: {system.get('python_version', 'N/A')}")
    
except Exception as e:
    print("\n❌ ComfyUI non accessible!")
    print(f"   Erreur: {e}")
    print("   Vérifier que le service est démarré sur port 8188")
# Out:
# 🔍 Test connexion ComfyUI...
#
# ❌ ComfyUI non accessible!
#    Erreur: 'ComfyUIClient' object has no attribute 'get_system_stats'
#    Vérifier que le service est démarré sur port 8188

# %% [markdown]
# ## Cell 3: Créer Client ComfyUI

# %%
# Créer client
try:
    client = create_client()
    print("✅ Client ComfyUI créé avec succès")
except ConnectionError as e:
    print(f"❌ Erreur connexion: {e}")
    client = None
# Out:
# ✅ Client ComfyUI créé avec succès

# %% [markdown]
# ## Cell 4: Génération Text-to-Image Simple

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
# Génération image test
if client:
    print("🎨 Lancement génération...")
    print("   Prompt: 'A beautiful sunset over mountains'")
    print("   Résolution: 512x512")
    print("   Steps: 20")
    print("\n⏳ Génération en cours (5-10 secondes)...\n")
    
    prompt_id = client.generate_text2image(
        prompt="A beautiful sunset over mountains",
        negative_prompt="blurry, low quality, distorted",
        width=512,
        height=512,
        steps=20,
        cfg=7.0,
        seed=42,  # Reproductible
        save_prefix="test_phase13a"
    )
    
    if prompt_id:
        print(f"\n✅ Génération réussie!")
        print(f"   Prompt ID: {prompt_id}")
        print(f"\n💾 Image sauvegardée dans ComfyUI output/")
    else:
        print("\n❌ Génération échouée")
        print("   Vérifier logs ComfyUI pour détails")
else:
    print("❌ Client non initialisé")
# Out:
# 🎨 Lancement génération...
#    Prompt: 'A beautiful sunset over mountains'
#    Résolution: 512x512
#    Steps: 20
#
# ⏳ Génération en cours (5-10 secondes)...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\Dev\CoursIA\MyIA.AI.Notebooks\GenAI\shared\helpers\comfyui_client.py:87, in ComfyUIClient._make_request(self, endpoint, method, data)
#      86 try:
# ---> 87     with request.urlopen(req) as response:
#      88         return json.loads(response.read().decode())
#
# File ~\.conda\envs\mcp-jupyter-py310\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\.conda\envs\mcp-jupyter-py310\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~\.conda\envs\mcp-jupyter-py310\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~\.conda\envs\mcp-jupyter-py310\lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File ~\.conda\envs\mcp-jupyter-py310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File ~\.conda\envs\mcp-jupyter-py310\lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6 print("   Steps: 20")
#       7 print("\n⏳ Génération en cours (5-10 secondes)...\n")
# ----> 9 prompt_id = client.generate_text2image(
#      10     prompt="A beautiful sunset over mountains",
#      11     negative_prompt="blurry, low quality, distorted",
#      12     width=512,
#      13     height=512,
#      14     steps=20,
#      15     cfg=7.0,
#      16     seed=42,  # Reproductible
#      17     save_prefix="test_phase13a"
#      18 )
#      20 if prompt_id:
#      21     print(f"\n✅ Génération réussie!")
#
# File d:\Dev\CoursIA\MyIA.AI.Notebooks\GenAI\shared\helpers\comfyui_client.py:301, in ComfyUIClient.generate_text2image(self, prompt, width, height, num_inference_steps, steps, seed, negative_prompt, cfg, save_prefix)
#     215 workflow = {
#     216     "1": {
#     217         "inputs": {"model_path": "qwen_2.5_vl_7b.safetensors"},
#    (...)
#     297     },
#     298 }
#     300 # Enqueue et attendre la complétion
# --> 301 prompt_id = self.queue_prompt(workflow)
#     302 result = self.wait_for_completion(prompt_id)
#     304 return result
#
# File d:\Dev\CoursIA\MyIA.AI.Notebooks\GenAI\shared\helpers\comfyui_client.py:111, in ComfyUIClient.queue_prompt(self, workflow)
#      98 """
#      99 Envoie un workflow à ComfyUI pour exécution.
#     100
#    (...)
#     108     Exception: Si l'enqueue échoue
#     109 """
#     110 payload = {"prompt": workflow, "client_id": self.client_id}
# --> 111 response = self._make_request("/prompt", method="POST", data=payload)
#     113 if "prompt_id" not in response:
#     114     raise Exception(f"Prompt queue failed: {response}")
#
# File d:\Dev\CoursIA\MyIA.AI.Notebooks\GenAI\shared\helpers\comfyui_client.py:91, in ComfyUIClient._make_request(self, endpoint, method, data)
#      89 except error.HTTPError as e:
#      90     error_body = e.read().decode() if e.fp else "No error body"
# ---> 91     raise Exception(
#      92         f"HTTP {e.code} Error calling {url}: {e.reason}\nBody: {error_body}"
#      93     )
#      94 except error.URLError as e:
#      95     raise Exception(f"URL Error calling {url}: {e.reason}")
#
# Exception: HTTP 400 Error calling http://localhost:8188/prompt: Bad Request
# Body: {"error": {"type": "prompt_outputs_failed_validation", "message": "Prompt outputs failed validation", "details": "", "extra_info": {}}, "node_errors": {"3": {"errors": [{"type": "value_not_in_list", "message": "Value not in list", "details": "vae_name: 'qwen_image_vae.safetensors' not in ['pixel_space']", "extra_info": {"input_name": "vae_name", "input_config": [["pixel_space"], {}], "received_value": "qwen_image_vae.safetensors"}}], "dependent_outputs": ["10"], "class_type": "VAELoader"}, "1": {"errors": [{"type": "required_input_missing", "message": "Required input is missing", "details": "model_name", "extra_info": {"input_name": "model_name"}}], "dependent_outputs": ["10"], "class_type": "QwenVLCLIPLoader"}, "2": {"errors": [{"type": "value_not_in_list", "message": "Value not in list", "details": "unet_name: 'qwen_image_edit_2509_fp8_e4m3fn.safetensors' not in []", "extra_info": {"input_name": "unet_name", "input_config": [[], {}], "received_value": "qwen_image_edit_2509_fp8_e4m3fn.safetensors"}}], "dependent_outputs": ["10"], "class_type": "UNETLoader"}, "18": {"errors": [{"type": "value_not_in_list", "message": "Value not in list", "details": "lora_name: 'Qwen-Image-Edit-Lightning-8steps-V1.0.safetensors' not in []", "extra_info": {"input_name": "lora_name", "input_config": [[], {}], "received_value": "Qwen-Image-Edit-Lightning-8steps-V1.0.safetensors"}}], "dependent_outputs": ["10"], "class_type": "LoraLoaderModelOnly"}, "17": {"errors": [{"type": "required_input_missing", "message": "Required input is missing", "details": "strength", "extra_info": {"input_name": "strength"}}], "dependent_outputs": ["10"], "class_type": "CFGNorm"}, "19": {"errors": [{"type": "value_not_in_list", "message": "Value not in list", "details": "sampler_name: 'res_2s' not in (list of length 42)", "extra_info": {"input_name": "sampler_name", "input_config": null, "received_value": "res_2s"}}, {"type": "value_not_in_list", "message": "Value not in list", "details": "scheduler: 'beta57' not in ['simple', 'sgm_uniform', 'karras', 'exponential', 'ddim_uniform', 'beta', 'normal', 'linear_quadratic', 'kl_optimal']", "extra_info": {"input_name": "scheduler", "input_config": [["simple", "sgm_uniform", "karras", "exponential", "ddim_uniform", "beta", "normal", "linear_quadratic", "kl_optimal"], {"tooltip": "The scheduler controls how noise is gradually removed to form the image."}], "received_value": "beta57"}}], "dependent_outputs": ["10"], "class_type": "KSampler"}}}

# %% [markdown]
# ## Cell 5: Résumé Test

# %%
# Résumé
print("="*60)
print("📋 RÉSUMÉ TEST PHASE 13A")
print("="*60)

if client and prompt_id:
    print("\n✅ Status: SUCCESS")
    print("\n🎯 Accomplissements:")
    print("   ✅ ComfyUI accessible")
    print("   ✅ Client Python opérationnel")
    print("   ✅ Génération text-to-image validée")
    print("   ✅ Bridge ComfyUI fonctionnel")
    
    print("\n🚀 Prêt pour Phase 13B:")
    print("   - Implémentation notebook 02-1 complet")
    print("   - Workflows avancés (image-to-image, etc.)")
    print("   - Intégration pédagogique complète")
else:
    print("\n⚠️ Status: PARTIAL")
    print("\n❌ Problèmes détectés:")
    if not client:
        print("   - Connexion ComfyUI échouée")
    if client and not prompt_id:
        print("   - Génération échouée (workflow incompatible?)")
    
    print("\n📚 Troubleshooting:")
    print("   1. Vérifier ComfyUI démarré: http://localhost:8188")
    print("   2. Vérifier modèle Qwen chargé")
    print("   3. Consulter logs ComfyUI")
    print("   4. Voir: TROUBLESHOOTING.md")

print("\n" + "="*60)
