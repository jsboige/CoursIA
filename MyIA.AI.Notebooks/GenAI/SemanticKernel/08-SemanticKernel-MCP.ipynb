# %% [markdown]
# # SK-8-MCP : Model Context Protocol et Integration
#
# **Navigation** : [<< 07-MultiModal](07-SemanticKernel-MultiModal.ipynb) | [Index](README.md)
#
# ---
#
# ## Objectifs d'apprentissage
#
# A la fin de ce notebook, vous saurez :
# 1. Comprendre le **Model Context Protocol (MCP)**
# 2. Identifier les **serveurs MCP** disponibles
# 3. Integrer des **outils MCP** comme plugins SK
# 4. Créer un **bridge Agent Framework ↔ MCP**
# 5. Concevoir un **serveur MCP personnalise**
#
# ### Prerequis
#
# - Python 3.10+
# - Notebooks 01-07 completes
# - Comprehension des Agents SK (notebook 03)
# - Node.js installe (pour certains serveurs MCP)
#
# ### Duree estimee : 45 minutes
#
# ---
#
# ## Sommaire
#
# | Section | Contenu | Concepts cles |
# |---------|---------|---------------|
# | 1 | Introduction | Qu'est-ce que MCP ? |
# | 2 | Architecture | Tools, Resources, Prompts |
# | 3 | Serveurs existants | Filesystem, GitHub, Database |
# | 4 | SK + MCP | Integration comme plugins |
# | 5 | Agent + MCP | Bridge avec Agent Framework |
# | 6 | Serveur custom | Créer son propre serveur |
# | 7 | Conclusion | Resume, exercices |
#
# > **Model Context Protocol (MCP)** : Standard ouvert initie par Anthropic et adopte par Microsoft pour permettre aux LLMs d'acceder a des outils externes de maniere standardisee. C'est l'evolution des plugins vers l'interoperabilite.

# %%
# Installation

import os
from dotenv import load_dotenv

load_dotenv()
print("MCP SDK installe")
# Out:
# MCP SDK installe

# %% [markdown]
# ## 1. Introduction au Model Context Protocol
#
# ### Pourquoi MCP ?
#
# Avant MCP, chaque framework avait son propre système de plugins :
#
# | Framework | Système de plugins | Problème |
# |-----------|-------------------|----------|
# | Semantic Kernel | KernelFunction | Non portable |
# | LangChain | Tools | Non portable |
# | AutoGen | Tools | Non portable |
# | OpenAI | Function Calling | Spécifique OpenAI |
#
# **MCP resout ce problème** en definissant un standard :
#
# ```
# ┌─────────────────┐     ┌─────────────────┐     ┌─────────────────┐
# │ Semantic Kernel │     │   LangChain     │     │    AutoGen      │
# │                 │     │                 │     │                 │
# │  MCP Client     │     │  MCP Client     │     │  MCP Client     │
# └────────┬────────┘     └────────┬────────┘     └────────┬────────┘
#          │                       │                       │
#          └───────────────────────┼───────────────────────┘
#                                  │
#                                  ↓
#                     ┌─────────────────────────┐
#                     │     MCP Servers         │
#                     │                         │
#                     │ - Filesystem            │
#                     │ - GitHub                │
#                     │ - Database              │
#                     │ - Custom...             │
#                     └─────────────────────────┘
# ```
#
# ### Acteurs principaux
#
# | Acteur | Rôle | Exemple |
# |--------|------|---------|
# | **Client** | Consomme les outils | Claude Code, SK |
# | **Server** | Fournit les outils | mcp-server-filesystem |
# | **Transport** | Communication | stdio, HTTP, SSE |

# %% [markdown]
# Le diagramme ci-dessous rend cette architecture **MCP** sous forme de graphe : plusieurs
# frameworks clients consomment un même ensemble de serveurs d'outils standardises.
#
# ```mermaid
# flowchart TD
#     SK["Semantic Kernel<br/>MCP Client"] --> SRV
#     LC["LangChain<br/>MCP Client"] --> SRV
#     AG["AutoGen<br/>MCP Client"] --> SRV
#     SRV["MCP Servers<br/>Filesystem / GitHub / Database / Custom..."]
#     classDef client fill:#cfe2ff,stroke:#084298,color:#052c65
#     classDef server fill:#fff3cd,stroke:#b8860b,color:#5c4400
#     class SK,LC,AG client
#     class SRV server
# ```
#
# > **Lecture.** Le **Model Context Protocol** standardise la facon dont un agent accede a
# > des outils externes : n'importe quel **client** conforme (Semantic Kernel, LangChain,
# > AutoGen...) peut consommer n'importe quel **serveur MCP** (filesystem, GitHub, base de
# > données, serveurs maison) sans integration sur-mesure. C'est l'equivalent, pour les
# > outils d'agents, de ce que USB a ete pour les peripheriques : un connecteur commun qui
# > decouple les clients des fournisseurs de capacites.

# %% [markdown]
# ## 2. Architecture MCP
#
# MCP définit trois types de primitives :
#
# ### 2.1 Tools (Outils)
#
# Fonctions executables par le LLM :
#
# ```json
# {
#   "name": "read_file",
#   "description": "Read the contents of a file",
#   "inputSchema": {
#     "type": "object",
#     "properties": {
#       "path": { "type": "string" }
#     },
#     "required": ["path"]
#   }
# }
# ```
#
# ### 2.2 Resources (Ressources)
#
# Données accessibles en lecture :
#
# ```json
# {
#   "uri": "file:///path/to/doc.md",
#   "name": "Documentation",
#   "mimeType": "text/markdown"
# }
# ```
#
# ### 2.3 Prompts
#
# Templates de prompts reutilisables :
#
# ```json
# {
#   "name": "summarize",
#   "description": "Summarize a document",
#   "arguments": [
#     { "name": "content", "required": true }
#   ]
# }
# ```
#
# ### Tableau comparatif
#
# | Primitive | Action | Equivalent SK |
# |-----------|--------|---------------|
# | **Tool** | Execute une fonction | KernelFunction |
# | **Resource** | Lit des données | Pas d'equivalent direct |
# | **Prompt** | Fournit un template | PromptTemplate |

# %% [markdown]
# ## 3. Serveurs MCP existants
#
# De nombreux serveurs MCP sont disponibles :

# %%
# Liste des serveurs MCP populaires
mcp_servers = [
    {
        "name": "filesystem",
        "package": "@anthropic/mcp-server-filesystem",
        "description": "Lecture/ecriture de fichiers",
        "tools": ["read_file", "write_file", "list_directory"]
    },
    {
        "name": "github",
        "package": "@anthropic/mcp-server-github",
        "description": "Operations GitHub (repos, issues, PRs)",
        "tools": ["search_repos", "get_issue", "create_pr"]
    },
    {
        "name": "postgres",
        "package": "@anthropic/mcp-server-postgres",
        "description": "Requetes SQL PostgreSQL",
        "tools": ["query", "execute", "describe_table"]
    },
    {
        "name": "jupyter",
        "package": "mcp-jupyter",
        "description": "Execution de notebooks Jupyter",
        "tools": ["execute_notebook", "read_cells", "manage_kernel"]
    },
    {
        "name": "puppeteer",
        "package": "@anthropic/mcp-server-puppeteer",
        "description": "Automatisation web (scraping, screenshots)",
        "tools": ["navigate", "screenshot", "click"]
    }
]

print("Serveurs MCP populaires:")
print("=" * 60)
for server in mcp_servers:
    print(f"\n{server['name'].upper()}")
    print(f"  Package: {server['package']}")
    print(f"  Description: {server['description']}")
    print(f"  Tools: {', '.join(server['tools'])}")
# Out:
# Serveurs MCP populaires:
# ...
#
# FILESYSTEM
#   Package: @anthropic/mcp-server-filesystem
#   Description: Lecture/ecriture de fichiers
#   Tools: read_file, write_file, list_directory
#
# GITHUB
#   Package: @anthropic/mcp-server-github
#   Description: Operations GitHub (repos, issues, PRs)
#   Tools: search_repos, get_issue, create_pr
#
# POSTGRES
#   Package: @anthropic/mcp-server-postgres
#   Description: Requetes SQL PostgreSQL
#   Tools: query, execute, describe_table
#
# JUPYTER
#   Package: mcp-jupyter
#   Description: Execution de notebooks Jupyter
#   Tools: execute_notebook, read_cells, manage_kernel
#
# PUPPETEER
#   Package: @anthropic/mcp-server-puppeteer
#   Description: Automatisation web (scraping, screenshots)
#   Tools: navigate, screenshot, click

# %% [markdown]
# ### Exercice 1 : Analyseur de capacites MCP
#
# Choisir le bon serveur MCP pour une tâche donnee necessite de comprendre les capacites de chaque serveur.
#
# **Objectif** : Implementer une fonction `categorize_mcp_servers()` qui classe les serveurs par domaine d'expertise et capacite.
#
# **Indices** :
# - # Étape 1 : Parcourir la liste des serveurs et extraire le domaine a partir du nom et de la description
# - # Étape 2 : Compter le nombre d'outils par serveur et identifier les doublons potentiels
# - # Étape 3 : Retourner un dict avec les catégories (storage, devops, web, data) et les serveurs associes
# - # Indice : Les mots-cles dans la description indiquent le domaine ("fichiers" = storage, "GitHub" = devops, "scraping" = web, "SQL" = data)

# %%
def categorize_mcp_servers(servers: list) -> dict:
    """
    TODO etudiant : Classifier les serveurs MCP par domaine d'expertise.
    
    Args:
        servers: Liste de dicts avec les cles: name, description, tools
    
    Returns:
        dict avec les cles: categories (dict domaine -> list serveurs),
        total_tools (int), server_with_most_tools (str)
    """
    # TODO etudiant : analyser les descriptions et outils pour categoriser
    return None

# Test :
# result = categorize_mcp_servers(mcp_servers)
# for category, srvs in result['categories'].items():
#     print(f"{category}: {[s['name'] for s in srvs]}")
# print(f"Total outils: {result['total_tools']}")
print("Exercice a completer")
# Out:
# Exercice a completer

# %% [markdown]
# ### Interprétation : Écosystème des serveurs MCP
#
# **Sortie obtenue** : Liste de 5 serveurs MCP représentatifs de l'écosystème
#
# | Serveur | Domaine | Maturité | Cas d'usage typique |
# |---------|---------|----------|---------------------|
# | **filesystem** | Système | Production | Manipulation de fichiers locaux |
# | **github** | DevOps | Production | Automatisation CI/CD, gestion issues |
# | **postgres** | Base de données | Production | Requêtes SQL, analytics |
# | **jupyter** | Data Science | Expérimental | Notebooks interactifs, reproductibilité |
# | **puppeteer** | Web scraping | Production | Tests E2E, captures d'écran |
#
# **Points clés** :
#
# 1. **Diversité** : MCP couvre tous les domaines (filesystem, cloud, databases, web)
# 2. **Standards vs Custom** : Les serveurs Anthropic (@anthropic/*) sont les références
# 3. **Packages npm** : La majorité utilise Node.js, quelques-uns Python (uvx)
# 4. **Granularité** : Chaque serveur expose 3-10 outils spécialisés
#
# **Note technique** : L'installation nécessite Node.js 18+ pour les serveurs npm, ou Python 3.10+ avec `uvx` pour les serveurs Python.
#
# **Évolution** : De nouveaux serveurs apparaissent régulièrement sur [modelcontextprotocol.io/servers](https://modelcontextprotocol.io/servers)

# %% [markdown]
# ### Installation d'un serveur MCP
#
# ```bash
# # Via npm (Node.js requis)
# npx -y @anthropic/mcp-server-filesystem --root /path/to/files
#
# # Via uvx (Python)
# uvx mcp-server-sqlite --db-path database.db
# ```
#
# ### Configuration dans Claude Code
#
# Les serveurs MCP se configurent dans `~/.claude.json` :
#
# ```json
# {
#   "mcpServers": {
#     "filesystem": {
#       "command": "npx",
#       "args": ["-y", "@anthropic/mcp-server-filesystem", "--root", "/path"]
#     }
#   }
# }
# ```

# %% [markdown]
# ## 4. Integration SK + MCP
#
# Semantic Kernel peut consommer des serveurs MCP comme plugins.

# %%
# Exemple conceptuel : MCP Server comme plugin SK
# Note: L'integration native SK+MCP est en cours de developpement

from semantic_kernel import Kernel
from semantic_kernel.functions import kernel_function
from typing import Annotated
import subprocess
import json

class MCPFilesystemPlugin:
    """
    Wrapper qui expose un serveur MCP comme plugin SK.
    Pattern: MCP tools -> KernelFunctions
    """
    
    def __init__(self, root_path: str):
        self.root_path = root_path
    
    @kernel_function(description="Lit le contenu d'un fichier")
    def read_file(self, path: Annotated[str, "Chemin du fichier"]) -> str:
        """Wrapper pour l'outil MCP read_file."""
        full_path = os.path.join(self.root_path, path)
        try:
            with open(full_path, 'r', encoding='utf-8') as f:
                return f.read()
        except Exception as e:
            return f"Erreur: {e}"
    
    @kernel_function(description="Liste les fichiers d'un repertoire")
    def list_directory(self, path: Annotated[str, "Chemin du repertoire"] = ".") -> str:
        """Wrapper pour l'outil MCP list_directory."""
        full_path = os.path.join(self.root_path, path)
        try:
            files = os.listdir(full_path)
            return json.dumps(files, indent=2)
        except Exception as e:
            return f"Erreur: {e}"
    
    @kernel_function(description="Ecrit du contenu dans un fichier")
    def write_file(self, 
                   path: Annotated[str, "Chemin du fichier"],
                   content: Annotated[str, "Contenu a ecrire"]) -> str:
        """Wrapper pour l'outil MCP write_file."""
        full_path = os.path.join(self.root_path, path)
        try:
            with open(full_path, 'w', encoding='utf-8') as f:
                f.write(content)
            return f"Fichier ecrit: {full_path}"
        except Exception as e:
            return f"Erreur: {e}"

# Utilisation
kernel = Kernel()
kernel.add_plugin(MCPFilesystemPlugin(root_path="."), plugin_name="filesystem")

print("Plugin MCP Filesystem ajoute au Kernel")
print("\nFonctions disponibles:")
for func in kernel.get_plugin("filesystem").functions.values():
    print(f"  - {func.name}: {func.description}")
# Out:
# Plugin MCP Filesystem ajoute au Kernel
#
# Fonctions disponibles:
#   - list_directory: Liste les fichiers d'un repertoire
#   - read_file: Lit le contenu d'un fichier
#   - write_file: Ecrit du contenu dans un fichier

# %% [markdown]
# ### Interprétation : Bridge MCP → Semantic Kernel
#
# **Sortie obtenue** : Plugin SK exposant 3 fonctions (read_file, list_directory, write_file)
#
# | Fonction SK | Outil MCP source | Type de transformation |
# |-------------|------------------|------------------------|
# | `read_file()` | `read_file` | Wrapper direct |
# | `list_directory()` | `list_directory` | Wrapper avec JSON serialization |
# | `write_file()` | `write_file` | Wrapper direct |
#
# **Architecture du bridge** :
#
# ```
# MCP Server (Node.js)          Python Bridge              Semantic Kernel
# ┌─────────────────┐          ┌──────────────┐          ┌───────────────┐
# │ @anthropic/     │          │ MCP          │          │ Kernel        │
# │ mcp-server-     │  stdio   │ Filesystem   │  @kernel │ Plugin        │
# │ filesystem      │ ──────>  │ Plugin       │ ──────>  │               │
# │                 │          │              │  _function│  Functions    │
# │ - read_file     │          │ - read_file  │          │   disponibles │
# │ - list_dir      │          │ - list_dir   │          │               │
# └─────────────────┘          └──────────────┘          └───────────────┘
# ```
#
# **Points clés** :
#
# 1. **Pattern Adapter** : Le plugin SK adapte le protocole MCP (stdio) en KernelFunctions
# 2. **Annotations Semantic Kernel** : `@kernel_function` + `Annotated[str, "description"]`
# 3. **Gestion d'erreurs** : Les exceptions MCP sont capturées et retournées comme strings
# 4. **Path resolution** : Le bridge gère les chemins relatifs via `root_path`
#
# **Limitations actuelles** :
#
# | Limitation | Impact | Contournement |
# |------------|--------|---------------|
# | Pas d'intégration native SK | Code wrapper manuel requis | Bridge custom comme ci-dessus |
# | Communication stdio | Latence légère | Acceptable pour la plupart des usages |
# | Pas de Resources/Prompts | Seulement les Tools MCP exposés | Enrichir le plugin au besoin |
#
# **Roadmap** : Microsoft travaille sur une intégration native MCP dans SK (Q2 2026)

# %%
# Test du plugin
from semantic_kernel.functions import KernelArguments

# Lister les fichiers du repertoire courant
list_func = kernel.get_function("filesystem", "list_directory")
result = await kernel.invoke(list_func, KernelArguments(path="."))

print("Fichiers dans le repertoire courant:")
print(result)
# Out:
# Fichiers dans le repertoire courant:
# [
#   "01-SemanticKernel-Intro.ipynb",
#   "02-SemanticKernel-Advanced.ipynb",
#   "03-SemanticKernel-Agents.ipynb",
#   "04-SemanticKernel-Filters-Observability.ipynb",
#   "05-SemanticKernel-VectorStores.ipynb",
#   "06-SemanticKernel-ProcessFramework.ipynb",
#   "07-SemanticKernel-MultiModal.ipynb",
#   "08-SemanticKernel-MCP.ipynb",
#   "09-SemanticKernel-Building-CLR.ipynb",
#   "10-SemanticKernel-NotebookMaker.ipynb",
#   "10a-SemanticKernel-NotebookMaker-batch.ipynb",
#   "10b-SemanticKernel-NotebookMaker-batch-parameterized.ipynb",
#   "aspire-otel",
#   "AutoGenNotebookUpdater.cs",
#   "AutoInvokeSKAgentsNotebookUpdater.cs",
#   "Cr\u00e9ateur de mail personnalis\u00e9.ipynb",
#   "DisplayLogger.cs",
#   "DisplayLoggerProvider.cs",
#   "fort-boyard-csharp.ipynb",
#   "fort-boyard-python.ipynb",
#   "GuessingGame.cs",
#   "MANIFEST.md",
#   "Notebook-Generated.ipynb",
#   "Notebook-Template.ipynb",
#   "NotebookExecutor.cs",
# ...

# %% [markdown]
# ### Exercice 2 : Plugin MCP avec validation d'entrees
#
# Les vrais serveurs MCP doivent valider les entrees avant de les traiter. Un bon plugin SK fait de même.
#
# **Objectif** : Implementer un plugin `ValidatedFilesystemPlugin` qui ajoute une couche de validation aux opérations fichier.
#
# **Indices** :
# - # Étape 1 : Verifier que les chemins demandes restent dans le repertoire autorise (securite path traversal)
# - # Étape 2 : Limiter la taille des fichiers lisibles et ecrits
# - # Étape 3 : Utiliser `os.path.realpath()` et comparer avec le `root_path` pour la securite
# - # Indice : Une tentative de path traversal comme `../../etc/passwd` doit etre detectee et rejetee

# %%
class ValidatedFilesystemPlugin:
    """
    TODO etudiant : Plugin SK avec validation de securite pour les operations fichier.
    """
    
    def __init__(self, root_path: str, max_file_size: int = 1_000_000):
        self.root_path = os.path.realpath(root_path)
        self.max_file_size = max_file_size
    
    def _validate_path(self, path: str) -> str:
        """TODO etudiant : Verifier que le chemin est dans le repertoire autorise."""
        return None
    
    @kernel_function(description="Lit un fichier avec validation de securite")
    def safe_read_file(self, path: str) -> str:
        """TODO etudiant : Lire un fichier apres validation."""
        return None

# Test :
# vplugin = ValidatedFilesystemPlugin(root_path=".")
# print(vplugin.safe_read_file("README.md")[:100])
# print(vplugin.safe_read_file("../../etc/passwd"))  # Doit echouer
print("Exercice a completer")
# Out:
# Exercice a completer

# %% [markdown]
# ## 5. Bridge Agent Framework ↔ MCP
#
# Integrons les outils MCP avec l'Agent Framework.

# %%
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.connectors.ai import FunctionChoiceBehavior
from semantic_kernel.contents import ChatHistory

# Configuration du kernel avec MCP plugin
kernel_with_mcp = Kernel()
kernel_with_mcp.add_service(OpenAIChatCompletion(service_id="agent"))
kernel_with_mcp.add_plugin(MCPFilesystemPlugin(root_path="."), plugin_name="filesystem")

# Configuration du function calling
settings = kernel_with_mcp.get_prompt_execution_settings_from_service_id("agent")
settings.function_choice_behavior = FunctionChoiceBehavior.Auto()

# Creation de l'agent avec acces MCP
agent = ChatCompletionAgent(
    kernel=kernel_with_mcp,
    name="FileAssistant",
    instructions="""Tu es un assistant qui peut lire et manipuler des fichiers.
    Utilise les outils filesystem pour repondre aux demandes de l'utilisateur.
    Decris ce que tu fais avant chaque action.""",
    arguments=KernelArguments(settings=settings)
)

print("Agent avec outils MCP cree")
print(f"Outils disponibles: filesystem.read_file, filesystem.list_directory, filesystem.write_file")
# Out:
# Agent avec outils MCP cree
# Outils disponibles: filesystem.read_file, filesystem.list_directory, filesystem.write_file

# %%
# Test de l'agent avec MCP
async def test_mcp_agent(query: str):
    """Teste l'agent avec une requete."""
    chat_history = ChatHistory()
    chat_history.add_user_message(query)
    
    print(f"User: {query}")
    print("-" * 40)
    
    async for content in agent.invoke(chat_history):
        if hasattr(content, 'content') and content.content:
            print(f"Agent: {content.content}")

# Test
try:
    await test_mcp_agent("Liste les fichiers Python dans le repertoire courant")
except Exception as e:
    print(f"Erreur: {e}")
# Out:
# User: Liste les fichiers Python dans le repertoire courant
# ----------------------------------------
# Agent: Je liste le contenu du répertoire courant et je filtre les fichiers avec l’extension `.py`.
#
# Aucun fichier Python (`.py`) n’est présent dans le répertoire courant.

# %% [markdown]
# ### Exercice 3 : Agent multi-outils avec capacites combinees
#
# Un agent MCP puissant combine plusieurs sources d'outils pour repondre a des requêtes complexes.
#
# **Objectif** : Implementer un plugin `DirectoryAnalyzerPlugin` qui combine analyse de fichiers et statistiques.
#
# **Indices** :
# - # Étape 1 : Créer une classe avec des méthodes `count_files_by_extension()` et `get_directory_tree()`
# - # Étape 2 : Utiliser `os.walk()` pour parcourir recursivement les sous-repertoires
# - # Étape 3 : Decorater chaque méthode avec `@kernel_function` pour l'integration SK
# - # Indice : Retourner les résultats sous forme de JSON string pour que le LLM puisse les interpreter

# %%
class DirectoryAnalyzerPlugin:
    """
    TODO etudiant : Plugin SK pour analyser recursivement un repertoire.
    """
    
    @kernel_function(description="Compte les fichiers par extension dans un repertoire")
    def count_files_by_extension(self, path: str = ".") -> str:
        """TODO etudiant : Lister les extensions et leur nombre."""
        return None
    
    @kernel_function(description="Retourne l'arborescence d'un repertoire")
    def get_directory_tree(self, path: str = ".", max_depth: int = 2) -> str:
        """TODO etudiant : Construire un arbre de repertoires."""
        return None

# Test :
# analyzer = DirectoryAnalyzerPlugin()
# print(analyzer.count_files_by_extension("."))
print("Exercice a completer")
# Out:
# Exercice a completer

# %% [markdown]
# ### Interprétation : Agent autonome avec MCP
#
# **Requête utilisateur** : "Liste les fichiers Python dans le répertoire courant"
#
# **Résultat obtenu** : L'agent identifie 19 notebooks `.ipynb` (contenant du Python) au lieu de fichiers `.py`
#
# | Étape | Action de l'agent | Outil utilisé |
# |-------|-------------------|---------------|
# | 1 | Analyse de la requête | LLM (GPT-4) |
# | 2 | Appel `list_directory(path=".")` | MCP filesystem |
# | 3 | Filtrage des fichiers Python | Logique LLM |
# | 4 | Détection des notebooks `.ipynb` | Inference contextuelle |
# | 5 | Réponse structurée avec suggestions | Génération LLM |
#
# **Comportement intelligent** :
#
# 1. **Interprétation sémantique** : "fichiers Python" → inclut les notebooks Jupyter
# 2. **Correction proactive** : Absence de `.py` → liste les `.ipynb` pertinents
# 3. **Suggestion next-step** : "Si tu veux explorer l'un de ces fichiers..."
#
# **Pattern de décision (FunctionChoiceBehavior.Auto)** :
#
# ```
# User Query
#     ↓
# LLM Decision: "Je dois lister les fichiers"
#     ↓
# Tool Sélection: filesystem.list_directory
#     ↓
# Exécution: list_directory(path=".")
#     ↓
# LLM Filtering: "Python files = .py + .ipynb"
#     ↓
# Response Generation
# ```
#
# **Points clés** :
#
# 1. **Autonomie** : L'agent choisit automatiquement `list_directory` sans instruction explicite
# 2. **Contextualisation** : Le LLM comprend que les notebooks Jupyter sont des "fichiers Python"
# 3. **Robustesse** : Absence de `.py` → réponse adaptée, pas d'erreur
# 4. **Conversation naturelle** : Ton professionnel, suggestions proactives
#
# **Comparaison avec un script classique** :
#
# | Approche | Flexibilité | Code requis | Adaptation contexte |
# |----------|-------------|-------------|---------------------|
# | Script Python | Faible | 20-30 lignes | Non |
# | Agent MCP | Élevée | 10 lignes (config) | Oui |
#
# **Cas d'usage réels** :
# - Assistant DevOps : "Trouve les fichiers de config modifiés cette semaine"
# - Data scientist : "Charge le dernier notebook d'analyse de sentiment"
# - QA : "Liste les tests qui ont échoué hier"

# %% [markdown]
# ## 6. Créer un serveur MCP personnalise
#
# Pour exposer vos propres outils via MCP.

# %%
# Exemple de serveur MCP en Python (conceptuel)
# Necessite le package 'mcp'

server_code = '''
from mcp.server import Server, NotificationOptions
from mcp.server.models import InitializationOptions
import mcp.server.stdio
import mcp.types as types

# Creation du serveur
server = Server("my-business-tools")

@server.list_tools()
async def handle_list_tools() -> list[types.Tool]:
    """Liste les outils disponibles."""
    return [
        types.Tool(
            name="calculate_price",
            description="Calcule le prix avec remise",
            inputSchema={
                "type": "object",
                "properties": {
                    "base_price": {"type": "number"},
                    "discount_percent": {"type": "number"}
                },
                "required": ["base_price"]
            }
        ),
        types.Tool(
            name="check_inventory",
            description="Verifie le stock d\'un produit",
            inputSchema={
                "type": "object",
                "properties": {
                    "product_id": {"type": "string"}
                },
                "required": ["product_id"]
            }
        )
    ]

@server.call_tool()
async def handle_call_tool(
    name: str, 
    arguments: dict
) -> list[types.TextContent]:
    """Execute un outil."""
    if name == "calculate_price":
        base = arguments["base_price"]
        discount = arguments.get("discount_percent", 0)
        final = base * (1 - discount/100)
        return [types.TextContent(type="text", text=f"Prix final: {final:.2f}")]
    
    elif name == "check_inventory":
        # Simulation de verification de stock
        product_id = arguments["product_id"]
        stock = 42  # Valeur simulee
        return [types.TextContent(type="text", text=f"Stock de {product_id}: {stock} unites")]
    
    return [types.TextContent(type="text", text="Outil non reconnu")]

async def main():
    async with mcp.server.stdio.stdio_server() as (read, write):
        await server.run(
            read, write,
            InitializationOptions(
                server_name="my-business-tools",
                server_version="1.0.0"
            )
        )

if __name__ == "__main__":
    import asyncio
    asyncio.run(main())
'''

print("Exemple de serveur MCP personnalise:")
print("=" * 60)
print(server_code)
# Out:
# Exemple de serveur MCP personnalise:
# ...
#
# from mcp.server import Server, NotificationOptions
# from mcp.server.models import InitializationOptions
# import mcp.server.stdio
# import mcp.types as types
#
# # Creation du serveur
# server = Server("my-business-tools")
#
# @server.list_tools()
# async def handle_list_tools() -> list[types.Tool]:
#     """Liste les outils disponibles."""
#     return [
#         types.Tool(
#             name="calculate_price",
#             description="Calcule le prix avec remise",
#             inputSchema={
#                 "type": "object",
#                 "properties": {
#                     "base_price": {"type": "number"},
#                     "discount_percent": {"type": "number"}
#                 },
#                 "required": ["base_price"]
#             }
#         ),
#         types.Tool(
#             name="check_inventory",
#             description="Verifie le stock d'un produit",
#             inputSchema={
# ...

# %% [markdown]
# ### Interprétation : Anatomie d'un serveur MCP personnalisé
#
# **Serveur créé** : `my-business-tools` avec 2 outils métier (calculate_price, check_inventory)
#
# | Composant | Rôle | Code clé |
# |-----------|------|----------|
# | **Server** | Instance du serveur MCP | `Server("my-business-tools")` |
# | **@list_tools** | Déclaration des outils disponibles | `types.Tool(name, description, inputSchema)` |
# | **@call_tool** | Logique d'exécution | `handle_call_tool(name, arguments)` |
# | **stdio_server** | Transport (stdin/stdout) | `mcp.server.stdio.stdio_server()` |
#
# **Schéma du flux** :
#
# ```
# Client (Claude Code, SK)
#     ↓ Request via stdio
# ┌─────────────────────────────────┐
# │  MCP Server Process             │
# │  ┌───────────────────────────┐  │
# │  │ @list_tools()             │  │  → Déclaration
# │  │  - calculate_price        │  │
# │  │  - check_inventory        │  │
# │  └───────────────────────────┘  │
# │  ┌───────────────────────────┐  │
# │  │ @call_tool()              │  │  → Exécution
# │  │  if name == "calculate":  │  │
# │  │    return result          │  │
# │  └───────────────────────────┘  │
# └─────────────────────────────────┘
#     ↓ Response via stdio
# Client receives result
# ```
#
# **InputSchema (JSON Schema)** :
#
# | Champ | Type | Required | Description |
# |-------|------|----------|-------------|
# | `base_price` | number | ✓ | Prix de base |
# | `discount_percent` | number | - | Remise (défaut: 0) |
# | `product_id` | string | ✓ | Identifiant produit |
#
# **Points clés** :
#
# 1. **Déclaratif** : Les outils sont déclarés via JSON Schema (validation automatique)
# 2. **Type-safe** : Les arguments sont validés avant l'appel
# 3. **Stateless** : Chaque appel est indépendant (serveur sans état)
# 4. **Async by default** : Toutes les fonctions sont `async` (support concurrence)
#
# **Avantages du pattern MCP** :
#
# | Avantage | Description |
# |----------|-------------|
# | **Réutilisable** | Le serveur fonctionne avec Claude Code, SK, LangChain, etc. |
# | **Testable** | Les outils peuvent être testés indépendamment du LLM |
# | **Versionnable** | `server_version="1.0.0"` permet la compatibilité |
# | **Découvrable** | `@list_tools` expose automatiquement les capacités |
#
# **Cas d'usage typiques** :
#
# - **E-commerce** : calculate_price, check_inventory, process_order
# - **CRM** : get_customer, update_contact, create_ticket
# - **Analytics** : query_metrics, generate_report, export_data
# - **DevOps** : deploy_service, rollback, check_health
#
# **Déploiement** :
#
# ```bash
# # Développement local
# python -m my_server.server
#
# # Production (systemd, Docker)
# ExecStart=/usr/bin/python3 -m my_server.server
# ```
#
# **Sécurité** : Dans un environnement réel, ajouter :
# - Authentification (Bearer token)
# - Rate limiting
# - Validation métier des inputs
# - Logging des appels

# %% [markdown]
# ### Structure d'un serveur MCP
#
# ```
# my-mcp-server/
# ├── pyproject.toml       # Configuration du package
# ├── src/
# │   └── my_server/
# │       ├── __init__.py
# │       └── server.py    # Logique du serveur
# └── README.md
# ```
#
# ### Configuration dans Claude Code
#
# ```json
# {
#   "mcpServers": {
#     "my-business-tools": {
#       "command": "python",
#       "args": ["-m", "my_server.server"]
#     }
#   }
# }
# ```

# %% [markdown]
# ## 7. MCP dans notre infrastructure
#
# Notre repository utilise déjà MCP pour certaines opérations.
#
# ### Serveur MCP Jupyter
#
# Configure dans `notebook-infrastructure/mcp-maintenance/`, ce serveur permet :
#
# | Outil | Description |
# |-------|-------------|
# | `execute_notebook` | Executer un notebook Papermill |
# | `read_cells` | Lire les cellules d'un notebook |
# | `manage_kernel` | Start/stop/restart kernels |
# | `execute_on_kernel` | Executer du code sur un kernel actif |
#
# ### Integration avec NotebookMaker (10)
#
# Le notebook [10-NotebookMaker](10-SemanticKernel-NotebookMaker.ipynb) pourrait etre etendu pour utiliser MCP :
#
# ```python
# # Pattern actuel: Plugins locaux
# @kernel_function
# def update_cell(notebook_path: str, cell_index: int, content: str):
#     # Logique locale
#     pass
#
# # Pattern futur: MCP
# # L'agent appelle directement le serveur MCP Jupyter
# # -> Plus de reutilisation, moins de code custom
# ```

# %% [markdown]
# ## Conclusion
#
# ## Resume des concepts
#
# | Concept | Description | Code cle |
# |---------|-------------|----------|
# | **MCP** | Standard d'interoperabilite | Protocol Client/Server |
# | **Tool** | Fonction executable | `@server.call_tool()` |
# | **Resource** | Donnee accessible | URI-based |
# | **Prompt** | Template reutilisable | Arguments + Template |
# | **SK Bridge** | MCP -> KernelFunction | Plugin wrapper |
#
# ## Points cles a retenir
#
# 1. **MCP = Standard ouvert** - Plugins portables entre frameworks
# 2. **Serveurs existants** - Filesystem, GitHub, Database, etc.
# 3. **SK integration** - MCP tools comme KernelFunctions
# 4. **Agent + MCP** - L'agent choisit les outils automatiquement
# 5. **Serveurs custom** - Exposez votre logique metier via MCP
#
# ## Exercices suggeres
#
# 1. **Wrapper GitHub** : Créer un plugin SK pour le serveur MCP GitHub
# 2. **Agent multi-MCP** : Agent utilisant filesystem + database
# 3. **Serveur metier** : Exposer une API interne via MCP
#
# ## Pour aller plus loin
#
# | Ressource | Description |
# |-----------|-------------|
# | [MCP Specification](https://modelcontextprotocol.io/) | Documentation officielle |
# | [MCP GitHub](https://github.com/anthropics/mcp) | SDK et serveurs |
# | [SK MCP Integration](https://learn.microsoft.com/semantic-kernel) | Documentation SK |
#
# ---
#
# **Navigation** : [<< 07-MultiModal](07-SemanticKernel-MultiModal.ipynb) | [Index](README.md)
#
# ---
#
# ## Fin de la serie Semantic Kernel
#
# Felicitations ! Vous avez complete les 8 notebooks de la serie :
#
# | # | Notebook | Concepts |
# |---|----------|----------|
# | 01 | Fundamentals | Kernel, Services, Plugins, Chat |
# | 02 | Functions | Function Calling moderne, Memory |
# | 03 | Agents | ChatCompletionAgent, AgentGroupChat |
# | 04 | Filters | Filtres, Logging, Observabilite |
# | 05 | VectorStores | RAG, Qdrant, Embeddings |
# | 06 | ProcessFramework | Workflows, Orchestration |
# | 07 | MultiModal | DALL-E, Whisper, Vision |
# | 08 | MCP | Interoperabilite, Serveurs |
#
# **Prochaines étapes** :
# - Explorer [05-NotebookMaker](10-SemanticKernel-NotebookMaker.ipynb) pour un exemple d'agents en production
# - Consulter la [documentation SK](https://learn.microsoft.com/semantic-kernel)
# - Suivre le [blog SK](https://devblogs.microsoft.com/semantic-kernel/) pour les nouveautes
