# %% [markdown]
# # SC-10-Fuzz-Testing - Fuzz Testing
#
# **Navigation** : [Index](../README.md) | [<< Foundry Basics](SC-9-Foundry-Basics.ipynb) | [Formal >>](SC-11-Formal-Verification.ipynb)
#
# ---
#
# ## Objectifs
# 1. Comprendre le **fuzz testing**
# 2. Tester des **invariants**
# 3. Utiliser `vm.assume` pour les contraintes
#
# ### Duree : 40 min
