# %% [markdown]
# # SC-9-Foundry-Basics - Tests avec Foundry
#
# **Navigation** : [Index](../README.md) | [<< LLM](../02-Solidity-Advanced/SC-8b-LLM-Assisted.ipynb) | [Fuzz >>](SC-10-Fuzz-Testing.ipynb)
#
# ---
#
# ## Objectifs
# 1. Ecrire des **tests Foundry** en Solidity
# 2. Utiliser les **assertions**
# 3. Maitriser les **cheatcodes** (vm.prank, vm.deal)
#
# ### Duree : 45 min
