# %% [markdown]
# # SC-6-DeFi-Primitives - Primitives DeFi
#
# **Navigation** : [Index](../README.md) | [<< Tokens](SC-5-Token-Standards.ipynb) | [DAO >>](SC-7-DAO-Governance.ipynb)
#
# ---
#
# ## Objectifs
# 1. Comprendre les **AMM** (x*y=k)
# 2. Implementer des **liquidity pools**
# 3. Creer un systeme de **lending** simple
#
# ### Duree : 55 min
