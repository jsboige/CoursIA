// %% [markdown]
// # Introduction à la planification classique
//
// ## A. Présentation des technologies utilisées
//
// ### 1. Fast Downward
//
// [Fast Downward](https://github.com/aibasel/downward) (cloner le dépôt) est un système de planification automatisée open-source développé en C++. Il implémente différents algorithmes de planification basés sur la recherche heuristique, tels que LAMA, Dijkstra, A*, etc. Fast Downward est utilisé pour résoudre des problèmes de planification dans divers domaines, tels que la planification de tâches, la planification logistique, la planification de ressources, etc.
//
// ### 2. Google OR-Tools
//
// Google OR-Tools est une suite open-source de logiciels d'optimisation qui comprend des solvers pour les problèmes de programmation par contraintes (CSP), la satisfaction de contraintes booléennes (SAT), l'optimisation linéaire (LP), l'optimisation en nombres entiers (MIP), l'optimisation de réseau, et la planification de routes.
// Dans le contexte de ce TP, nous nous intéresserons principalement aux fonctionnalités de planification de OR-Tools, qui fournissent une suite d'algorithmes et de méthodes pour résoudre des problèmes de planification tels que le problème du voyageur de commerce, le problème de sac à dos, et la planification de tâches.
// OR-Tools peut être utilisé en C# via le package Nuget officiel. Il fournit une API C# qui permet d'utiliser les solvers et les méthodes d'optimisation de OR-Tools dans un projet .NET.

// %% [markdown]
// ## B. Problèmes et domaines de planification
//
// ### 1. Qu’est-ce que la planification ?
//
// La planification est une composante essentielle de l'intelligence artificielle (IA). Dans ce cadre, on peut définir la planification comme le processus permettant de déterminer une séquence d'actions qui mènera un agent d'un état initial à un état d'objectif. Ce concept est crucial dans diverses applications de l'IA, notamment dans la robotique, où il est souvent nécessaire d'établir un plan d'action pour un robot qui doit accomplir une série de tâches dans un ordre précis.
//
// La planification en IA se base sur une représentation formalisée d'un problème de planification classique, qui est généralement exprimé comme un triplet : <I, G, D>. Ici, I représente l'état initial de l'agent, G est l'état d'objectif que l'agent veut atteindre, et D décrit la théorie du domaine, c'est-à-dire l'ensemble des actions que l'agent peut entreprendre pour modifier son environnement.
//
// ### 2. Représentation élémentaire : le modèle STRIPS
//
// L'un des modèles de planification les plus fondamentaux en IA est STRIPS (Stanford Research Institute Problem Solver). Dans STRIPS, les actions sont formalisées avec une liste de préconditions et une liste d'effets. Les préconditions doivent être satisfaites pour que l'action puisse être effectuée, et les effets sont les conséquences de l'action sur l'état du monde.
// Une action est définie par :
// - Son nom
// - Ses paramètres
// - Ses préconditions
// - Ses résultats
//
// #### Exemple de STRIPS
//
// Considérons un exemple simple dans le monde des blocs. Supposons que nous ayons un bras robotique qui peut effectuer un certain nombre d'actions spécifiques, comme prendre un bloc, le déposer, le placer sur un autre bloc, ou le retirer d'un autre bloc. Dans STRIPS, chaque action serait représentée avec une liste de préconditions et une liste d'effets. Par exemple, pour l'action de prendre un bloc, les préconditions pourraient inclure le fait que le bras soit libre et que le bloc soit accessible. Les effets de l'action seraient que le bras n'est plus libre (il tient le bloc) et que le bloc n'est plus accessible (il est dans la main du robot).
//
// ##### Quatre actions définies pour le monde des blocs
//
// ```strips
// pickup(X)
// P: gripping() ∧ clear(X) ∧ ontable(X)
// A: gripping(X)
// D: ontable(X) ∧ gripping()
// putdown(X)
// P: gripping(X)
// A: ontable(X) ∧ gripping() ∧ clear(X)
// D: gripping(X)
// stack(X,Y)
// P: gripping(X) ∧ clear(Y)
// A: on(X,Y) ∧ gripping() ∧ clear(X)
// D:gripping(X) ∧ clear(Y)
// unstack(X,Y)
// P: gripping() ∧ clear(X) ∧ on(X,Y)
// A: gripping(X) ∧ clear(Y)
// D: on(X,Y) ∧ gripping()
// ```
//
// ### 3. Les limites de STRIPS
//
//
// STRIPS repose sur plusieurs hypothèses importantes qui simplifient le problème de planification, mais qui peuvent également limiter son applicabilité. Ces hypothèses comprennent l'idée que le monde est statique (à part les actions de l'agent), que toutes les actions sont déterministes et que l'agent a une connaissance parfaite du monde. Cependant, malgré sa utilité, STRIPS présente certaines limites.
//
// #### Le problème du cadre
//
// Le problème du cadre est l'un des problèmes qui peut se poser lors de l'utilisation de STRIPS. Il consiste à énumérer tout ce qui ne change pas dans le problème de planification. Cependant, de nos jours, ce problème est moins significatif car ce qui n'est pas explicitement listé comme changeant (via les listes d'ajout et de suppression d'effets) est supposé ne pas changer.
//
// #### Le problème de qualification
//
// Le problème de qualification est un autre défi dans la représentation des actions dans STRIPS. Il concerne la possibilité d'énumérer chaque précondition nécessaire pour qu'une action puisse être exécutée. Par exemple, dans le cas de l'action "prendre un bloc", il peut être nécessaire de spécifier que le bloc ne doit pas être collé à la table ou cloué à la table, etc. Ce problème reste une difficulté, mais une solution partielle consiste à hiérarchiser les préconditions en déterminant celles qui sont les plus importantes à atteindre.
//
// #### Extensions de STRIPS : PDDL
//
// Pour surmonter ces limites, le langage de définition du domaine de planification (PDDL) a été introduit. PDDL est une extension de STRIPS qui permet une plus grande flexibilité dans la représentation des problèmes de planification. Par exemple, PDDL permet de représenter les actions concurrentes, les actions non déterministes et les négations des effets des actions. De plus, PDDL offre des fonctionnalités supplémentaires, comme la possibilité de représenter les préférences et les contraintes temporelles.
//
// ### 4. PDDL et le problème du Gripper
//
//
// Dans PDDL, chaque action ou opérateur est défini par son nom, ses paramètres, ses préconditions et ses effets. C'est une représentation spéciale conçue pour la planification qui simplifie considérablement le processus en faisant de nombreuses suppositions.
//
//
// #### Domaine (domain.pddl)
//
// ```pddl
// (define (domain gripper-strips)
//   (:predicates (room ?r)
//                (ball ?b)
//                (gripper ?g)
//                (at-robby ?r)
//                (at ?b ?r)
//                (free ?g)
//                (carry ?o ?g))
//   (:action move
//            :parameters (?from ?to)
//            :precondition (and (room ?from) (room ?to) (at-robby ?from))
//            :effect (and (at-robby ?to) (not (at-robby ?from))))
//   (:action pick
//            :parameters (?obj ?room ?gripper)
//            :precondition (and (ball ?obj) (room ?room) (gripper ?gripper) (at ?obj ?room) (at-robby ?room) (free ?gripper))
//            :effect (and (carry ?obj ?gripper) (not (at ?obj ?room)) (not (free ?gripper))))
//   (:action drop
//            :parameters (?obj ?room ?gripper)
//
//
//  :precondition (and (ball ?obj) (room ?room) (gripper ?gripper) (at-robby ?room) (carry ?obj ?gripper))
//            :effect (and (at ?obj ?room) (free ?gripper) (not (carry ?obj ?gripper)))))
// ```
//
// #### Problème (problem.pddl)
//
// ```pddl
// (define (problem strips-gripper2)
//   (:domain gripper-strips)
//   (:objects rooma roomb ball1 ball2 left right)
//   (:init (room rooma) (room roomb) (ball ball1) (ball ball2) (gripper left) (gripper right) (at-robby rooma) (free left) (free right) (at ball1 rooma) (at ball2 rooma))
//   (:goal (at ball1 roomb)))
// ```
//
//
// ## C. Exécution de commandes avec Fast Downward
//
// ### Préparation de l'environnement
// Nous allons créer une méthode en C# pour exécuter des commandes externes comme `fast-downward.py`. Cette méthode utilisera `System.Diagnostics.Process`.

// %%
using System;
using System.Diagnostics;
using System.IO;
using System.IO.Compression;
using System.Net.Http;
using System.Threading.Tasks;

public class FastDownwardRunner
{
    // Configuration: chemin vers Fast Downward (auto-detecte ou telecharge si necessaire)
    private static string _fastDownwardPath = null;

    // Repertoire par defaut pour Fast Downward (relatif au notebook)
    private static readonly string DEFAULT_FD_DIR = Path.Combine(
        Environment.GetFolderPath(Environment.SpecialFolder.UserProfile),
        ".local", "fast-downward"
    );

    // URL de telechargement (release GitHub)
    private const string FD_DOWNLOAD_URL = "https://github.com/aibasel/downward/archive/refs/tags/release-24.06.1.zip";
    private const string FD_VERSION = "24.06.1";

    public static string FastDownwardPath
    {
        get
        {
            if (_fastDownwardPath == null)
            {
                _fastDownwardPath = FindOrDownloadFastDownward();
            }
            return _fastDownwardPath;
        }
        set { _fastDownwardPath = value; }
    }

    private string BasePath { get; }

    public FastDownwardRunner(string basePath = null)
    {
        // Si basePath n'est pas specifie, utiliser le repertoire de Fast Downward
        BasePath = basePath ?? Path.GetDirectoryName(FastDownwardPath);
    }

    private static string FindOrDownloadFastDownward()
    {
        // 1. Verifier la variable d'environnement
        var envPath = Environment.GetEnvironmentVariable("FAST_DOWNWARD_PATH");
        if (!string.IsNullOrEmpty(envPath) && File.Exists(envPath))
        {
            Console.WriteLine($"Fast Downward trouve via FAST_DOWNWARD_PATH: {envPath}");
            return envPath;
        }

        // 2. Verifier le repertoire par defaut
        var defaultPath = Path.Combine(DEFAULT_FD_DIR, $"downward-release-{FD_VERSION}", "fast-downward.py");
        if (File.Exists(defaultPath))
        {
            // Verifier si la compilation a ete effectuee
            var buildsDir = Path.Combine(Path.GetDirectoryName(defaultPath), "builds");
            if (Directory.Exists(buildsDir) && Directory.GetDirectories(buildsDir).Length > 0)
            {
                Console.WriteLine($"Fast Downward trouve et compile: {defaultPath}");
                return defaultPath;
            }
            else
            {
                Console.WriteLine($"Fast Downward trouve mais non compile. Lancement de la compilation...");
                CompileFastDownward(Path.GetDirectoryName(defaultPath));
                return defaultPath;
            }
        }

        // 3. Telecharger automatiquement
        Console.WriteLine($"Fast Downward non trouve. Telechargement en cours...");
        return DownloadFastDownward().Result;
    }

    private static async Task<string> DownloadFastDownward()
    {
        Directory.CreateDirectory(DEFAULT_FD_DIR);
        var zipPath = Path.Combine(DEFAULT_FD_DIR, $"fast-downward-{FD_VERSION}.zip");
        var extractPath = DEFAULT_FD_DIR;

        using (var client = new HttpClient())
        {
            client.Timeout = TimeSpan.FromMinutes(10);
            Console.WriteLine($"Telechargement depuis {FD_DOWNLOAD_URL}...");

            var response = await client.GetAsync(FD_DOWNLOAD_URL);
            response.EnsureSuccessStatusCode();

            using (var fs = new FileStream(zipPath, FileMode.Create))
            {
                await response.Content.CopyToAsync(fs);
            }
        }

        Console.WriteLine("Extraction de l'archive...");
        ZipFile.ExtractToDirectory(zipPath, extractPath, true);
        File.Delete(zipPath);

        var fdDir = Path.Combine(extractPath, $"downward-release-{FD_VERSION}");
        var fdPath = Path.Combine(fdDir, "fast-downward.py");

        if (File.Exists(fdPath))
        {
            Console.WriteLine($"Fast Downward extrait: {fdPath}");

            // Compilation automatique
            Console.WriteLine("Lancement de la compilation automatique...");
            CompileFastDownward(fdDir);

            return fdPath;
        }

        throw new Exception("Echec de l'installation de Fast Downward");
    }

    private static void CompileFastDownward(string fdDir)
    {
        Console.WriteLine($"Compilation de Fast Downward dans {fdDir}...");
        Console.WriteLine("Cette operation peut prendre plusieurs minutes...");

        var buildScript = Path.Combine(fdDir, "build.py");
        if (!File.Exists(buildScript))
        {
            Console.WriteLine($"ERREUR: Script de compilation non trouve: {buildScript}");
            return;
        }

        var processStartInfo = new ProcessStartInfo
        {
            FileName = "python",
            Arguments = $"\"{buildScript}\"",
            RedirectStandardOutput = true,
            RedirectStandardError = true,
            UseShellExecute = false,
            CreateNoWindow = true,
            WorkingDirectory = fdDir
        };

        try
        {
            using (var process = Process.Start(processStartInfo))
            {
                if (process != null)
                {
                    // Lire la sortie en temps reel pour montrer la progression
                    process.OutputDataReceived += (sender, e) => {
                        if (!string.IsNullOrEmpty(e.Data))
                            Console.WriteLine(e.Data);
                    };
                    process.ErrorDataReceived += (sender, e) => {
                        if (!string.IsNullOrEmpty(e.Data))
                            Console.WriteLine($"[stderr] {e.Data}");
                    };

                    process.BeginOutputReadLine();
                    process.BeginErrorReadLine();

                    // Attendre la fin de la compilation (timeout 30 minutes)
                    var completed = process.WaitForExit(30 * 60 * 1000);

                    if (!completed)
                    {
                        process.Kill();
                        Console.WriteLine("ERREUR: Timeout de compilation (30 minutes)");
                        return;
                    }

                    if (process.ExitCode == 0)
                    {
                        Console.WriteLine("Compilation de Fast Downward terminee avec succes!");
                    }
                    else
                    {
                        Console.WriteLine($"ATTENTION: La compilation s'est terminee avec le code {process.ExitCode}");
                        Console.WriteLine("Fast Downward pourrait ne pas fonctionner correctement.");
                    }
                }
            }
        }
        catch (Exception ex)
        {
            Console.WriteLine($"ERREUR lors de la compilation: {ex.Message}");
            Console.WriteLine("Vous pouvez compiler manuellement avec:");
            Console.WriteLine($"  cd \"{fdDir}\" && python build.py");
        }
    }

    public void RunFastDownward(string domainFileRelative, string problemFileRelative, string additionalArgs = "")
    {
        var domainFile = Path.Combine(BasePath, domainFileRelative);
        var problemFile = string.IsNullOrEmpty(problemFileRelative) ? "" : Path.Combine(BasePath, problemFileRelative);

        // Afficher le debut du fichier de domaine
        if (!string.IsNullOrEmpty(domainFileRelative))
            DisplayFileStart(domainFile, "Domaine");

        // Afficher le debut du fichier de probleme
        if (!string.IsNullOrEmpty(problemFileRelative))
            DisplayFileStart(problemFile, "Probleme");

        var args = string.IsNullOrEmpty(problemFile)
            ? $"\"{FastDownwardPath}\" \"{domainFile}\" {additionalArgs}"
            : $"\"{FastDownwardPath}\" \"{domainFile}\" \"{problemFile}\" {additionalArgs}";

        var processStartInfo = new ProcessStartInfo
        {
            FileName = "python",
            Arguments = args,
            RedirectStandardOutput = true,
            RedirectStandardError = true,
            UseShellExecute = false,
            CreateNoWindow = true,
            WorkingDirectory = BasePath
        };

        using (var process = Process.Start(processStartInfo))
        {
            if (process != null)
            {
                using (var reader = process.StandardOutput)
                {
                    string result = reader.ReadToEnd();
                    Console.WriteLine(result);
                }
                var errors = process.StandardError.ReadToEnd();
                if (!string.IsNullOrEmpty(errors))
                    Console.WriteLine($"Erreurs: {errors}");
            }
        }

        // Afficher le contenu du fichier sas_plan
        var sasPlanFile = Path.Combine(BasePath, "sas_plan");
        if (File.Exists(sasPlanFile))
        {
            Console.WriteLine("Contenu de sas_plan:");
            Console.WriteLine(File.ReadAllText(sasPlanFile));
        }
    }

    private void DisplayFileStart(string filePath, string fileType)
    {
        if (File.Exists(filePath))
        {
            Console.WriteLine($"Debut du fichier {fileType} ({filePath}):");
            using (var reader = new StreamReader(filePath))
            {
                for (int i = 0; i < 50; i++)
                {
                    if (reader.EndOfStream) break;
                    Console.WriteLine(reader.ReadLine());
                }
            }
        }
        else
        {
            Console.WriteLine($"Le fichier {fileType} ({filePath}) n'a pas ete trouve.");
        }
    }
}

// Initialisation - le chemin sera auto-detecte ou Fast Downward sera telecharge et compile
Console.WriteLine("Initialisation de Fast Downward...");
Console.WriteLine($"Chemin: {FastDownwardRunner.FastDownwardPath}");
var runner = new FastDownwardRunner();
Console.WriteLine("Runner initialise.");
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-57588.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
//                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
//                     method: 'POST',
//                     cache: 'no-cache',
//                     mode: 'cors',
//                     timeout: 1000,
//                     headers: {
//                         'Content-Type': 'text/plain'
//                     },
//                     body: probingAddresses[i]
//                 }));
//
//                 if (response.status == 200) {
//                     return rootUrl;
//                 }
//             }
//             catch (e) { }
//         }
//     }
// }
//
// function loadDotnetInteractiveApi() {
//     probeAddresses(["http://192.168.0.20:2048/", "http://172.22.208.1:2048/", "http://172.26.176.1:2048/", "http://127.0.0.1:2048/"])
//         .then((root) => {
//         // use probing to find host url and api resources
//         // load interactive helpers and language services
//         let dotnetInteractiveRequire = require.config({
//         context: '57588.Microsoft.DotNet.Interactive.Http.HttpPort',
//                 paths:
//             {
//                 'dotnet-interactive': `${root}resources`
//                 }
//         }) || require;
//
//             window.dotnetInteractiveRequire = dotnetInteractiveRequire;
//
//             window.configureRequireFromExtension = function(extensionName, extensionCacheBuster) {
//                 let paths = {};
//                 paths[extensionName] = `${root}extensions/${extensionName}/resources/`;
//
//                 let internalRequire = require.config({
//                     context: extensionCacheBuster,
//                     paths: paths,
//                     urlArgs: `cacheBuster=${extensionCacheBuster}`
//                     }) || require;
//
//                 return internalRequire
//             };
//
//             dotnetInteractiveRequire([
//                     'dotnet-interactive/dotnet-interactive'
//                 ],
//                 function (dotnet) {
//                     dotnet.init(window);
//                 },
//                 function (error) {
//                     console.log(error);
//                 }
//             );
//         })
//         .catch(error => {console.log(error);});
//     }
//
// // ensure `require` is available globally
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     let require_script = document.createElement('script');
//     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
//     require_script.setAttribute('type', 'text/javascript');
//
//
//     require_script.onload = function() {
//         loadDotnetInteractiveApi();
//     };
//
//     document.getElementsByTagName('head')[0].appendChild(require_script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
//     </script>
// </div>
// Initialisation de Fast Downward...
// Fast Downward trouve et compile: C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py
// Chemin: C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py
// Runner initialise.

// %% [markdown]
// ### Interprétation de l'initialisation
//
// **Objectif** : Cette cellule met en place la classe `FastDownwardRunner` qui automatise l'installation, la compilation et l'exécution de Fast Downward.
//
// **Points clés** :
// - **Auto-détection** : Le système cherche Fast Downward dans la variable d'environnement `FAST_DOWNWARD_PATH`, puis dans `~/.local/fast-downward`
// - **Téléchargement automatique** : Si Fast Downward n'est pas trouvé, il est automatiquement téléchargé depuis GitHub (release 24.06.1)
// - **Compilation automatique** : Le script `build.py` est exécuté pour compiler les binaires C++ de Fast Downward
// - **Affichage des fichiers** : Les méthodes permettent d'afficher les fichiers PDDL (domaine et problème) avant l'exécution
//
// > **Note technique** : La compilation peut prendre plusieurs minutes lors de la première exécution. Un timeout de 30 minutes est configuré pour gérer les compilations longues.

// %% [markdown]
// ## III. Syntaxe de ligne de commande de Fast Downward
//
// Fast Downward propose une interface en ligne de commande flexible pour paramétrer ses différents composants. Les paramètres peuvent être spécifiés par mot-clé ou par position, et certains ont des valeurs par défaut. Voici quelques exemples de commandes et options disponibles.
//
// Fast Downward propose une fonctionnalité permettant de spécifier différentes options en fonction des propriétés du fichier d'entrée, comme la sélection des heuristiques à utiliser en fonction du coût unitaire ou non unitaire des actions. Cette option est conditionnée par des sélecteurs tels que --if-unit-cost.
//
// Fast Downward offre également la possibilité de définir des variables pour des objets qui doivent être utilisés à plusieurs reprises, par exemple une heuristique ou une LandmarkFactory. Ces variables peuvent être définies avec let(name, definition, expression).
//
// Les options de commande comprennent des options pour sélectionner les composants du planificateur à exécuter (translation, recherche), des limites de temps et de mémoire, des options pour le fichier de plan et de nombreuses autres options.
//
//
// ### Options de traduction
//
// Fast Downward permet une grande flexibilité dans la façon dont le problème de planification est traduit en une tâche de planification abstraite qui peut être résolue par l'algorithme de recherche. Les options de traduction permettent de spécifier des options telles que l'encodage complet et d'autres options spécifiques à la tâche de planification.

// %% [markdown]
// ### Interprétation de la traduction avec encodage complet
//
// Cette commande exécute Fast Downward sur le problème du **Gripper** avec l'option `--full-encoding`, qui génère une représentation complète de la tâche de planification.
//
// **Résultat attendu** :
// - Traduction du PDDL vers le format SAS+ interne de Fast Downward
// - Génération des fichiers intermédiaires (`output.sas`)
// - Affichage des statistiques de traduction (nombre de variables, domaines, opérateurs)
//
// > **Astuce** : L'encodage complet peut augmenter la taille de la représentation mais facilite certains types d'heuristiques.

// %%
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", 
    "misc/tests/benchmarks/gripper/prob01.pddl", "--translate-options --full-encoding");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --full-encoding --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.003s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.016s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.003s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.001s wall-clock]
// Instantiating: [0.016s CPU, 0.005s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// using full encoding: between-variable mutex information skipped.
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 7 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 0 of 0 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 28
// Translator goal facts: 4
// Translator mutex groups: 0
// Translator total mutex groups size: 0
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 237
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.016s CPU, 0.012s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// Erreurs: search needs --alias, --portfolio, or search options

// %% [markdown]
// ### Interprétation de la recherche avec l'heuristique FF
//
// Cette cellule démontre l'utilisation de **l'heuristique FF (Fast Forward)** combinée avec une recherche **eager greedy**.
//
// **Composants de la commande** :
// - `--heuristic "h=ff()"` : Définit une heuristique FF nommée `h`
// - `--search "eager_greedy([h])"` : Utilise une recherche gloutonne qui évalue immédiatement tous les successeurs
//
// **Stratégie** :
// | Algorithme | Heuristique | Garantie d'optimalité |
// |------------|-------------|----------------------|
// | Eager Greedy | FF | Non (mais rapide) |
//
// L'heuristique FF estime le coût en relaxant les effets négatifs (relaxation de suppression). Elle est **non admissible** mais très efficace en pratique.

// %% [markdown]
// ### Options de recherche
//
// Les options de recherche spécifient l'algorithme de recherche à utiliser pour résoudre la tâche de planification. Fast Downward supporte une grande variété d'algorithmes de recherche, y compris A*, chaînage avant, chaînage arrière et planification d'ordre partiel.
//
// Les options de recherche permettent également de spécifier des options spécifiques à l'algorithme de recherche, telles que les heuristiques à utiliser.

// %% [markdown]
// ### Utilisation des limites de ressources
//
// Cette cellule exécute Fast Downward avec des contraintes explicites de **temps** et de **mémoire** pour les phases de traduction et de recherche.
//
// **Paramètres configurés** :
//
// | Phase | Limite de temps | Limite mémoire |
// |-------|-----------------|----------------|
// | Traduction | 300s (5 min) | 4000 MB |
// | Recherche | 500s (8.3 min) | 8000 MB |
//
// > **Cas d'usage** : Ces limites sont essentielles pour les compétitions de planification ou pour éviter qu'un problème difficile ne monopolise les ressources indéfiniment.

// %%
// Exemple d'exécution avec les options de recherche
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", 
"misc/tests/benchmarks/gripper/prob01.pddl", 
"--search-options --heuristic \"h=ff()\" --search \"eager_greedy([h])\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.005s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.016s CPU, 0.005s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.001s wall-clock]
// Instantiating: [0.016s CPU, 0.007s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.016s CPU, 0.018s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --heuristic 'h=ff()' --search 'eager_greedy([h])' --internal-plan-file sas_plan < output.sas
// [t=0.006343s, 1716 KB] reading input...
// [t=0.008360s, 1716 KB] done reading input!
// [t=0.023841s, 1920 KB] Simplifying 66 unary operators... done! [66 unary operators]
// [t=0.023892s, 1920 KB] time to simplify: 0.000056s
// [t=0.023903s, 1920 KB] Initializing additive heuristic...
// [t=0.023907s, 1920 KB] Initializing FF heuristic...
// [t=0.024368s, 1920 KB] Building successor generator...done!
// [t=0.024593s, 1920 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.024597s, 1920 KB] time for successor generation creation: 0.000203s
// [t=0.024604s, 1920 KB] Variables: 7
// [t=0.024609s, 1920 KB] FactPairs: 24
// [t=0.024611s, 1920 KB] Bytes per state: 4
// [t=0.024629s, 1920 KB] Conducting best first search without reopening closed nodes, (real) bound = 2147483647
// [t=0.024768s, 1920 KB] New best heuristic value for ff: 9
// [t=0.024773s, 1920 KB] g=0, 1 evaluated, 0 expanded
// [t=0.024780s, 1920 KB] Initial heuristic value for ff: 9
// [t=0.024782s, 1920 KB] pruning method: none
// [t=0.024907s, 1920 KB] New best heuristic value for ff: 8
// [t=0.024911s, 1920 KB] g=1, 3 evaluated, 1 expanded
// [t=0.024971s, 1920 KB] New best heuristic value for ff: 7
// [t=0.024975s, 1920 KB] g=3, 31 evaluated, 10 expanded
// [t=0.024986s, 1920 KB] New best heuristic value for ff: 6
// [t=0.024990s, 1920 KB] g=5, 33 evaluated, 12 expanded
// [t=0.025026s, 1920 KB] New best heuristic value for ff: 5
// [t=0.025030s, 1920 KB] g=7, 51 evaluated, 19 expanded
// [t=0.025045s, 1920 KB] New best heuristic value for ff: 4
// [t=0.025047s, 1920 KB] g=9, 56 evaluated, 21 expanded
// [t=0.025057s, 1920 KB] New best heuristic value for ff: 3
// [t=0.025060s, 1920 KB] g=10, 61 evaluated, 22 expanded
// [t=0.025065s, 1920 KB] New best heuristic value for ff: 2
// [t=0.025067s, 1920 KB] g=11, 62 evaluated, 23 expanded
// [t=0.025077s, 1920 KB] New best heuristic value for ff: 1
// [t=0.025080s, 1920 KB] g=12, 63 evaluated, 24 expanded
// [t=0.025094s, 1920 KB] New best heuristic value for ff: 0
// [t=0.025097s, 1920 KB] g=13, 68 evaluated, 25 expanded
// [t=0.025100s, 1920 KB] Solution found!
// [t=0.025102s, 1920 KB] Actual search time: 0.000319s
// Peak memory: 1920 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--heuristic', 'h=ff()', '--search', 'eager_greedy([h])', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// ### Pourquoi exécuter deux fois la même commande ?
//
// Cette cellule est identique à la précédente et semble redondante. Dans un contexte pédagogique, on pourrait :
// - **Comparer différentes limites** pour observer l'impact sur les performances
// - **Tester la reproductibilité** des résultats
//
// **Suggestion** : Modifier les limites pour illustrer l'impact sur le temps de résolution ou le nombre de nœuds explorés.

// %% [markdown]
// ### Utilisation d'un alias
//
// Fast Downward permet l'utilisation d'alias pour spécifier des configurations de planification prédéfinies. Ces alias peuvent être spécifiés à l'aide de l'option --alias sur la ligne de commande.

// %%
// Exemple d'exécution avec des limites de temps et de mémoire
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "", "--translate-time-limit 300 --translate-memory-limit 4000 --search-time-limit 500 --search-memory-limit 8000");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing task
// 	->Parsing problem name
// Invalid problem name definition
// Syntax: (problem NAME)
// Got: ['domain', 'gripper-strips']
// translate exit code: 31
//
// Driver aborting after translate

// %% [markdown]
// ### Interprétation de l'exécution avec portfolio
//
// Cette commande illustre l'utilisation d'un **portfolio de configurations**, une stratégie avancée utilisée dans les compétitions de planification.
//
// **Principe** :
// - Le fichier `seq_opt_fdss_1.py` contient plusieurs configurations de planification
// - Chaque configuration est exécutée séquentiellement jusqu'à trouver une solution
// - Le temps total est limité à 30 minutes
//
// **Avantages** :
// - **Robustesse** : Différentes configurations excellent sur différents types de problèmes
// - **Optimisation** : Combine les forces de multiples heuristiques
//
// > **Note** : Les portfolios sont la stratégie standard des planificateurs performants aux compétitions IPC (International Planning Competition).

// %% [markdown]
// ### Limites de temps et de mémoire
//
// Fast Downward permet de spécifier des limites de temps et de mémoire pour les différentes composantes du planificateur. Ces limites peuvent être spécifiées à l'aide des options de ligne de commande --translate-time-limit, --translate-memory-limit, --search-time-limit, et --search-memory-limit.

// %% [markdown]
// ### Résultat avec l'heuristique additive
//
// **Caractéristiques** :
// - **Non admissible** : Peut surestimer le coût (la solution peut ne pas être optimale)
// - **Rapide à calculer** : Somme simple des coûts des sous-buts
// - **Opérateurs préférés** : Identifie les actions utiles
//
// L'heuristique additive tend à **surestimer** car elle suppose que tous les sous-buts sont indépendants, ce qui n'est souvent pas le cas (ils peuvent interagir positivement).

// %% [markdown]
// ### Exploration des heuristiques de Fast Downward
//
// Dans les cellules suivantes, nous allons explorer systématiquement différentes **heuristiques** implémentées dans Fast Downward. Chaque heuristique possède des propriétés différentes :
//
// | Propriété | Signification |
// |-----------|---------------|
// | **Admissible** | Ne surestime jamais le coût réel (garantit optimalité avec A*) |
// | **Cohérente** | Respecte l'inégalité triangulaire (admissibilité + propriété plus forte) |
// | **Sûre** | Fonctionne correctement avec axiomes et effets conditionnels |
// | **Opérateurs préférés** | Identifie des actions prometteuses pour accélérer la recherche |
//
// Nous commençons avec l'**heuristique additive (add)**, qui combine les coûts estimés des sous-buts de manière additive.

// %% [markdown]
// ### Résultat avec l'heuristique aveugle
//
// **Caractéristiques** :
// - **Admissible et cohérente** : Garantit l'optimalité avec A*
// - **Très simple** : Retourne le coût minimal d'action (souvent 1)
// - **Pas d'opérateurs préférés** : Aucune guidance
//
// Cette heuristique est équivalente à une **recherche de Dijkstra** (ou recherche en largeur si tous les coûts sont unitaires). Elle explore exhaustivement sans guidance, ce qui est très lent mais garantit l'optimalité.

// %%
// Exemple d'exécution avec des limites de temps et de mémoire
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "", "--translate-time-limit 300 --translate-memory-limit 4000 --search-time-limit 500 --search-memory-limit 8000");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing task
// 	->Parsing problem name
// Invalid problem name definition
// Syntax: (problem NAME)
// Got: ['domain', 'gripper-strips']
// translate exit code: 31
//
// Driver aborting after translate

// %% [markdown]
// ### Résultat avec l'heuristique context-enhanced additive
//
// **Amélioration de l'heuristique additive** :
// - Prend en compte les **interactions entre sous-buts**
// - Plus précise que l'heuristique additive simple
// - Toujours **non admissible**, mais meilleure guidance en pratique
//
// L'heuristique CEA analyse le contexte dans lequel les actions sont appliquées pour affiner l'estimation des coûts.

// %% [markdown]
// ### Validation de plan
//
// Fast Downward peut également valider les plans générés en utilisant l'outil de validation VAL.

// %% [markdown]
// ### Résultat avec l'heuristique merge-and-shrink
//
// **Technique sophistiquée** basée sur l'abstraction :
// - **Merge** : Fusion de variables de planification
// - **Shrink** : Réduction de l'espace d'états par bisimulation
//
// **Propriétés** :
// - **Admissible et cohérente** : Optimalité garantie
// - **Configurable** : Nombreuses stratégies de fusion et réduction
// - **Coûteuse** : Précalcul parfois long mais estimation très précise
//
// Cette heuristique est particulièrement efficace sur les problèmes avec de nombreuses interactions entre variables.

// %% [markdown]
// ### Utilisation d'un portfolio
//
// Fast Downward supporte l'utilisation de portfolios de configurations de planification. Un portfolio est un ensemble de configurations de planification qui sont exécutées en séquence ou en parallèle pour résoudre une tâche de planification. L'utilisation d'un portfolio peut être spécifiée à l'aide de l'option --portfolio sur la ligne de commande.

// %% [markdown]
// ### Transition vers les heuristiques classiques
//
// Les cellules suivantes explorent des heuristiques plus classiques et largement utilisées dans la littérature de planification automatique. Nous commençons par l'**heuristique de graphe causal (cg)**, qui analyse les dépendances causales entre variables.

// %%
// Exemple d'exécution avec un portfolio
runner.RunFastDownward("", "", "--portfolio driver/portfolios/seq_opt_fdss_1.py --search-time-limit 30m output.sas");
// Out:
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 14, in main
//     args = arguments.parse_args()
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\arguments.py", line 501, in parse_args
//     _set_components_and_inputs(parser, args)
//     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\arguments.py", line 239, in _set_components_and_inputs
//     _set_components_automatically(parser, args)
//     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\arguments.py", line 215, in _set_components_automatically
//     if len(args.filenames) == 1 and _looks_like_search_input(args.filenames[0]):
//                                     ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\arguments.py", line 201, in _looks_like_search_input
//     with open(filename) as input_file:
//          ~~~~^^^^^^^^^^
// PermissionError: [Errno 13] Permission denied: 'C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1'

// %% [markdown]
// ### Résultat avec l'heuristique de graphe causal
//
// **Analyse des dépendances causales** :
// - Construit un **graphe de causalité** entre variables
// - Estime le coût en analysant les chemins dans ce graphe
// - **Opérateurs préférés** : Identifie les actions qui résolvent les sous-buts critiques
//
// **Limitations** :
// - **Non admissible** : Peut surestimer ou sous-estimer
// - **Axiomes** : Support rudimentaire
//
// Cette heuristique est efficace sur les problèmes où les dépendances causales sont structurées.

// %% [markdown]
// ### Heuristiques avancées de Fast Downward
//
// L'efficacité de Fast Downward réside dans son usage d'heuristiques de pointe pour guider la recherche de solutions aux problèmes de planification. Quelques-unes de ces heuristiques avancées sont décrites ci-dessous.
//
// Chacune de ces heuristiques possède des avantages et des limites en termes d'efficacité, d'admissibilité, de cohérence, et d'identification d'opérateurs privilégiés. Le choix de l'heuristique à utiliser dépend donc du problème de planification spécifique à résoudre.
//
//
// #### Additive Heuristic
//
// L'heuristique additive (add) est une méthode permettant de combiner les estimations de plusieurs heuristiques pour une meilleure estimation. Elle n'est ni admissible, ni cohérente, mais identifie les opérateurs privilégiés.
//
// Les options de cette heuristique incluent le niveau de verbosité, la transformation de la tâche, et le cache des estimations.

// %% [markdown]
// ### Résultat avec l'heuristique FF (Fast Forward)
//
// **Une des heuristiques les plus populaires** :
// - Basée sur la **relaxation de suppression** (ignore les effets négatifs)
// - Construit un graphe de planification relaxé pour estimer le coût
// - **Opérateurs préférés** : Actions apparaissant dans le plan relaxé
//
// **Performance** :
// - **Rapide à calculer** : Complexité polynomiale
// - **Non admissible** mais très efficace en pratique
// - **Référence** dans les compétitions de planification
//
// L'heuristique FF a révolutionné la planification automatique dans les années 2000 en permettant de résoudre des problèmes auparavant intractables.

// %%
// Exemple d'exécution avec l'heuristique additive
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(add ())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.008s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
// Preparing model... [0.000s CPU, 0.001s wall-clock]
// Generated 24 rules.
// Computing model... [0.016s CPU, 0.003s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.002s wall-clock]
// Instantiating: [0.016s CPU, 0.009s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.002s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.003s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.002s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.003s wall-clock]
// Done! [0.016s CPU, 0.028s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(add ())' --internal-plan-file sas_plan < output.sas
// [t=0.001129s, 1688 KB] reading input...
// [t=0.002583s, 1688 KB] done reading input!
// [t=0.007696s, 1888 KB] Simplifying 66 unary operators... done! [66 unary operators]
// [t=0.007745s, 1888 KB] time to simplify: 0.000053s
// [t=0.007758s, 1888 KB] Initializing additive heuristic...
// [t=0.008232s, 1888 KB] Building successor generator...done!
// [t=0.008277s, 1888 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.008280s, 1888 KB] time for successor generation creation: 0.000028s
// [t=0.008287s, 1888 KB] Variables: 7
// [t=0.008290s, 1888 KB] FactPairs: 24
// [t=0.008292s, 1888 KB] Bytes per state: 4
// [t=0.008311s, 1888 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.008354s, 1888 KB] New best heuristic value for add: 12
// [t=0.008358s, 1888 KB] g=0, 1 evaluated, 0 expanded
// [t=0.008361s, 1888 KB] f = 12, 1 evaluated, 0 expanded
// [t=0.008367s, 1888 KB] Initial heuristic value for add: 12
// [t=0.008372s, 1888 KB] pruning method: none
// [t=0.008388s, 1888 KB] New best heuristic value for add: 11
// [t=0.008393s, 1888 KB] g=1, 3 evaluated, 1 expanded
// [t=0.008416s, 1888 KB] New best heuristic value for add: 10
// [t=0.008420s, 1888 KB] g=2, 11 evaluated, 2 expanded
// [t=0.008433s, 1888 KB] New best heuristic value for add: 9
// [t=0.008437s, 1888 KB] g=3, 15 evaluated, 3 expanded
// [t=0.008510s, 1888 KB] f = 13, 38 evaluated, 21 expanded
// [t=0.008517s, 1888 KB] New best heuristic value for add: 8
// [t=0.008519s, 1888 KB] g=5, 39 evaluated, 22 expanded
// [t=0.008535s, 1888 KB] New best heuristic value for add: 7
// [t=0.008537s, 1888 KB] g=6, 45 evaluated, 23 expanded
// [t=0.008546s, 1888 KB] New best heuristic value for add: 6
// [t=0.008571s, 1888 KB] g=7, 48 evaluated, 24 expanded
// [t=0.008878s, 1888 KB] f = 14, 134 evaluated, 80 expanded
// [t=0.008891s, 1888 KB] New best heuristic value for add: 5
// [t=0.008893s, 1888 KB] g=9, 135 evaluated, 81 expanded
// [t=0.008905s, 1888 KB] New best heuristic value for add: 4
// [t=0.008908s, 1888 KB] g=10, 139 evaluated, 82 expanded
// [t=0.008916s, 1888 KB] New best heuristic value for add: 3
// [t=0.008920s, 1888 KB] g=11, 141 evaluated, 83 expanded
// [t=0.008945s, 1888 KB] New best heuristic value for add: 2
// [t=0.008949s, 1888 KB] g=11, 150 evaluated, 85 expanded
// [t=0.008956s, 1888 KB] New best heuristic value for add: 1
// [t=0.008964s, 1888 KB] g=12, 151 evaluated, 86 expanded
// [t=0.008978s, 1888 KB] New best heuristic value for add: 0
// [t=0.008982s, 1888 KB] g=13, 156 evaluated, 87 expanded
// [t=0.008986s, 1888 KB] Solution found!
// [t=0.008989s, 1888 KB] Actual search time: 0.000616s
// Peak memory: 1888 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(add ())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// ### Résultat avec l'heuristique goalcount
//
// **Heuristique la plus simple** :
// - Compte simplement le **nombre de sous-buts non atteints**
// - Ignore complètement les coûts des actions
// - **Très rapide** mais peu informative
//
// **Utilité** :
// - Référence de base pour comparer d'autres heuristiques
// - Utile pour les problèmes où tous les sous-buts sont également difficiles
//
// Cette heuristique donne essentiellement une borne inférieure triviale sur le nombre d'actions restantes.

// %% [markdown]
// #### Blind Heuristic
//
// L'heuristique aveugle (blind) retourne le coût de l'action la moins chère pour les états non-cibles et 0 pour les états cibles. Elle supporte les coûts d'action, les effets conditionnels, et les axiomes. C'est une heuristique admissible, cohérente et sûre, mais elle ne permet pas d'identifier des opérateurs privilégiés.

// %% [markdown]
// ### Résultat avec l'heuristique h^m
//
// **Heuristique basée sur les ensembles de faits** :
// - Considère les interactions entre **m faits simultanément**
// - Plus m est grand, plus l'heuristique est précise (mais coûteuse)
// - **Admissible et cohérente** pour m suffisamment grand
//
// **Compromis** :
// | m | Précision | Complexité |
// |---|-----------|------------|
// | 1 | Faible | O(n) |
// | 2 | Moyenne | O(n²) |
// | 3+ | Élevée | Exponentielle |
//
// En pratique, m=1 ou m=2 sont les plus utilisés. Pour m → ∞, on obtient l'heuristique h* (optimale).

// %%
// Exemple d'exécution avec l'heuristique aveugle
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(blind())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.000s wall-clock]
// Instantiating: [0.000s CPU, 0.003s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.009s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(blind())' --internal-plan-file sas_plan < output.sas
// [t=0.001339s, 1684 KB] reading input...
// [t=0.002320s, 1684 KB] done reading input!
// [t=0.005616s, 1876 KB] Initializing blind search heuristic...
// [t=0.005720s, 1876 KB] Building successor generator...done!
// [t=0.005776s, 1876 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.005782s, 1876 KB] time for successor generation creation: 0.000041s
// [t=0.005793s, 1876 KB] Variables: 7
// [t=0.005801s, 1876 KB] FactPairs: 24
// [t=0.005806s, 1876 KB] Bytes per state: 4
// [t=0.005844s, 1876 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.005872s, 1876 KB] New best heuristic value for blind: 1
// [t=0.005880s, 1876 KB] g=0, 1 evaluated, 0 expanded
// [t=0.005885s, 1876 KB] f = 1, 1 evaluated, 0 expanded
// [t=0.005897s, 1876 KB] Initial heuristic value for blind: 1
// [t=0.005904s, 1876 KB] pruning method: none
// [t=0.005941s, 1876 KB] f = 2, 10 evaluated, 1 expanded
// [t=0.005995s, 1876 KB] f = 3, 30 evaluated, 10 expanded
// [t=0.006054s, 1876 KB] f = 4, 46 evaluated, 30 expanded
// [t=0.006127s, 1876 KB] f = 5, 74 evaluated, 46 expanded
// [t=0.006229s, 1876 KB] f = 6, 104 evaluated, 74 expanded
// [t=0.006395s, 1876 KB] f = 7, 134 evaluated, 104 expanded
// [t=0.006578s, 1876 KB] f = 8, 182 evaluated, 134 expanded
// [t=0.006750s, 1876 KB] f = 9, 218 evaluated, 182 expanded
// [t=0.006878s, 1876 KB] f = 10, 234 evaluated, 218 expanded
// [t=0.006961s, 1876 KB] f = 11, 246 evaluated, 234 expanded
// [t=0.007005s, 1876 KB] New best heuristic value for blind: 0
// [t=0.007018s, 1876 KB] g=11, 253 evaluated, 238 expanded
// [t=0.007030s, 1876 KB] Solution found!
// [t=0.007043s, 1876 KB] Actual search time: 0.001136s
// Peak memory: 1876 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(blind())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// ### Résultat avec l'heuristique hmax
//
// **Variante conservative de l'heuristique additive** :
// - Prend le **maximum** des coûts des sous-buts au lieu de la somme
// - **Admissible** : Ne surestime jamais le coût
// - Plus précise que goalcount, moins que h^m
//
// **Formule** :
// ```
// h_add(s) = Σ coût(sous-but_i)  → peut surestimer
// h_max(s) = max(coût(sous-but_i))  → admissible mais moins informative
// ```
//
// L'heuristique hmax est utile quand on cherche l'optimalité avec une heuristique simple et rapide.

// %% [markdown]
// #### Context-enhanced Additive Heuristic
//
// L'heuristique context-enhanced additive (cea) est une heuristique non admissible, non cohérente et non sûre, mais qui identifie les opérateurs privilégiés. Comme pour les heuristiques précédentes, elle offre des options pour le niveau de verbosité, la transformation de la tâche, et le cache des estimations.

// %% [markdown]
// ### Transition vers les techniques avancées
//
// Les sections suivantes explorent des techniques de planification plus sophistiquées qui combinent plusieurs approches :
// - **Relaxations et repères** (landmarks)
// - **Adaptation dynamique des coûts**
// - **Bases de données de motifs** (Pattern Databases)
//
// Ces techniques représentent l'état de l'art en planification classique et sont utilisées dans les planificateurs gagnants des compétitions.

// %%
// Exemple d'exécution avec l'heuristique context-enhanced additive
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(cea())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.016s CPU, 0.003s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.005s wall-clock]
// Preparing model... [0.000s CPU, 0.001s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.002s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.000s wall-clock]
// Instantiating: [0.000s CPU, 0.009s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.016s CPU, 0.016s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(cea())' --internal-plan-file sas_plan < output.sas
// [t=0.001638s, 1692 KB] reading input...
// [t=0.002186s, 1692 KB] done reading input!
// [t=0.003663s, 1888 KB] Initializing context-enhanced additive heuristic...
// [t=0.006304s, 1888 KB] Building successor generator...done!
// [t=0.006335s, 1888 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.006338s, 1888 KB] time for successor generation creation: 0.000020s
// [t=0.006343s, 1888 KB] Variables: 7
// [t=0.006345s, 1888 KB] FactPairs: 24
// [t=0.006346s, 1888 KB] Bytes per state: 4
// [t=0.006360s, 1888 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.006387s, 1888 KB] New best heuristic value for cea: 12
// [t=0.006391s, 1888 KB] g=0, 1 evaluated, 0 expanded
// [t=0.006394s, 1888 KB] f = 12, 1 evaluated, 0 expanded
// [t=0.006398s, 1888 KB] Initial heuristic value for cea: 12
// [t=0.006400s, 1888 KB] pruning method: none
// [t=0.006417s, 1888 KB] New best heuristic value for cea: 11
// [t=0.006421s, 1888 KB] g=1, 3 evaluated, 1 expanded
// [t=0.006458s, 1888 KB] New best heuristic value for cea: 10
// [t=0.006461s, 1888 KB] g=2, 11 evaluated, 2 expanded
// [t=0.006483s, 1888 KB] New best heuristic value for cea: 9
// [t=0.006486s, 1888 KB] g=3, 15 evaluated, 3 expanded
// [t=0.006564s, 1888 KB] f = 13, 38 evaluated, 21 expanded
// [t=0.006572s, 1888 KB] New best heuristic value for cea: 8
// [t=0.006574s, 1888 KB] g=5, 39 evaluated, 22 expanded
// [t=0.006591s, 1888 KB] New best heuristic value for cea: 7
// [t=0.006593s, 1888 KB] g=6, 45 evaluated, 23 expanded
// [t=0.006602s, 1888 KB] New best heuristic value for cea: 6
// [t=0.006604s, 1888 KB] g=7, 48 evaluated, 24 expanded
// [t=0.006864s, 1888 KB] f = 14, 134 evaluated, 80 expanded
// [t=0.006874s, 1888 KB] New best heuristic value for cea: 5
// [t=0.006878s, 1888 KB] g=9, 135 evaluated, 81 expanded
// [t=0.006890s, 1888 KB] New best heuristic value for cea: 4
// [t=0.006894s, 1888 KB] g=10, 139 evaluated, 82 expanded
// [t=0.006903s, 1888 KB] New best heuristic value for cea: 3
// [t=0.006905s, 1888 KB] g=11, 141 evaluated, 83 expanded
// [t=0.006929s, 1888 KB] New best heuristic value for cea: 2
// [t=0.006932s, 1888 KB] g=11, 150 evaluated, 85 expanded
// [t=0.006937s, 1888 KB] New best heuristic value for cea: 1
// [t=0.006939s, 1888 KB] g=12, 151 evaluated, 86 expanded
// [t=0.006951s, 1888 KB] New best heuristic value for cea: 0
// [t=0.006954s, 1888 KB] g=13, 156 evaluated, 87 expanded
// [t=0.006957s, 1888 KB] Solution found!
// [t=0.006959s, 1888 KB] Actual search time: 0.000558s
// Peak memory: 1888 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(cea())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// ### Résultat avec l'heuristique LM-cut
//
// **Technique de pointe basée sur les landmarks** :
// - Un **landmark** est un fait qui doit obligatoirement être vrai dans tout plan solution
// - **LM-cut** identifie des ensembles de landmarks et calcule une borne inférieure optimale
// - **Admissible** : Garantit l'optimalité
//
// **Principe** :
// 1. Identifier un "cut" (coupure) dans le graphe de relaxation
// 2. Chaque cut correspond à un ensemble d'actions dont au moins une doit être exécutée
// 3. Sommer les coûts minimaux de chaque cut
//
// Cette heuristique est considérée comme l'une des plus précises pour la planification optimale, au prix d'un temps de calcul plus élevé.

// %% [markdown]
// #### Merge-and-shrink Heuristic
//
// L'heuristique merge-and-shrink (merge_and_shrink) est basée sur l'algorithme décrit dans plusieurs articles scientifiques. Cette heuristique est configurable avec plusieurs stratégies de fusion et de réduction. Elle supporte les coûts d'action et les effets conditionnels, mais pas les axiomes. Elle est admissible, cohérente, sûre, mais ne permet pas d'identifier des opérateurs privilégiés.

// %% [markdown]
// ### Résultat avec l'adaptation de coûts
//
// **Transformation de la tâche** : Cette technique modifie dynamiquement les coûts des actions pour améliorer l'heuristique.
//
// **Options d'adaptation** :
//
// | Mode | Description |
// |------|-------------|
// | `normal` | Coûts originaux (pas de transformation) |
// | `one` | Tous les coûts deviennent 1 (optimal pour longueur de plan) |
// | `plusone` | Tous les coûts augmentent de 1 |
//
// **Intérêt** :
// - `one` : Utile pour minimiser le nombre d'actions
// - `plusone` : Évite les cycles à coût nul dans certains domaines
//
// Cette cellule combine LM-cut avec la transformation `one`, optimisant pour le plan le plus court.

// %%
// Exemple d'exécution avec l'heuristique merge-and-shrink
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(merge_and_shrink ())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.001s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.016s CPU, 0.000s wall-clock]
// Instantiating: [0.016s CPU, 0.003s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.016s CPU, 0.008s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(merge_and_shrink ())' --internal-plan-file sas_plan < output.sas
// [t=0.000990s, 1684 KB] reading input...
// [t=0.001475s, 1684 KB] done reading input!
// Remove intermediate file output.sas
// search exit code: 33
//
// Driver aborting after search
// Erreurs: Traceback:
//   Start semantic analysis
//   -> Checking Plugin: astar
//   -> Checking the 1. positional argument (eval)
//   -> Checking Plugin: merge_and_shrink
//   -> Checking the default for argument 'merge_strategy'.
//
// Missing argument is mandatory!
// Usage error occurred.

// %% [markdown]
// ### Résultat avec les Pattern Databases (iPDB)
//
// **Concept des Pattern Databases** :
// - Un **pattern** est un sous-ensemble de variables du problème
// - Une **PDB** précalcule les coûts optimaux pour toutes les combinaisons de valeurs du pattern
// - Utilisé comme table de lookup pendant la recherche
//
// **Incrémental (iPDB)** :
// - Génère des patterns dynamiquement pendant la recherche
// - Ajoute de nouveaux patterns quand les patterns existants ne sont pas assez informatifs
//
// **Avantages** :
// - **Admissible** : Garantit l'optimalité
// - **Précis** : Stocke les coûts exacts pour les sous-problèmes
// - **Incrémental** : S'adapte au problème spécifique
//
// Cette technique est particulièrement efficace sur les problèmes avec une structure factorisée.

// %% [markdown]
// #### Operator-counting Heuristic
//
// L'heuristique operator-counting (operatorcounting) est une heuristique qui calcule un programme linéaire à chaque état. Elle est admissible, cohérente, sûre, mais ne permet pas d'identifier des opérateurs privilégiés. Elle supporte les coûts d'action, mais pas les effets conditionnels ni les axiomes, en raison de la limitation des générateurs de contraintes actuellement implémentés.

// %% [markdown]
// ### Résultat avec merge-and-shrink avancé
//
// Cette configuration illustre une utilisation sophistiquée de **merge-and-shrink** avec plusieurs paramètres :
//
// **Paramètres utilisés** :
//
// | Paramètre | Valeur | Description |
// |-----------|--------|-------------|
// | `merge_strategy` | `merge_precomputed` | Utilise un arbre de fusion précalculé |
// | `merge_tree` | `linear(reverse_level)` | Fusion linéaire en ordre inverse de niveau |
// | `shrink_strategy` | `shrink_bisimulation(greedy=true)` | Réduction par bisimulation gloutonne |
// | `label_reduction` | `exact(before_shrinking=true)` | Réduction exacte des étiquettes avant réduction |
//
// **Compromis** :
// - **Précalcul** : Plus long au démarrage
// - **Précision** : Heuristique très informative
// - **Mémoire** : Peut consommer beaucoup de RAM sur gros problèmes
//
// Cette configuration est typique des planificateurs optimaux dans les compétitions.

// %% [markdown]
// ## Conclusion et synthèse
//
// ### Récapitulatif des heuristiques explorées
//
// Ce notebook a présenté un panorama complet des heuristiques de Fast Downward :
//
// | Heuristique | Admissible | Rapide | Opérateurs préférés | Meilleur usage |
// |-------------|------------|--------|---------------------|----------------|
// | **blind** | ✓ | ✓ | ✗ | Référence de base |
// | **goalcount** | ✗ | ✓✓ | ✗ | Problèmes simples |
// | **add** | ✗ | ✓ | ✓ | Recherche rapide non optimale |
// | **cea** | ✗ | ✓ | ✓ | Amélioration de add |
// | **cg** | ✗ | ✓ | ✓ | Problèmes avec dépendances causales |
// | **ff** | ✗ | ✓ | ✓ | Recherche gloutonne efficace |
// | **hmax** | ✓ | ✓ | ✗ | Recherche optimale simple |
// | **h^m** | ✓ (m grand) | ✗ | ✗ | Recherche optimale avec interactions |
// | **lmcut** | ✓ | ✗ | ✗ | Recherche optimale précise |
// | **merge_and_shrink** | ✓ | ✗ | ✗ | Problèmes factorisés |
// | **iPDB** | ✓ | ✗ | ✗ | Problèmes avec structure |
//
// ### Stratégies de sélection
//
// **Pour la planification optimale** (garantir le plan le moins coûteux) :
// - `lmcut` : Meilleur compromis précision/temps
// - `merge_and_shrink` : Si le problème a une structure factorisée
// - `iPDB` : Si suffisamment de mémoire disponible
//
// **Pour la planification satisfiable** (trouver rapidement un plan) :
// - `ff` + `eager_greedy` : Stratégie standard, très efficace
// - `cea` + `lazy_greedy` : Alternative robuste
// - `cg` : Pour problèmes avec dépendances causales fortes
//
// **Pour les compétitions** :
// - Utiliser un **portfolio** qui combine plusieurs configurations
// - Tester différentes heuristiques sur des benchmarks représentatifs
//
// ### Techniques avancées couvertes
//
// - **Relaxations** : Simplifications du problème (suppression d'effets négatifs)
// - **Landmarks** : Identification de faits obligatoires
// - **Pattern Databases** : Précalcul de coûts pour sous-problèmes
// - **Adaptation de coûts** : Transformation dynamique pour améliorer l'heuristique
// - **Merge-and-shrink** : Abstraction par fusion et réduction
//
// ### Ressources pour aller plus loin
//
// - [Documentation officielle Fast Downward](https://www.fast-downward.org/)
// - [Compétitions IPC](https://www.icaps-conference.org/competitions/)
// - [Benchmarks PDDL](https://github.com/aibasel/downward-benchmarks)
// - Articles fondateurs : FF (Hoffmann & Nebel, 2001), LM-cut (Helmert & Domshlak, 2009)
//
// Fast Downward reste l'un des planificateurs les plus performants et flexibles pour la planification classique, grâce à sa riche collection d'heuristiques et de techniques d'optimisation.

// %% [markdown]
// #### Heuristique de Graphique Causal (cg)
//
// L'heuristique de Graphique Causal (cg) est configurable avec plusieurs paramètres comme la taille maximale du cache (max_cache_size), la verbosité (verbosity), la transformation de tâche (transform) et la mise en cache des estimations (cache_estimates). Elle supporte les coûts d'action, les effets conditionnels et les axiomes, bien que le traitement des axiomes puisse être rudimentaire. Elle n'est ni admissible, ni cohérente, ni sûre, mais elle prend en charge les opérateurs préférés.

// %%
// Exemple d'exécution avec l'heuristique de Graphique Causal
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(cg())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.001s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.000s wall-clock]
// Instantiating: [0.000s CPU, 0.003s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.008s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(cg())' --internal-plan-file sas_plan < output.sas
// [t=0.001117s, 1680 KB] reading input...
// [t=0.001620s, 1680 KB] done reading input!
// [t=0.003109s, 1880 KB] Initializing causal graph heuristic...
// [t=0.003126s, 1880 KB] Initializing heuristic cache... building causal graph...done! [t=0.000019s]
// [t=0.003163s, 1880 KB] done!
// [t=0.003264s, 1880 KB] Building successor generator...done!
// [t=0.003294s, 1880 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.003297s, 1880 KB] time for successor generation creation: 0.000023s
// [t=0.003303s, 1880 KB] Variables: 7
// [t=0.003305s, 1880 KB] FactPairs: 24
// [t=0.003309s, 1880 KB] Bytes per state: 4
// [t=0.003320s, 1880 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.003347s, 1880 KB] New best heuristic value for cg: 12
// [t=0.003351s, 1880 KB] g=0, 1 evaluated, 0 expanded
// [t=0.003354s, 1880 KB] f = 12, 1 evaluated, 0 expanded
// [t=0.003360s, 1880 KB] Initial heuristic value for cg: 12
// [t=0.003362s, 1880 KB] pruning method: none
// [t=0.003375s, 1880 KB] New best heuristic value for cg: 8
// [t=0.003379s, 1880 KB] g=1, 2 evaluated, 1 expanded
// [t=0.003413s, 1880 KB] New best heuristic value for cg: 7
// [t=0.003417s, 1880 KB] g=2, 11 evaluated, 3 expanded
// [t=0.003429s, 1880 KB] New best heuristic value for cg: 6
// [t=0.003436s, 1880 KB] g=3, 15 evaluated, 4 expanded
// [t=0.003507s, 1880 KB] f = 13, 38 evaluated, 26 expanded, 4 reopened
// [t=0.003522s, 1880 KB] New best heuristic value for cg: 5
// [t=0.003525s, 1880 KB] g=6, 45 evaluated, 28 expanded, 4 reopened
// [t=0.003531s, 1880 KB] New best heuristic value for cg: 4
// [t=0.003533s, 1880 KB] g=7, 48 evaluated, 29 expanded, 4 reopened
// [t=0.003725s, 1880 KB] f = 14, 134 evaluated, 102 expanded, 22 reopened
// [t=0.003738s, 1880 KB] New best heuristic value for cg: 3
// [t=0.003740s, 1880 KB] g=10, 139 evaluated, 104 expanded, 22 reopened
// [t=0.003746s, 1880 KB] New best heuristic value for cg: 2
// [t=0.003747s, 1880 KB] g=11, 141 evaluated, 105 expanded, 22 reopened
// [t=0.003763s, 1880 KB] New best heuristic value for cg: 1
// [t=0.003765s, 1880 KB] g=12, 151 evaluated, 108 expanded, 22 reopened
// [t=0.003773s, 1880 KB] New best heuristic value for cg: 0
// [t=0.003775s, 1880 KB] g=13, 156 evaluated, 109 expanded, 22 reopened
// [t=0.003779s, 1880 KB] Solution found!
// [t=0.003782s, 1880 KB] Actual search time: 0.000419s
// Peak memory: 1880 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(cg())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Heuristique FF
//
// L'heuristique FF partage de nombreuses caractéristiques avec l'heuristique de Graphique Causal, y compris la prise en charge des coûts d'action, des effets conditionnels et des axiomes. Elle est sûre pour les tâches sans axiomes et supporte également les opérateurs préférés. Comme l'heuristique de Graphique Causal, elle n'est ni admissible, ni cohérente.

// %%
// Exemple d'exécution avec l'heuristique FF
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(ff())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.001s wall-clock]
// Instantiating: [0.000s CPU, 0.004s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.011s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(ff())' --internal-plan-file sas_plan < output.sas
// [t=0.005376s, 1684 KB] reading input...
// [t=0.005918s, 1684 KB] done reading input!
// [t=0.013007s, 1888 KB] Simplifying 66 unary operators... done! [66 unary operators]
// [t=0.013449s, 1888 KB] time to simplify: 0.000479s
// [t=0.013585s, 1888 KB] Initializing additive heuristic...
// [t=0.013629s, 1888 KB] Initializing FF heuristic...
// [t=0.013964s, 1888 KB] Building successor generator...done!
// [t=0.014264s, 1888 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.014292s, 1888 KB] time for successor generation creation: 0.000235s
// [t=0.014355s, 1888 KB] Variables: 7
// [t=0.014392s, 1888 KB] FactPairs: 24
// [t=0.014428s, 1888 KB] Bytes per state: 4
// [t=0.014550s, 1888 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.014758s, 1888 KB] New best heuristic value for ff: 9
// [t=0.014797s, 1888 KB] g=0, 1 evaluated, 0 expanded
// [t=0.014835s, 1888 KB] f = 9, 1 evaluated, 0 expanded
// [t=0.014899s, 1888 KB] Initial heuristic value for ff: 9
// [t=0.014936s, 1888 KB] pruning method: none
// [t=0.015092s, 1888 KB] New best heuristic value for ff: 8
// [t=0.015134s, 1888 KB] g=1, 3 evaluated, 1 expanded
// [t=0.015868s, 1888 KB] f = 10, 30 evaluated, 9 expanded
// [t=0.015943s, 1888 KB] New best heuristic value for ff: 7
// [t=0.015977s, 1888 KB] g=3, 31 evaluated, 10 expanded
// [t=0.016139s, 1888 KB] New best heuristic value for ff: 6
// [t=0.016218s, 1888 KB] g=4, 34 evaluated, 13 expanded
// [t=0.016336s, 1888 KB] New best heuristic value for ff: 5
// [t=0.016373s, 1888 KB] g=5, 37 evaluated, 14 expanded
// [t=0.018461s, 1888 KB] f = 11, 110 evaluated, 76 expanded
// [t=0.018540s, 1888 KB] New best heuristic value for ff: 4
// [t=0.018579s, 1888 KB] g=7, 111 evaluated, 77 expanded
// [t=0.018729s, 1888 KB] New best heuristic value for ff: 3
// [t=0.018765s, 1888 KB] g=8, 116 evaluated, 78 expanded
// [t=0.018835s, 1888 KB] New best heuristic value for ff: 2
// [t=0.018871s, 1888 KB] g=9, 117 evaluated, 79 expanded
// [t=0.018941s, 1888 KB] New best heuristic value for ff: 1
// [t=0.018976s, 1888 KB] g=10, 118 evaluated, 80 expanded
// [t=0.019119s, 1888 KB] New best heuristic value for ff: 0
// [t=0.019154s, 1888 KB] g=11, 123 evaluated, 81 expanded
// [t=0.019189s, 1888 KB] Solution found!
// [t=0.019236s, 1888 KB] Actual search time: 0.004277s
// Peak memory: 1888 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(ff())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Heuristique de Compte d'Objectif (goalcount)
//
// L'heuristique de Compte d'Objectif ignore les coûts d'action par conception, mais supporte les effets conditionnels et les axiomes. Elle est sûre, mais n'est ni admissible, ni cohérente, et ne supporte pas les opérateurs préférés.

// %%
// Exemple d'exécution avec l'heuristique de Compte d'Objectif
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(goalcount())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.016s CPU, 0.007s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.001s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.010s wall-clock]
// Preparing model... [0.000s CPU, 0.001s wall-clock]
// Generated 24 rules.
// Computing model... [0.016s CPU, 0.004s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.002s wall-clock]
// Instantiating: [0.016s CPU, 0.019s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.002s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.003s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.002s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.001s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.031s CPU, 0.034s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(goalcount())' --internal-plan-file sas_plan < output.sas
// [t=0.004508s, 1692 KB] reading input...
// [t=0.006233s, 1692 KB] done reading input!
// [t=0.010694s, 1876 KB] Initializing goal count heuristic...
// [t=0.010843s, 1876 KB] Building successor generator...done!
// [t=0.010938s, 1876 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.010947s, 1876 KB] time for successor generation creation: 0.000068s
// [t=0.010962s, 1876 KB] Variables: 7
// [t=0.010969s, 1876 KB] FactPairs: 24
// [t=0.010974s, 1876 KB] Bytes per state: 4
// [t=0.011029s, 1876 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.011075s, 1876 KB] New best heuristic value for goalcount: 4
// [t=0.011088s, 1876 KB] g=0, 1 evaluated, 0 expanded
// [t=0.011097s, 1876 KB] f = 4, 1 evaluated, 0 expanded
// [t=0.011121s, 1876 KB] Initial heuristic value for goalcount: 4
// [t=0.011128s, 1876 KB] pruning method: none
// [t=0.011184s, 1876 KB] f = 5, 10 evaluated, 1 expanded
// [t=0.011271s, 1876 KB] f = 6, 30 evaluated, 10 expanded
// [t=0.011291s, 1876 KB] New best heuristic value for goalcount: 3
// [t=0.011299s, 1876 KB] g=3, 31 evaluated, 11 expanded
// [t=0.011418s, 1876 KB] f = 7, 50 evaluated, 34 expanded
// [t=0.011522s, 1876 KB] New best heuristic value for goalcount: 2
// [t=0.011534s, 1876 KB] g=5, 77 evaluated, 40 expanded
// [t=0.011743s, 1876 KB] f = 8, 110 evaluated, 80 expanded
// [t=0.011964s, 1876 KB] f = 9, 158 evaluated, 110 expanded
// [t=0.012219s, 1876 KB] f = 10, 218 evaluated, 158 expanded
// [t=0.012254s, 1876 KB] New best heuristic value for goalcount: 1
// [t=0.012267s, 1876 KB] g=9, 219 evaluated, 159 expanded
// [t=0.012589s, 1876 KB] f = 11, 238 evaluated, 222 expanded
// [t=0.012638s, 1876 KB] New best heuristic value for goalcount: 0
// [t=0.012645s, 1876 KB] g=11, 249 evaluated, 228 expanded
// [t=0.012653s, 1876 KB] Solution found!
// [t=0.012660s, 1876 KB] Actual search time: 0.001528s
// Peak memory: 1876 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(goalcount())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Heuristique h^m
//
// L'heuristique h^m, où 'm' est la taille du sous-ensemble, supporte les coûts d'action mais ignore les effets conditionnels et les axiomes. Elle est admissible, cohérente et sûre pour les tâches sans effets conditionnels ou axiomes, mais ne prend pas en charge les opérateurs préférés.

// %%
// Exemple d'exécution avec l'heuristique h^m
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(hm())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.003s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.000s wall-clock]
// Instantiating: [0.000s CPU, 0.005s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.010s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(hm())' --internal-plan-file sas_plan < output.sas
// [t=0.001258s, 1688 KB] reading input...
// [t=0.001850s, 1688 KB] done reading input!
// [t=0.003507s, 1884 KB] Using h^2.
// [t=0.003528s, 1884 KB] The implementation of the h^m heuristic is preliminary.
// [t=0.003532s, 1884 KB] It is SLOOOOOOOOOOOW.
// [t=0.003534s, 1884 KB] Please do not use this for comparison!
// [t=0.003648s, 1884 KB] Building successor generator...done!
// [t=0.003684s, 1884 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.003687s, 1884 KB] time for successor generation creation: 0.000027s
// [t=0.003694s, 1884 KB] Variables: 7
// [t=0.003699s, 1884 KB] FactPairs: 24
// [t=0.003702s, 1884 KB] Bytes per state: 4
// [t=0.003715s, 1884 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.009260s, 1884 KB] New best heuristic value for hm: 4
// [t=0.009268s, 1884 KB] g=0, 1 evaluated, 0 expanded
// [t=0.009276s, 1884 KB] f = 4, 1 evaluated, 0 expanded
// [t=0.009284s, 1884 KB] Initial heuristic value for hm: 4
// [t=0.009286s, 1884 KB] pruning method: none
// [t=0.067878s, 1884 KB] f = 6, 10 evaluated, 1 expanded
// [t=0.210075s, 1884 KB] f = 8, 30 evaluated, 10 expanded
// [t=0.601874s, 1884 KB] f = 9, 74 evaluated, 38 expanded
// [t=0.852904s, 1884 KB] f = 10, 98 evaluated, 50 expanded
// [t=1.363038s, 1884 KB] f = 11, 158 evaluated, 110 expanded
// [t=1.381312s, 1884 KB] New best heuristic value for hm: 3
// [t=1.381330s, 1884 KB] g=8, 160 evaluated, 111 expanded
// [t=1.390205s, 1884 KB] New best heuristic value for hm: 2
// [t=1.390249s, 1884 KB] g=9, 161 evaluated, 112 expanded
// [t=1.398090s, 1884 KB] New best heuristic value for hm: 1
// [t=1.398097s, 1884 KB] g=10, 162 evaluated, 113 expanded
// [t=1.421920s, 1884 KB] New best heuristic value for hm: 0
// [t=1.421934s, 1884 KB] g=11, 167 evaluated, 114 expanded
// [t=1.421938s, 1884 KB] Solution found!
// [t=1.421942s, 1884 KB] Actual search time: 1.412654s
// Peak memory: 1884 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(hm())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Heuristique Max (hmax)
//
// L'heuristique Max est similaire à l'heuristique h^m en ce sens qu'elle supporte les coûts d'action et les effets conditionnels, et peut gérer les axiomes à un degré limité. Elle est admissible, cohérente et sûre pour les tâches sans axiomes, mais ne prend pas en charge les opérateurs préférés.

// %%
// Exemple d'exécution avec l'heuristique Max
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(hmax())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.001s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.000s wall-clock]
// Instantiating: [0.000s CPU, 0.003s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.001s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.008s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(hmax())' --internal-plan-file sas_plan < output.sas
// [t=0.001196s, 1684 KB] reading input...
// [t=0.001642s, 1684 KB] done reading input!
// [t=0.003055s, 1868 KB] Simplifying 66 unary operators... done! [66 unary operators]
// [t=0.003113s, 1868 KB] time to simplify: 0.000061s
// [t=0.003128s, 1868 KB] Initializing HSP max heuristic...
// [t=0.003167s, 1868 KB] Building successor generator...done!
// [t=0.003195s, 1868 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.003198s, 1868 KB] time for successor generation creation: 0.000021s
// [t=0.003203s, 1868 KB] Variables: 7
// [t=0.003207s, 1868 KB] FactPairs: 24
// [t=0.003209s, 1868 KB] Bytes per state: 4
// [t=0.003231s, 1868 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.003251s, 1868 KB] New best heuristic value for hmax: 2
// [t=0.003255s, 1868 KB] g=0, 1 evaluated, 0 expanded
// [t=0.003258s, 1868 KB] f = 2, 1 evaluated, 0 expanded
// [t=0.003263s, 1868 KB] Initial heuristic value for hmax: 2
// [t=0.003267s, 1868 KB] pruning method: none
// [t=0.003292s, 1868 KB] f = 3, 10 evaluated, 1 expanded
// [t=0.003332s, 1868 KB] f = 4, 30 evaluated, 9 expanded
// [t=0.003337s, 1868 KB] f = 5, 30 evaluated, 10 expanded
// [t=0.003375s, 1868 KB] f = 6, 46 evaluated, 30 expanded
// [t=0.003464s, 1868 KB] f = 7, 98 evaluated, 50 expanded
// [t=0.003541s, 1868 KB] f = 8, 128 evaluated, 98 expanded
// [t=0.003603s, 1868 KB] f = 9, 158 evaluated, 110 expanded
// [t=0.003711s, 1868 KB] f = 10, 218 evaluated, 158 expanded
// [t=0.003725s, 1868 KB] New best heuristic value for hmax: 1
// [t=0.003727s, 1868 KB] g=9, 219 evaluated, 159 expanded
// [t=0.003785s, 1868 KB] f = 11, 238 evaluated, 206 expanded
// [t=0.003793s, 1868 KB] New best heuristic value for hmax: 0
// [t=0.003795s, 1868 KB] g=11, 240 evaluated, 207 expanded
// [t=0.003797s, 1868 KB] Solution found!
// [t=0.003799s, 1868 KB] Actual search time: 0.000531s
// Peak memory: 1868 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(hmax())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Heuristique de Partage des Coûts des Points de Repère (landmark_cost_partitioning)
//
// L'heuristique de Partage des Coûts des Points de Repère est une heuristique admissible qui utilise un ensemble de points de repère pour établir des coûts. Elle supporte les coûts d'action et les effets conditionnels, mais pas les axiomes. Cette heuristique est sûre et peut utiliser des opérateurs préférés si cela est activé.

// %% [markdown]
// ### Utilisation avancée de Fast Downward
//
// Fast Downward est un outil de planification classique flexible et puissant qui offre de nombreuses fonctionnalités avancées pour optimiser et personnaliser le processus de planification. Pour tirer pleinement parti de ces fonctionnalités, il est important de comprendre comment elles fonctionnent et comment les utiliser efficacement. Voici une description détaillée de quelques-unes de ces fonctionnalités.
//
// #### Relaxations et repères
//
// Fast Downward propose des fonctionnalités pour travailler avec des relaxations de suppression et des repères. La relaxation de suppression peut être utile pour calculer l'heuristique optimale h+. Fast Downward calcule également un ensemble de repères pour chaque état à l'aide de la méthode LM-cut, qui peut être très utile pour guider la recherche de planification.

// %%
// Exemple d'exécution avec la relaxation LM-cut
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(lmcut())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.001s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.000s wall-clock]
// Instantiating: [0.000s CPU, 0.003s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.008s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(lmcut())' --internal-plan-file sas_plan < output.sas
// [t=0.001012s, 1680 KB] reading input...
// [t=0.001482s, 1680 KB] done reading input!
// [t=0.002868s, 1864 KB] Initializing landmark cut heuristic...
// [t=0.002937s, 1864 KB] Building successor generator...done!
// [t=0.002986s, 1864 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.002989s, 1864 KB] time for successor generation creation: 0.000026s
// [t=0.002996s, 1864 KB] Variables: 7
// [t=0.002999s, 1864 KB] FactPairs: 24
// [t=0.003001s, 1864 KB] Bytes per state: 4
// [t=0.003036s, 1864 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.003067s, 1864 KB] New best heuristic value for lmcut: 9
// [t=0.003072s, 1864 KB] g=0, 1 evaluated, 0 expanded
// [t=0.003074s, 1864 KB] f = 9, 1 evaluated, 0 expanded
// [t=0.003082s, 1864 KB] Initial heuristic value for lmcut: 9
// [t=0.003084s, 1864 KB] pruning method: none
// [t=0.003108s, 1864 KB] New best heuristic value for lmcut: 7
// [t=0.003112s, 1864 KB] g=1, 3 evaluated, 1 expanded
// [t=0.003275s, 1864 KB] New best heuristic value for lmcut: 6
// [t=0.003280s, 1864 KB] g=3, 30 evaluated, 9 expanded
// [t=0.003290s, 1864 KB] New best heuristic value for lmcut: 5
// [t=0.003293s, 1864 KB] g=4, 31 evaluated, 10 expanded
// [t=0.003689s, 1864 KB] f = 10, 100 evaluated, 65 expanded
// [t=0.003904s, 1864 KB] f = 11, 134 evaluated, 92 expanded
// [t=0.003918s, 1864 KB] New best heuristic value for lmcut: 4
// [t=0.003921s, 1864 KB] g=7, 135 evaluated, 93 expanded
// [t=0.003929s, 1864 KB] New best heuristic value for lmcut: 3
// [t=0.003932s, 1864 KB] g=8, 136 evaluated, 94 expanded
// [t=0.004034s, 1864 KB] New best heuristic value for lmcut: 2
// [t=0.004039s, 1864 KB] g=9, 156 evaluated, 104 expanded
// [t=0.004047s, 1864 KB] New best heuristic value for lmcut: 1
// [t=0.004049s, 1864 KB] g=10, 157 evaluated, 105 expanded
// [t=0.004070s, 1864 KB] New best heuristic value for lmcut: 0
// [t=0.004074s, 1864 KB] g=11, 162 evaluated, 106 expanded
// [t=0.004078s, 1864 KB] Solution found!
// [t=0.004081s, 1864 KB] Actual search time: 0.000996s
// Peak memory: 1864 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(lmcut())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Adaptation des coûts des actions
//
// Fast Downward offre un moyen de moduler les coûts des actions via la transformation de la tâche racine, nommée "Cost-adapted task". Cette fonctionnalité offre trois options d'adaptation des coûts : "normal", "one" et "plusone". La capacité à adapter les coûts des actions peut avoir un impact significatif sur la qualité des plans produits.

// %%
// Exemple d'exécution avec l'adaptation des coûts des actions
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(lmcut(transform=adapt_costs(one)))\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.001s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.000s wall-clock]
// Instantiating: [0.000s CPU, 0.003s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.008s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(lmcut(transform=adapt_costs(one)))' --internal-plan-file sas_plan < output.sas
// [t=0.001026s, 1672 KB] reading input...
// [t=0.001487s, 1672 KB] done reading input!
// [t=0.002936s, 1860 KB] Initializing landmark cut heuristic...
// [t=0.002986s, 1860 KB] Building successor generator...done!
// [t=0.003023s, 1860 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.003025s, 1860 KB] time for successor generation creation: 0.000025s
// [t=0.003031s, 1860 KB] Variables: 7
// [t=0.003033s, 1860 KB] FactPairs: 24
// [t=0.003035s, 1860 KB] Bytes per state: 4
// [t=0.003054s, 1860 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.003081s, 1860 KB] New best heuristic value for lmcut: 9
// [t=0.003111s, 1860 KB] g=0, 1 evaluated, 0 expanded
// [t=0.003115s, 1860 KB] f = 9, 1 evaluated, 0 expanded
// [t=0.003123s, 1860 KB] Initial heuristic value for lmcut: 9
// [t=0.003127s, 1860 KB] pruning method: none
// [t=0.003153s, 1860 KB] New best heuristic value for lmcut: 7
// [t=0.003156s, 1860 KB] g=1, 3 evaluated, 1 expanded
// [t=0.003312s, 1860 KB] New best heuristic value for lmcut: 6
// [t=0.003316s, 1860 KB] g=3, 30 evaluated, 9 expanded
// [t=0.003326s, 1860 KB] New best heuristic value for lmcut: 5
// [t=0.003328s, 1860 KB] g=4, 31 evaluated, 10 expanded
// [t=0.003679s, 1860 KB] f = 10, 100 evaluated, 65 expanded
// [t=0.003856s, 1860 KB] f = 11, 134 evaluated, 92 expanded
// [t=0.003867s, 1860 KB] New best heuristic value for lmcut: 4
// [t=0.003869s, 1860 KB] g=7, 135 evaluated, 93 expanded
// [t=0.003876s, 1860 KB] New best heuristic value for lmcut: 3
// [t=0.003878s, 1860 KB] g=8, 136 evaluated, 94 expanded
// [t=0.003961s, 1860 KB] New best heuristic value for lmcut: 2
// [t=0.003965s, 1860 KB] g=9, 156 evaluated, 104 expanded
// [t=0.003972s, 1860 KB] New best heuristic value for lmcut: 1
// [t=0.003974s, 1860 KB] g=10, 157 evaluated, 105 expanded
// [t=0.003992s, 1860 KB] New best heuristic value for lmcut: 0
// [t=0.003994s, 1860 KB] g=11, 162 evaluated, 106 expanded
// [t=0.003997s, 1860 KB] Solution found!
// [t=0.004000s, 1860 KB] Actual search time: 0.000871s
// Peak memory: 1860 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(lmcut(transform=adapt_costs(one)))', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Optimisation post-hoc et équations d'état
//
// Fast Downward peut utiliser des bases de données de motifs (PDB) pour calculer des contraintes d'optimisation post-hoc. Ces contraintes peuvent aider à maximiser l'utilité des PDB pour la planification classique. De plus, Fast Downward ajoute une contrainte permanente pour chaque fait qui tient compte du changement net du fait.

// %%
// Exemple d'exécution avec l'optimisation post-hoc et les équations d'état
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(ipdb())\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.001s wall-clock]
// Instantiating: [0.000s CPU, 0.003s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.000s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.000s CPU, 0.009s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(ipdb())' --internal-plan-file sas_plan < output.sas
// [t=0.001214s, 1688 KB] reading input...
// [t=0.001760s, 1688 KB] done reading input!
// [t=0.003571s, 1884 KB] Initializing canonical PDB heuristic...
// [t=0.003591s, 1884 KB] Generating patterns using: hill climbing pattern collection generator
// [t=0.006214s, 1884 KB] Done calculating initial pattern collection: 0.002623s
// [t=0.006232s, 1884 KB] Average operator cost: 1.000000
// [t=0.006241s, 1884 KB] building causal graph...done! [t=0.000023s]
// [t=0.006455s, 1884 KB] Done calculating initial candidate PDBs
// [t=0.008723s, 1936 KB] found a better pattern with improvement 576
// [t=0.012051s, 1936 KB] found a better pattern with improvement 50
// [t=0.015934s, 1936 KB] Improvement below threshold. Stop hill climbing.
// [t=0.015943s, 1936 KB] Hill climbing iterations: 3
// [t=0.015948s, 1936 KB] Hill climbing generated patterns: 21
// [t=0.015951s, 1936 KB] Hill climbing rejected patterns: 0
// [t=0.015954s, 1936 KB] Hill climbing maximum PDB size: 30
// [t=0.015957s, 1936 KB] Hill climbing time: 0.009729s
// [t=0.016035s, 1936 KB] hill climbing pattern collection generator number of patterns: 6
// [t=0.016042s, 1936 KB] hill climbing pattern collection generator total PDB size: 24
// [t=0.016046s, 1936 KB] hill climbing pattern collection generator computation time: 0.012436s
// [t=0.016054s, 1936 KB] Running dominance pruning...
// [t=0.016062s, 1936 KB] Pruned 1 of 3 pattern cliques
// [t=0.016065s, 1936 KB] Pruned 0 of 6 PDBs
// [t=0.016068s, 1936 KB] Dominance pruning took 0.000012s
// [t=0.016072s, 1936 KB] Canonical PDB heuristic number of patterns: 6
// [t=0.016075s, 1936 KB] Canonical PDB heuristic total PDB size: 24
// [t=0.016078s, 1936 KB] Canonical PDB heuristic computation time: 0.012502s
// [t=0.016139s, 1936 KB] Building successor generator...done!
// [t=0.016173s, 1936 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.016177s, 1936 KB] time for successor generation creation: 0.000026s
// [t=0.016185s, 1936 KB] Variables: 7
// [t=0.016188s, 1936 KB] FactPairs: 24
// [t=0.016190s, 1936 KB] Bytes per state: 4
// [t=0.016247s, 1936 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.016275s, 1936 KB] New best heuristic value for cpdbs: 5
// [t=0.016281s, 1936 KB] g=0, 1 evaluated, 0 expanded
// [t=0.016285s, 1936 KB] f = 5, 1 evaluated, 0 expanded
// [t=0.016293s, 1936 KB] Initial heuristic value for cpdbs: 5
// [t=0.016296s, 1936 KB] pruning method: none
// [t=0.016311s, 1936 KB] New best heuristic value for cpdbs: 4
// [t=0.016316s, 1936 KB] g=1, 2 evaluated, 1 expanded
// [t=0.016334s, 1936 KB] f = 6, 10 evaluated, 2 expanded
// [t=0.016349s, 1936 KB] New best heuristic value for cpdbs: 3
// [t=0.016353s, 1936 KB] g=3, 15 evaluated, 4 expanded
// [t=0.016418s, 1936 KB] f = 7, 38 evaluated, 22 expanded
// [t=0.016434s, 1936 KB] New best heuristic value for cpdbs: 2
// [t=0.016438s, 1936 KB] g=5, 43 evaluated, 25 expanded
// [t=0.016585s, 1936 KB] f = 8, 110 evaluated, 76 expanded
// [t=0.016606s, 1936 KB] f = 9, 114 evaluated, 81 expanded
// [t=0.016718s, 1936 KB] f = 10, 164 evaluated, 114 expanded
// [t=0.016727s, 1936 KB] New best heuristic value for cpdbs: 1
// [t=0.016731s, 1936 KB] g=9, 165 evaluated, 115 expanded
// [t=0.016936s, 1936 KB] f = 11, 228 evaluated, 212 expanded
// [t=0.016959s, 1936 KB] New best heuristic value for cpdbs: 0
// [t=0.016963s, 1936 KB] g=11, 237 evaluated, 216 expanded
// [t=0.016966s, 1936 KB] Solution found!
// [t=0.016970s, 1936 KB] Actual search time: 0.000672s
// Peak memory: 1936 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(ipdb())', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Réduction des étiquettes
//
// Fast Downward offre une technique de réduction d'étiquettes, nommée "Exact Generalized Label Reduction". Cette technique peut être appliquée avant le rétrécissement et avant la fusion des systèmes de transitions.
//
// #### Fabriques de repères et fonctions de scoring
//
// Fast Downward propose divers types de fabriques de repères et plusieurs fonctions de scoring. Les repères peuvent être utilisés pour guider la recherche de planification, tandis que les fonctions de scoring sont utilisées pour évaluer les candidats à la fusion.
//
// #### Stratégies de fusion
//
// Fast Downward propose plusieurs stratégies de fusion, y compris l'utilisation d'un arbre de fusion précalculé, la stratégie de fusion SSCs, et la stratégie de fusion sans état. Ces stratégies peuvent être personnalisées à l'aide de différents sélecteurs de fusion.

// %%
// Exemple d'exécution avec une stratégie de fusion
runner.RunFastDownward("misc/tests/benchmarks/gripper/domain.pddl", "misc/tests/benchmarks/gripper/prob01.pddl", "--search \"astar(merge_and_shrink(merge_strategy=merge_precomputed(merge_tree=linear(variable_order=reverse_level)),shrink_strategy=shrink_bisimulation(greedy=true),label_reduction=exact(before_shrinking=true,before_merging=false)))\"");
// Out:
// Debut du fichier Domaine (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/domain.pddl):
// (define (domain gripper-strips)
//    (:predicates (room ?r)
// 		(ball ?b)
// 		(gripper ?g)
// 		(at-robby ?r)
// 		(at ?b ?r)
// 		(free ?g)
// 		(carry ?o ?g))
//    (:action move
//        :parameters  (?from ?to)
//        :precondition (and  (room ?from) (room ?to) (at-robby ?from))
//        :effect (and  (at-robby ?to)
// 		     (not (at-robby ?from))))
//    (:action pick
//        :parameters (?obj ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (at ?obj ?room) (at-robby ?room) (free ?gripper))
//        :effect (and (carry ?obj ?gripper)
// 		    (not (at ?obj ?room))
// 		    (not (free ?gripper))))
//    (:action drop
//        :parameters  (?obj  ?room ?gripper)
//        :precondition  (and  (ball ?obj) (room ?room) (gripper ?gripper)
// 			    (carry ?obj ?gripper) (at-robby ?room))
//        :effect (and (at ?obj ?room)
// 		    (free ?gripper)
// 		    (not (carry ?obj ?gripper)))))
// Debut du fichier Probleme (C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc/tests/benchmarks/gripper/prob01.pddl):
// (define (problem strips-gripper-x-1)
//    (:domain gripper-strips)
//    (:objects rooma roomb ball4 ball3 ball2 ball1 left right)
//    (:init (room rooma)
//           (room roomb)
//           (ball ball4)
//           (ball ball3)
//           (ball ball2)
//           (ball ball1)
//           (at-robby rooma)
//           (free left)
//           (free right)
//           (at ball4 rooma)
//           (at ball3 rooma)
//           (at ball2 rooma)
//           (at ball1 rooma)
//           (gripper left)
//           (gripper right))
//    (:goal (and (at ball4 roomb)
//                (at ball3 roomb)
//                (at ball2 roomb)
//                (at ball1 roomb))))
// INFO     planner time limit: None
// INFO     planner memory limit: None
//
// INFO     Running translator.
// INFO     translator stdin: None
// INFO     translator time limit: None
// INFO     translator memory limit: None
// INFO     translator command line string: 'C:\ProgramData\miniconda3\python.exe' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\translate\translate.py' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\domain.pddl' 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\misc\tests\benchmarks\gripper\prob01.pddl' --sas-file output.sas
// Warning! SIGXCPU is not available on your platform. This means that the planner cannot be gracefully terminated when using a time limit, which, however, is probably supported on your platform anyway.
// Parsing...
// Parsing: [0.000s CPU, 0.002s wall-clock]
// Normalizing task... [0.000s CPU, 0.000s wall-clock]
// Instantiating...
// Generating Datalog program... [0.000s CPU, 0.000s wall-clock]
// Normalizing Datalog program...
// Normalizing Datalog program: [0.000s CPU, 0.002s wall-clock]
// Preparing model... [0.000s CPU, 0.000s wall-clock]
// Generated 24 rules.
// Computing model... [0.000s CPU, 0.001s wall-clock]
// 81 relevant atoms
// 60 auxiliary atoms
// 141 final queue length
// 180 total queue pushes
// Completing instantiation... [0.000s CPU, 0.001s wall-clock]
// Instantiating: [0.000s CPU, 0.004s wall-clock]
// Computing fact groups...
// Finding invariants...
// 10 initial candidates
// Finding invariants: [0.000s CPU, 0.001s wall-clock]
// Checking invariant weight... [0.000s CPU, 0.000s wall-clock]
// Instantiating groups... [0.000s CPU, 0.000s wall-clock]
// Collecting mutex groups... [0.000s CPU, 0.000s wall-clock]
// Choosing groups...
// 0 uncovered facts
// Choosing groups: [0.000s CPU, 0.000s wall-clock]
// Building translation key... [0.000s CPU, 0.000s wall-clock]
// Computing fact groups: [0.016s CPU, 0.001s wall-clock]
// Building STRIPS to SAS dictionary... [0.000s CPU, 0.000s wall-clock]
// Building dictionary for full mutex groups... [0.000s CPU, 0.000s wall-clock]
// Building mutex information...
// Building mutex information: [0.000s CPU, 0.000s wall-clock]
// Translating task...
// Processing axioms...
// Simplifying axioms... [0.000s CPU, 0.000s wall-clock]
// Translator axioms removed by simplifying: 0
// Processing axioms: [0.000s CPU, 0.000s wall-clock]
// Translating task: [0.000s CPU, 0.001s wall-clock]
// 0 effect conditions simplified
// 0 implied preconditions added
// Detecting unreachable propositions...
// 0 operators removed
// 0 axioms removed
// 3 propositions removed
// Detecting unreachable propositions: [0.000s CPU, 0.000s wall-clock]
// Reordering and filtering variables...
// 7 of 7 variables necessary.
// 4 of 7 mutex groups necessary.
// 34 of 34 operators necessary.
// 0 of 0 axiom rules necessary.
// Reordering and filtering variables: [0.000s CPU, 0.000s wall-clock]
// Translator variables: 7
// Translator derived variables: 0
// Translator facts: 24
// Translator goal facts: 4
// Translator mutex groups: 4
// Translator total mutex groups size: 16
// Translator operators: 34
// Translator axioms: 0
// Translator task size: 233
// warning: could not determine peak memory
// Writing output... [0.000s CPU, 0.001s wall-clock]
// Done! [0.016s CPU, 0.010s wall-clock]
// translate exit code: 0
//
// INFO     Running search (release).
// INFO     search stdin: output.sas
// INFO     search time limit: None
// INFO     search memory limit: None
// INFO     search command line string: 'C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\builds\release\bin\downward.exe' --search 'astar(merge_and_shrink(merge_strategy=merge_precomputed(merge_tree=linear(variable_order=reverse_level)),shrink_strategy=shrink_bisimulation(greedy=true),label_reduction=exact(before_shrinking=true,before_merging=false)))' --internal-plan-file sas_plan < output.sas
// [t=0.001190s, 1680 KB] reading input...
// [t=0.001751s, 1680 KB] done reading input!
// [t=0.004027s, 1908 KB] Initializing merge-and-shrink heuristic...
// [t=0.004046s, 1908 KB] Running merge-and-shrink algorithm...
// [t=0.004049s, 1908 KB] Merge strategy options:
// [t=0.004052s, 1908 KB] Type: precomputed
// [t=0.004054s, 1908 KB] Merge tree options:
// [t=0.004056s, 1908 KB] Type: linear
// [t=0.004058s, 1908 KB] Update option: use random
// [t=0.004062s, 1908 KB] Variable order type: by reverse level
//
// [t=0.004065s, 1908 KB] Options related to size limits and shrinking:
// [t=0.004067s, 1908 KB] Transition system size limit: 50000
// [t=0.004069s, 1908 KB] Transition system size limit right before merge: 50000
// [t=0.004071s, 1908 KB] Threshold to trigger shrinking right before merge: 50000
//
// [t=0.004099s, 1908 KB] Shrink strategy options:
// [t=0.004105s, 1908 KB] Type: bisimulation
// [t=0.004109s, 1908 KB] Bisimulation type: greedy
// [t=0.004111s, 1908 KB] At limit: return
//
// [t=0.004114s, 1908 KB] Pruning unreachable states: yes
// [t=0.004116s, 1908 KB] Pruning irrelevant states: yes
//
// [t=0.004121s, 1908 KB] Label reduction options:
// [t=0.004125s, 1908 KB] Before merging: disabled
// [t=0.004129s, 1908 KB] Before shrinking: enabled
// [t=0.004132s, 1908 KB] Method: all transition systems with fixpoint computation
// [t=0.004134s, 1908 KB] System order: random
//
// [t=0.004137s, 1908 KB] Main loop max time in seconds: inf
//
//
// [t=0.004145s, 1908 KB] Building atomic transition systems...
// [t=0.004227s, 1908 KB] M&S algorithm timer: 0.000183s (after computation of atomic factors)
//
// [t=0.004242s, 1908 KB] Starting main loop without a time limit.
// [t=0.004254s, 1908 KB] building causal graph...done! [t=0.000019s]
// [t=0.004287s, 1908 KB] Next pair of indices: (0, 1)
// [t=0.004291s, 1908 KB] M&S algorithm main loop timer: 0.000052s (after computation of next merge)
// [t=0.004686s, 1908 KB] M&S algorithm main loop timer: 0.000448s (after label reduction)
// [t=0.004711s, 1908 KB] M&S algorithm main loop timer: 0.000473s (after merging)
//
// [t=0.004717s, 1908 KB] Next pair of indices: (7, 2)
// [t=0.004721s, 1908 KB] M&S algorithm main loop timer: 0.000482s (after computation of next merge)
// [t=0.004873s, 1908 KB] M&S algorithm main loop timer: 0.000634s (after merging)
//
// [t=0.004884s, 1908 KB] Next pair of indices: (8, 3)
// [t=0.004886s, 1908 KB] M&S algorithm main loop timer: 0.000647s (after computation of next merge)
// [t=0.005006s, 1908 KB] M&S algorithm main loop timer: 0.000768s (after label reduction)
// [t=0.005089s, 1908 KB] M&S algorithm main loop timer: 0.000851s (after merging)
// [t=0.005115s, 1908 KB] M&S algorithm main loop timer: 0.000876s (after pruning)
//
// [t=0.005120s, 1908 KB] Next pair of indices: (9, 4)
// [t=0.005124s, 1908 KB] M&S algorithm main loop timer: 0.000885s (after computation of next merge)
// [t=0.005171s, 1908 KB] M&S algorithm main loop timer: 0.000932s (after label reduction)
// [t=0.005280s, 1908 KB] M&S algorithm main loop timer: 0.001042s (after merging)
// [t=0.005310s, 1908 KB] M&S algorithm main loop timer: 0.001071s (after pruning)
//
// [t=0.005317s, 1908 KB] Next pair of indices: (10, 5)
// [t=0.005319s, 1908 KB] M&S algorithm main loop timer: 0.001080s (after computation of next merge)
// [t=0.005353s, 1908 KB] M&S algorithm main loop timer: 0.001114s (after label reduction)
// [t=0.005518s, 1908 KB] M&S algorithm main loop timer: 0.001280s (after merging)
// [t=0.005556s, 1908 KB] M&S algorithm main loop timer: 0.001317s (after pruning)
//
// [t=0.005563s, 1908 KB] Next pair of indices: (11, 6)
// [t=0.005566s, 1908 KB] M&S algorithm main loop timer: 0.001326s (after computation of next merge)
// [t=0.005602s, 1908 KB] M&S algorithm main loop timer: 0.001363s (after label reduction)
// [t=0.005839s, 1908 KB] M&S algorithm main loop timer: 0.001602s (after merging)
// [t=0.005890s, 1908 KB] M&S algorithm main loop timer: 0.001651s (after pruning)
//
// [t=0.005897s, 1908 KB] End of merge-and-shrink algorithm, statistics:
// [t=0.005900s, 1908 KB] Main loop runtime: 0.001661s
// [t=0.005903s, 1908 KB] Maximum intermediate abstraction size: 552
// [t=0.005908s, 1908 KB] Final peak memory increase of merge-and-shrink algorithm: 0 KB
// [t=0.005910s, 1908 KB] Merge-and-shrink algorithm runtime: 0.001866s
//
// [t=0.005914s, 1908 KB] Number of remaining factors: 1
// [t=0.005919s, 1908 KB] Number of factors kept: 1
// [t=0.005924s, 1908 KB] Done initializing merge-and-shrink heuristic.
//
// [t=0.005994s, 1908 KB] Building successor generator...done!
// [t=0.006029s, 1908 KB] peak memory difference for successor generator creation: 0 KB
// [t=0.006032s, 1908 KB] time for successor generation creation: 0.000027s
// [t=0.006039s, 1908 KB] Variables: 7
// [t=0.006043s, 1908 KB] FactPairs: 24
// [t=0.006045s, 1908 KB] Bytes per state: 4
// [t=0.006104s, 1908 KB] Conducting best first search with reopening closed nodes, (real) bound = 2147483647
// [t=0.006122s, 1908 KB] New best heuristic value for merge_and_shrink: 11
// [t=0.006126s, 1908 KB] g=0, 1 evaluated, 0 expanded
// [t=0.006128s, 1908 KB] f = 11, 1 evaluated, 0 expanded
// [t=0.006137s, 1908 KB] Initial heuristic value for merge_and_shrink: 11
// [t=0.006140s, 1908 KB] pruning method: none
// [t=0.006154s, 1908 KB] New best heuristic value for merge_and_shrink: 10
// [t=0.006159s, 1908 KB] g=1, 3 evaluated, 1 expanded
// [t=0.006177s, 1908 KB] New best heuristic value for merge_and_shrink: 9
// [t=0.006182s, 1908 KB] g=2, 12 evaluated, 2 expanded
// [t=0.006190s, 1908 KB] New best heuristic value for merge_and_shrink: 8
// [t=0.006192s, 1908 KB] g=3, 15 evaluated, 3 expanded
// [t=0.006197s, 1908 KB] New best heuristic value for merge_and_shrink: 7
// [t=0.006201s, 1908 KB] g=4, 16 evaluated, 4 expanded
// [t=0.006211s, 1908 KB] New best heuristic value for merge_and_shrink: 6
// [t=0.006215s, 1908 KB] g=5, 19 evaluated, 5 expanded
// [t=0.006223s, 1908 KB] New best heuristic value for merge_and_shrink: 5
// [t=0.006227s, 1908 KB] g=6, 20 evaluated, 6 expanded
// [t=0.006235s, 1908 KB] New best heuristic value for merge_and_shrink: 4
// [t=0.006239s, 1908 KB] g=7, 23 evaluated, 7 expanded
// [t=0.006247s, 1908 KB] New best heuristic value for merge_and_shrink: 3
// [t=0.006250s, 1908 KB] g=8, 28 evaluated, 8 expanded
// [t=0.006254s, 1908 KB] New best heuristic value for merge_and_shrink: 2
// [t=0.006256s, 1908 KB] g=9, 29 evaluated, 9 expanded
// [t=0.006260s, 1908 KB] New best heuristic value for merge_and_shrink: 1
// [t=0.006265s, 1908 KB] g=10, 30 evaluated, 10 expanded
// [t=0.006281s, 1908 KB] New best heuristic value for merge_and_shrink: 0
// [t=0.006285s, 1908 KB] g=11, 35 evaluated, 11 expanded
// [t=0.006289s, 1908 KB] Solution found!
// [t=0.006292s, 1908 KB] Actual search time: 0.000151s
// Peak memory: 1908 KB
// caught signal 11 -- exiting
// Erreurs: Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 130, in run_search
//     call.check_call(
//     ~~~~~~~~~~~~~~~^
//         "search",
//         ^^^^^^^^^
//     ...<2 lines>...
//         time_limit=time_limit,
//         ^^^^^^^^^^^^^^^^^^^^^^
//         memory_limit=memory_limit)
//         ^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\call.py", line 63, in check_call
//     return subprocess.check_call(cmd, stdin=stdin_file, **kwargs)
//            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
//   File "C:\ProgramData\miniconda3\Lib\subprocess.py", line 419, in check_call
//     raise CalledProcessError(retcode, cmd)
// subprocess.CalledProcessError: Command '['C:\\Users\\jsboi\\.local\\fast-downward\\downward-release-24.06.1\\builds\\release\\bin\\downward.exe', '--search', 'astar(merge_and_shrink(merge_strategy=merge_precomputed(merge_tree=linear(variable_order=reverse_level)),shrink_strategy=shrink_bisimulation(greedy=true),label_reduction=exact(before_shrinking=true,before_merging=false)))', '--internal-plan-file', 'sas_plan']' returned non-zero exit status 3.
//
// During handling of the above exception, another exception occurred:
//
// Traceback (most recent call last):
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\fast-downward.py", line 5, in <module>
//     main()
//     ~~~~^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\main.py", line 40, in main
//     (exitcode, continue_execution) = run_components.run_search(args)
//                                      ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
//   File "C:\Users\jsboi\.local\fast-downward\downward-release-24.06.1\driver\run_components.py", line 142, in run_search
//     assert err.returncode >= 10 or err.returncode < 0, "got returncode < 10: {}".format(err.returncode)
//            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
// AssertionError: got returncode < 10: 3

// %% [markdown]
// #### Génération de collections de motifs
//
// Fast Downward propose une série d'algorithmes pour la génération de collections de motifs. Ces algorithmes, y compris la Factory for pattern collections, Combo, Disjoint CEGAR, et d'autres, offrent diverses stratégies pour créer des collections de motifs.
//
// #### Usines à motifs
//
// Fast Downward propose plusieurs usines à motifs, y compris la Factory for single patterns, Greedy, Manual Pattern, et Random Pattern. Chacune de ces usines offre des moyens distincts pour générer des motifs de planification.
//
// En somme, Fast Downward offre une variété d'outils pour personnaliser et optimiser le process

// %% [markdown]
// ### Soumission aux compétitions internationales
//
// Fast Downward est régulièrement soumis aux compétitions internationales de planification avec un ensemble de configurations complexes à tester sur les problèmes des benchmarks, illustrant l’utilisation simultanée de plusieurs fonctionnalités présentées ci-dessus.
//
// Le [fichier suivant](https://github.com/aibasel/downward/blob/main/misc/tests/configs.py) propose des alias de configuration élémentaires, et [ce répertoire](https://github.com/aibasel/downward/tree/main/driver/portfolios) contient un grand nombre de configurations qui ont été présentées aux compétitions (il faut fusionner les chaînes distinctes en ligne de commande).
