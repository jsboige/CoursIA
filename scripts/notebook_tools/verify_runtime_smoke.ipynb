# %%
import os
import sys
# Tell c.1186-L2 ★ ★ fondateur : print basename only -- absolute paths
# leak the machine username and trip the scrub-papermill-paths hook.
# The runtime verifier script computes the venv match itself via
# ``sys.prefix`` below, which is the canonical venv identifier.
print(f"RUNTIME sys.executable.basename={os.path.basename(sys.executable)}")
print(f"RUNTIME sys.prefix={sys.prefix}")
print(f"RUNTIME sys.base_prefix={sys.base_prefix}")
_RUNTIME_SYS_EXECUTABLE_BASENAME = os.path.basename(sys.executable)
_RUNTIME_SYS_PREFIX = sys.prefix
_RUNTIME_SYS_BASE_PREFIX = sys.base_prefix
# Out:
# RUNTIME sys.executable.basename=python.exe
# RUNTIME sys.prefix=<USER_PATH>\AppData\Local\Programs\Python\Python311
# RUNTIME sys.base_prefix=<USER_PATH>\AppData\Local\Programs\Python\Python311
